# %%
import argparse
import pathlib
import json
import os
import torch
import numpy as np
import time
import sys
import matplotlib.pyplot as plt
import geomloss
from scipy.special import softmax
import pymeshlab
from sklearn.decomposition import PCA
import SimpleITK as sitk
import nighres

sys.path.append('/data/pauly2/tk/crashs')
from vtkutil import *
from lddmm import *
from crashs import MeshData, Template, ASHSFolder, Workspace, ashs_output_to_cruise_input, run_cruise, cruise_postproc

# %cd /data/pauly2/tk/crashs
# Out:
# /data/pauly2/tk/crashs

# %% [markdown]
# # Load the inputs and parameters

# %%
# Load the template
template = Template('/data/pauly2/ashs_xv/manifest/template_init_dir')

# Load the ASHS json
with open('/data/pauly2/ashs_xv/manifest/crashs_input_fold_0.json') as fd:
    ashs_input_desc = json.load(fd)

# Prepare device
# device = torch.device(args.device) if torch.cuda.is_available() else 'cpu'
device = torch.device(torch.cuda.current_device() if torch.cuda.is_available() else 'cpu')
print("Is cuda available?", torch.cuda.is_available())
print("Device count?", torch.cuda.device_count())
print("Current device?", torch.cuda.current_device())
print("Device name? ", torch.cuda.get_device_name(torch.cuda.current_device()))

# Keep track of ASHS importers and workspaces created
data = {}

# Run basic Nighres for each subject
for d in ashs_input_desc:
    id = d['id']
    side = d['side']

    # Create the output dir
    out_dir = os.path.join('/data/pauly2/ashs_xv/work/fold_0/crashs_build', id)
    os.makedirs(out_dir, exist_ok=True)
    workspace = Workspace(out_dir, id, side)

    # Store the data
    data[id] = { 'side': side, 'workspace': workspace }
# Out:
# Is cuda available? True
# Device count? 1
# Current device? 0
# Device name?  Quadro RTX 5000

# %%
# From the template directory, load the left/right flip file. 
flip_lr = np.loadtxt(os.path.join(template.root, 'ashs_template_flip.mat'))

# Set the sigma tensors
# sigma_varifold = torch.tensor([template['left'].get_varifold_sigma()], dtype=torch.float32, device=device)
sigma_varifold = torch.tensor([5], dtype=torch.float32, device=device)
sigma_lddmm = torch.tensor([template.get_lddmm_sigma()], dtype=torch.float32, device=device)

# Load each of the meshes that will be used to build the template
md = {}
md_ds = {}
for id, sd in data.items():
    
    # Depending on the side, apply flip_lr as the transform
    transform = flip_lr if sd['side'] == 'right' else None

    # Load the mesh data (inflated avg surface in ASHS template space)
    md[id] = MeshData(load_vtk(sd['workspace'].affine_moving), device, transform=transform)

    # Also downsample the mesh for faster affine registration
    md_ds[id] = MeshData(vtk_clone_pd(md[id].pd), device, transform=transform, target_faces=5000)

    # Apply additional Taubin smoothing to help build a smoother template
    save_vtk(md[id].pd, f'tmp/tb_input_{id}.vtk')
# Out:
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces
# Decimating mesh, target: 5000 faces
# Decimation complete, 5000 faces

# %%
# Compute the varifold loss between all pairs of atlases in the template subset before
# any registration - this is to determine the best candidate for the template
""" ids = list(md.keys())
dsq_sub = np.zeros((len(md), len(md)))
for i1, (k1,v1) in enumerate(md.items()):
    for i2, (k2,v2) in enumerate(md.items()):
        pair_loss = lossVarifoldSurfWithLabels(v1.ft, v2.vt, v2.ft, v1.lpt, v2.lpt, 
                                                GaussLinKernelWithLabels(sigma_varifold, v1.lp.shape[1]))
        dsq_sub[i1,i2] = pair_loss(v1.vt).item()
        print(k1, k2, dsq_sub[i1,i2])
        
# Find the index of the template candidate
i_src = np.argmin(dsq_sub.sum(axis=1))
id_src = ids[i_src]
print(f'Best template candidate: {id_src}, mean distance {dsq_sub.mean(axis=1)[i_src]} vs {dsq_sub.mean()}') """
# Out:
# " ids = list(md.keys())\ndsq_sub = np.zeros((len(md), len(md)))\nfor i1, (k1,v1) in enumerate(md.items()):\n    for i2, (k2,v2) in enumerate(md.items()):\n        pair_loss = lossVarifoldSurfWithLabels(v1.ft, v2.vt, v2.ft, v1.lpt, v2.lpt, \n                                                GaussLinKernelWithLabels(sigma_varifold, v1.lp.shape[1]))\n        dsq_sub[i1,i2] = pair_loss(v1.vt).item()\n        print(k1, k2, dsq_sub[i1,i2])\n        \n# Find the index of the template candidate\ni_src = np.argmin(dsq_sub.sum(axis=1))\nid_src = ids[i_src]\nprint(f'Best template candidate: {id_src}, mean distance {dsq_sub.mean(axis=1)[i_src]} vs {dsq_sub.mean()}') "

# %%
def my_rotation_from_vector(x):
    """
    Generate a 3D rotation vector from three parameters.

    Args:
        x: 
            A torch tensor of shape (3). It contains the parameters of the rotation.
            [Write more detail about what the parameters mean geometrically]
    Output:
        A shape (3,3) tensor holding a rotation matrix corresponding to x
    """
    # I will use the the axis/angle representation. The norm of the vector x gives the
    # angle in radians, and the normalized vector is the axis around which the rotation
    # is performed. At x=[0,0,0], there is a degeneracy that requires special handling
    # but this should not prevent the code from being used in optimization
    
    # Compute theta, no issues here
    theta = torch.norm(x)

    # Use the trick from `torch.nn.functional.normalize`, which adds a small epsilon to
    # the denominator to avoid division by zero
    v = torch.nn.functional.normalize(x, dim=0)

    # Apply the Rodrigues formula
    A = torch.zeros(3, 3, dtype=x.dtype, device=x.device)
    A[0,1], A[0,2], A[1,2] = -v[2], v[1], -v[0]
    K = A - A.T
    R = torch.eye(3, dtype=x.dtype, device=x.device) + torch.sin(theta) * K + (1-torch.cos(theta)) * (K @ K)
    return R

# %%
# Compute the varifold loss between all pairs of atlases with similarity transform,
# running a quick registration between all pairs. This might get too much for large
# training sets though
ids = list(md.keys())
dsq_sub = np.zeros((len(md), len(md)))

# The default affine parameters
theta_all = { }
kernel = GaussLinKernelWithLabels(sigma_varifold, md[ids[0]].lp.shape[1])
for i1, (k1,v1) in enumerate(md_ds.items()):
    for i2, (k2,v2) in enumerate(md_ds.items()):
        if k1 != k2: 
            # Define the symmetric loss for this pair
            loss_ab = lossVarifoldSurfWithLabels(v1.ft, v2.vt, v2.ft, v1.lpt, v2.lpt, kernel)
            loss_ba = lossVarifoldSurfWithLabels(v2.ft, v1.vt, v1.ft, v2.lpt, v1.lpt, kernel)
            pair_theta = torch.tensor([0.01, 0.01, 0.01, 1.0, 0.0, 0.0, 0.0], 
                                    dtype=torch.float32, device=device, requires_grad=True)
            
            # Create optimizer
            opt_affine = torch.optim.LBFGS([pair_theta], max_eval=10, max_iter=10, line_search_fn='strong_wolfe')

            # Define closure
            def closure():
                opt_affine.zero_grad()

                R = my_rotation_from_vector(pair_theta[0:3]) * pair_theta[3]
                b = pair_theta[4:]
                R_inv = torch.inverse(R)
                b_inv = - R_inv @ b

                v1_to_v2 = (R @ v1.vt.t()).t() + b
                v2_to_v1 = (R_inv @ v2.vt.t()).t() + b_inv

                L = 0.5 * (loss_ab(v1_to_v2) + loss_ba(v2_to_v1))
                L.backward()
                return L
            
            # Run the optimization
            for i in range(10):
                opt_affine.step(closure)

            # Print loss and record the best run/best parameters
            dsq_sub[i1,i2] = closure().item()
            theta_all[(k1,k2)] = pair_theta.detach()
            print(f'Pair {k1}, {k2} loss : {dsq_sub[i1,i2]:8.6f}')
# Out:
# Pair 104937L, 106049L loss : 100608.500000
# Pair 104937L, 106312R loss : 106330.859375
# Pair 104937L, 113909R loss : 96887.109375
# Pair 104937L, 116748R loss : 81386.609375
# Pair 104937L, 117243R loss : 113444.625000
# Pair 104937L, 117667R loss : 93864.312500
# Pair 104937L, 118374L loss : 81879.468750
# Pair 104937L, 118430R loss : 105904.375000
# Pair 104937L, 120126L loss : 75038.906250
# Pair 104937L, 120267L loss : 95297.304688
# Pair 104937L, 120937L loss : 118714.132812
# Pair 104937L, 121250L loss : 63058.117188
# Pair 106049L, 104937L loss : 100663.859375
# Pair 106049L, 106312R loss : 87120.843750
# Pair 106049L, 113909R loss : 86781.898438
# Pair 106049L, 116748R loss : 91687.468750
# Pair 106049L, 117243R loss : 75494.968750
# Pair 106049L, 117667R loss : 84323.539062
# Pair 106049L, 118374L loss : 47913.578125
# Pair 106049L, 118430R loss : 72208.617188
# Pair 106049L, 120126L loss : 88430.046875
# Pair 106049L, 120267L loss : 75380.109375
# Pair 106049L, 120937L loss : 108996.382812
# Pair 106049L, 121250L loss : 100324.109375
# Pair 106312R, 104937L loss : 106330.843750
# Pair 106312R, 106049L loss : 87121.195312
# Pair 106312R, 113909R loss : 75840.140625
# Pair 106312R, 116748R loss : 95195.648438
# Pair 106312R, 117243R loss : 94761.679688
# Pair 106312R, 117667R loss : 100874.328125
# Pair 106312R, 118374L loss : 87517.078125
# Pair 106312R, 118430R loss : 81260.546875
# Pair 106312R, 120126L loss : 92076.617188
# Pair 106312R, 120267L loss : 82983.046875
# Pair 106312R, 120937L loss : 110931.593750
# Pair 106312R, 121250L loss : 99955.132812
# Pair 113909R, 104937L loss : 96887.046875
# Pair 113909R, 106049L loss : 86781.890625
# Pair 113909R, 106312R loss : 75824.750000
# Pair 113909R, 116748R loss : 93647.531250
# Pair 113909R, 117243R loss : 86217.210938
# Pair 113909R, 117667R loss : 53286.492188
# Pair 113909R, 118374L loss : 75757.492188
# Pair 113909R, 118430R loss : 64148.375000
# Pair 113909R, 120126L loss : 73825.601562
# Pair 113909R, 120267L loss : 72847.382812
# Pair 113909R, 120937L loss : 98410.773438
# Pair 113909R, 121250L loss : 82690.726562
# Pair 116748R, 104937L loss : 81362.164062
# Pair 116748R, 106049L loss : 91686.234375
# Pair 116748R, 106312R loss : 95198.140625
# Pair 116748R, 113909R loss : 93647.523438
# Pair 116748R, 117243R loss : 118044.671875
# Pair 116748R, 117667R loss : 92327.351562
# Pair 116748R, 118374L loss : 90474.320312
# Pair 116748R, 118430R loss : 107135.914062
# Pair 116748R, 120126L loss : 77119.039062
# Pair 116748R, 120267L loss : 78346.781250
# Pair 116748R, 120937L loss : 141267.140625
# Pair 116748R, 121250L loss : 87300.210938
# Pair 117243R, 104937L loss : 113444.625000
# Pair 117243R, 106049L loss : 75494.968750
# Pair 117243R, 106312R loss : 94783.468750
# Pair 117243R, 113909R loss : 86217.210938
# Pair 117243R, 116748R loss : 118044.671875
# Pair 117243R, 117667R loss : 78249.812500
# Pair 117243R, 118374L loss : 64708.398438
# Pair 117243R, 118430R loss : 86989.312500
# Pair 117243R, 120126L loss : 98862.179688
# Pair 117243R, 120267L loss : 86913.273438
# Pair 117243R, 120937L loss : 104642.281250
# Pair 117243R, 121250L loss : 95521.453125
# Pair 117667R, 104937L loss : 93864.343750
# Pair 117667R, 106049L loss : 84323.539062
# Pair 117667R, 106312R loss : 100874.335938
# Pair 117667R, 113909R loss : 53283.375000
# Pair 117667R, 116748R loss : 92325.609375
# Pair 117667R, 117243R loss : 78249.804688
# Pair 117667R, 118374L loss : 80566.078125
# Pair 117667R, 118430R loss : 56414.015625
# Pair 117667R, 120126L loss : 89379.375000
# Pair 117667R, 120267L loss : 78391.000000
# Pair 117667R, 120937L loss : 113136.992188
# Pair 117667R, 121250L loss : 92914.695312
# Pair 118374L, 104937L loss : 81879.468750
# Pair 118374L, 106049L loss : 47916.046875
# Pair 118374L, 106312R loss : 87517.093750
# Pair 118374L, 113909R loss : 75757.421875
# Pair 118374L, 116748R loss : 90474.320312
# Pair 118374L, 117243R loss : 64702.921875
# Pair 118374L, 117667R loss : 80566.078125
# Pair 118374L, 118430R loss : 70538.515625
# Pair 118374L, 120126L loss : 77441.375000
# Pair 118374L, 120267L loss : 65999.140625
# Pair 118374L, 120937L loss : 90354.671875
# Pair 118374L, 121250L loss : 83211.890625
# Pair 118430R, 104937L loss : 105904.328125
# Pair 118430R, 106049L loss : 72229.859375
# Pair 118430R, 106312R loss : 81260.539062
# Pair 118430R, 113909R loss : 64148.375000
# Pair 118430R, 116748R loss : 107135.914062
# Pair 118430R, 117243R loss : 86989.320312
# Pair 118430R, 117667R loss : 56414.000000
# Pair 118430R, 118374L loss : 70538.515625
# Pair 118430R, 120126L loss : 80470.640625
# Pair 118430R, 120267L loss : 81047.976562
# Pair 118430R, 120937L loss : 109131.414062
# Pair 118430R, 121250L loss : 103305.414062
# Pair 120126L, 104937L loss : 75038.687500
# Pair 120126L, 106049L loss : 88430.031250
# Pair 120126L, 106312R loss : 92076.601562
# Pair 120126L, 113909R loss : 73825.601562
# Pair 120126L, 116748R loss : 77119.046875
# Pair 120126L, 117243R loss : 98862.187500
# Pair 120126L, 117667R loss : 89379.382812
# Pair 120126L, 118374L loss : 77442.046875
# Pair 120126L, 118430R loss : 80470.656250
# Pair 120126L, 120267L loss : 84306.468750
# Pair 120126L, 120937L loss : 122518.695312
# Pair 120126L, 121250L loss : 69060.281250
# Pair 120267L, 104937L loss : 95299.742188
# Pair 120267L, 106049L loss : 75379.734375
# Pair 120267L, 106312R loss : 82983.031250
# Pair 120267L, 113909R loss : 72835.609375
# Pair 120267L, 116748R loss : 78346.773438
# Pair 120267L, 117243R loss : 86917.523438
# Pair 120267L, 117667R loss : 78398.140625
# Pair 120267L, 118374L loss : 65999.132812
# Pair 120267L, 118430R loss : 81047.765625
# Pair 120267L, 120126L loss : 84306.453125
# Pair 120267L, 120937L loss : 110584.914062
# Pair 120267L, 121250L loss : 78707.945312
# Pair 120937L, 104937L loss : 118714.125000
# Pair 120937L, 106049L loss : 108995.609375
# Pair 120937L, 106312R loss : 110931.242188
# Pair 120937L, 113909R loss : 98410.757812
# Pair 120937L, 116748R loss : 141267.156250
# Pair 120937L, 117243R loss : 104642.289062
# Pair 120937L, 117667R loss : 113137.015625
# Pair 120937L, 118374L loss : 90354.328125
# Pair 120937L, 118430R loss : 109128.281250
# Pair 120937L, 120126L loss : 122518.695312
# Pair 120937L, 120267L loss : 110584.898438
# Pair 120937L, 121250L loss : 102918.476562
# Pair 121250L, 104937L loss : 63060.976562
# Pair 121250L, 106049L loss : 100324.101562
# Pair 121250L, 106312R loss : 99955.125000
# Pair 121250L, 113909R loss : 82690.726562
# Pair 121250L, 116748R loss : 87300.203125
# Pair 121250L, 117243R loss : 95521.445312
# Pair 121250L, 117667R loss : 92914.687500
# Pair 121250L, 118374L loss : 83212.617188
# Pair 121250L, 118430R loss : 103305.398438
# Pair 121250L, 120126L loss : 69060.257812
# Pair 121250L, 120267L loss : 78707.945312
# Pair 121250L, 120937L loss : 102918.679688

# %%
# Find the index of the template candidate
i_best = np.argmin(dsq_sub.sum(axis=1))
k_best = ids[i_best]
print(f'Best template candidate: {k_best}, mean distance {dsq_sub.mean(axis=1)[i_best]} vs {dsq_sub.mean()}')

# Now we need to go through and apply the best transformation to each case
for i, (k,v) in enumerate(md_ds.items()):
    affine_mat = np.eye(4)
    md_full = md[k]
    if k != k_best:
        # Compute the transform to move k to k_best
        theta_pair = theta_all[(k,k_best)]
        R = my_rotation_from_vector(theta_pair[0:3]) * theta_pair[3]
        b = theta_pair[4:]

        # Save the transformation
        affine_mat[0:3,0:3] = R.detach().cpu().numpy()
        affine_mat[0:3,  3] = b.detach().cpu().numpy()

        # Save the registered mesh (original resolution)
        v_reg = (R @ md_full.vt.t()).t() + b
        pd_reg = vtk_make_pd(v_reg.detach().cpu().numpy(), md_full.f)
        pd_reg = vtk_set_cell_array(pd_reg, 'plab', md_full.lp)
        save_vtk(pd_reg, f'tmp/test_register_{k}.vtk')
    else:
        pd_reg = vtk_make_pd(md_full.vt.detach().cpu().numpy(), md_full.f)
        pd_reg = vtk_set_cell_array(pd_reg, 'plab', md_full.lp)
        save_vtk(pd_reg, f'tmp/test_register_{k}.vtk')

    np.savetxt(f'tmp/affine_to_template_{k}.mat', affine_mat)
# Out:
# Best template candidate: 118374L, mean distance 70489.14963942308 vs 81912.80422522189

# %% [markdown]
# # Build the template starting from an ellipsoid

# %%
# Now let's read these meshes all over again
md_aff = {}
for id, sd in data.items():
    md_aff[id] = MeshData(load_vtk(f'tmp/test_register_{id}.vtk'), device)

# %%
# Generate a sphere
ms = pymeshlab.MeshSet()
ms.create_sphere(subdiv = 4)
m0 = ms.mesh(0)
v_sph, f_sph = m0.vertex_matrix(), m0.face_matrix()
pd_sph = vtk_make_pd(v_sph, f_sph)
pd_sph = vtk_set_cell_array(pd_sph, 'plab', np.zeros((f_sph.shape[0],1)))
md_sph = MeshData(pd_sph, device)

# Map the cartesian coordinates to spherical coordinates
sph_phi = np.arctan2(v_sph[:,1], v_sph[:,0])
sph_theta = np.arccos(v_sph[:,2])

# %%
# Find an affine transformation of the sphere that best aligns with the data 
# using the varifold measure
v_all = np.concatenate([ x.v for id,x in md_aff.items() ], 0)
pca = PCA(n_components=3)
pca.fit(v_all)

# Create losses for each of the target meshes
kernel = GaussLinKernel(sigma_varifold)
loss = { id: lossVarifoldSurf(md_sph.ft, v.vt, v.ft, kernel) for (id,v) in md_aff.items() }

# Create a parameter tensor for the sphere
b = torch.tensor(pca.mean_, dtype=torch.float32, device=device, requires_grad=True).contiguous()
A = torch.tensor(pca.get_covariance(), dtype=torch.float32, device=device, requires_grad=True).contiguous()

# Generate a combined objective function
optimizer = torch.optim.LBFGS([A,b], max_eval=16, max_iter=16, line_search_fn='strong_wolfe')
start = time.time()

def closure():
    optimizer.zero_grad()
    # Apply transformation to the sphere
    x = md_sph.vt
    y = (A @ x.T).T + b
    L = 0
    for i, (id,v) in enumerate(md_aff.items()):
        L = L + loss[id](y)
    L = L / len(md_aff.items())
    L.backward()
    return L

for i in range(30):
    print(f'Iter {i:03d}, Loss: {closure()}')
    optimizer.step(closure)
# Out:
# Iter 000, Loss: 12633112.0
# Iter 001, Loss: 248984.203125
# Iter 002, Loss: 244574.953125
# Iter 003, Loss: 244538.859375
# Iter 004, Loss: 244467.703125
# Iter 005, Loss: 244355.515625
# Iter 006, Loss: 243975.21875
# Iter 007, Loss: 243362.234375
# Iter 008, Loss: 243129.703125
# Iter 009, Loss: 242992.734375
# Iter 010, Loss: 242734.4375
# Iter 011, Loss: 241542.375
# Iter 012, Loss: 239994.625
# Iter 013, Loss: 238290.015625
# Iter 014, Loss: 235576.390625
# Iter 015, Loss: 234737.625
# Iter 016, Loss: 226558.734375
# Iter 017, Loss: 207570.4375
# Iter 018, Loss: 138724.328125
# Iter 019, Loss: 117534.96875
# Iter 020, Loss: 117534.1875
# Iter 021, Loss: 117534.1796875
# Iter 022, Loss: 117534.1796875
# Iter 023, Loss: 117534.1796875
# Iter 024, Loss: 117534.1796875
# Iter 025, Loss: 117534.1796875
# Iter 026, Loss: 117534.1796875
# Iter 027, Loss: 117534.1796875
# Iter 028, Loss: 117534.1796875
# Iter 029, Loss: 117534.1796875

# %%
# Compute the new rotated sphere
v_sph_opt = (A @ md_sph.vt.T).T + b

# Peform remeshing of the sphere
ms = pymeshlab.MeshSet()
ms.add_mesh(pymeshlab.Mesh(vertex_matrix=v_sph_opt.detach().cpu().numpy(), face_matrix=md_sph.f))
ms.meshing_isotropic_explicit_remeshing()
v_ell, f_ell = ms.mesh(0).vertex_matrix(), ms.mesh(0).face_matrix()

pd_ell = vtk_make_pd(v_ell, f_ell)
pd_ell = vtk_set_cell_array(pd_ell, 'plab', np.zeros((f_ell.shape[0],1)))
md_ell = MeshData(pd_ell, device)

pd_sphere_opt = vtk_make_pd(v_ell, f_ell)
save_vtk(pd_sphere_opt, 'tmp/ellipsoid_best_fit.vtk')

# %%
# Now we need to initialize the labeling of the sphere. We can try directly to use OMT to 
# match the sphere to each of the meshes and maybe that's going to be good enough for getting
# the initial label distributions. If not, have to deform
def to_measure(points, triangles):
    """Turns a triangle into a weighted point cloud."""

    # Our mesh is given as a collection of ABC triangles:
    A, B, C = points[triangles[:, 0]], points[triangles[:, 1]], points[triangles[:, 2]]

    # Locations and weights of our Dirac atoms:
    X = (A + B + C) / 3  # centers of the faces
    S = torch.sqrt(torch.sum(torch.cross(B - A, C - A) ** 2, dim=1)) / 2  # areas of the faces

    # We return a (normalized) vector of weights + a "list" of points
    return S / torch.sum(S), X

# Compute optimal transport matching
def match_omt(vs, fs, vt, ft):
    (a_src, x_src) = to_measure(vs, fs)
    (a_trg, x_trg) = to_measure(vt, ft)
    x_src.requires_grad_(True)
    x_trg.requires_grad_(True)

    # Generate correspondence between models using OMT
    t_start = time.time()
    w_loss = geomloss.SamplesLoss("sinkhorn", p=2, blur=0.05, scaling=0.8, backend='multiscale', verbose=True)
    w_loss_value = w_loss(a_src, x_src, a_trg, x_trg)
    [w_loss_grad] = torch.autograd.grad(w_loss_value, x_src)
    w_match = x_src - w_loss_grad / a_src[:, None]
    t_end = time.time()

    print(f'OMT matching distance: {w_loss_value.item()}, time elapsed: {t_end-t_start}')
    return w_loss_value, w_match

# %%
plab_sample = []
for (id, md_i) in md_aff.items():
    f_omt, w_omt = match_omt(md_ell.vt, md_ell.ft, md_i.vt, md_i.ft)
    lp_omt = vtk_sample_cell_array_at_vertices(md_i.pd, md_i.lp, w_omt.detach().cpu().numpy())
    plab_sample.append(lp_omt)
# Out:
# 233x385 clusters, computed at scale = 3.630
# Successive scales :  79.210, 79.210, 63.368, 50.695, 40.556, 32.444, 25.956, 20.764, 16.612, 13.289, 10.631, 8.505, 6.804, 5.443, 4.355, 3.484, 2.787, 2.230, 1.784, 1.427, 1.142, 0.913, 0.731, 0.584, 0.468, 0.374, 0.299, 0.239, 0.192, 0.153, 0.123, 0.098, 0.078, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=4.355) and 15 (σ=3.484).
# Keep 37203/89705 = 41.5% of the coarse cost matrix.
# Keep 25109/54289 = 46.3% of the coarse cost matrix.
# Keep 52585/148225 = 35.5% of the coarse cost matrix.
# OMT matching distance: 14.987838745117188, time elapsed: 3.0157408714294434
# 290x483 clusters, computed at scale = 3.324
# Successive scales :  72.530, 72.530, 58.024, 46.419, 37.135, 29.708, 23.767, 19.013, 15.211, 12.169, 9.735, 7.788, 6.230, 4.984, 3.987, 3.190, 2.552, 2.042, 1.633, 1.307, 1.045, 0.836, 0.669, 0.535, 0.428, 0.343, 0.274, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.987) and 15 (σ=3.190).
# Keep 53696/140070 = 38.3% of the coarse cost matrix.
# Keep 34624/84100 = 41.2% of the coarse cost matrix.
# Keep 79489/233289 = 34.1% of the coarse cost matrix.
# OMT matching distance: 9.348712921142578, time elapsed: 3.4682748317718506
# 234x425 clusters, computed at scale = 3.611
# Successive scales :  78.792, 78.792, 63.034, 50.427, 40.342, 32.273, 25.819, 20.655, 16.524, 13.219, 10.575, 8.460, 6.768, 5.415, 4.332, 3.465, 2.772, 2.218, 1.774, 1.419, 1.136, 0.908, 0.727, 0.581, 0.465, 0.372, 0.298, 0.238, 0.191, 0.152, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.332) and 15 (σ=3.465).
# Keep 41393/99450 = 41.6% of the coarse cost matrix.
# Keep 25400/54756 = 46.4% of the coarse cost matrix.
# Keep 64847/180625 = 35.9% of the coarse cost matrix.
# OMT matching distance: 14.486936569213867, time elapsed: 3.1235275268554688
# 254x366 clusters, computed at scale = 3.534
# Successive scales :  77.121, 77.121, 61.697, 49.358, 39.486, 31.589, 25.271, 20.217, 16.173, 12.939, 10.351, 8.281, 6.625, 5.300, 4.240, 3.392, 2.713, 2.171, 1.737, 1.389, 1.111, 0.889, 0.711, 0.569, 0.455, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.240) and 15 (σ=3.392).
# Keep 37409/92964 = 40.2% of the coarse cost matrix.
# Keep 28622/64516 = 44.4% of the coarse cost matrix.
# Keep 47720/133956 = 35.6% of the coarse cost matrix.
# OMT matching distance: 16.19204330444336, time elapsed: 2.778921365737915
# 284x447 clusters, computed at scale = 3.333
# Successive scales :  72.728, 72.728, 58.182, 46.546, 37.237, 29.789, 23.831, 19.065, 15.252, 12.202, 9.761, 7.809, 6.247, 4.998, 3.998, 3.199, 2.559, 2.047, 1.638, 1.310, 1.048, 0.838, 0.671, 0.537, 0.429, 0.343, 0.275, 0.220, 0.176, 0.141, 0.113, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=3.998) and 15 (σ=3.199).
# Keep 49046/126948 = 38.6% of the coarse cost matrix.
# Keep 33254/80656 = 41.2% of the coarse cost matrix.
# Keep 69677/199809 = 34.9% of the coarse cost matrix.
# OMT matching distance: 18.473861694335938, time elapsed: 3.248121738433838
# 227x412 clusters, computed at scale = 3.752
# Successive scales :  81.881, 81.881, 65.505, 52.404, 41.923, 33.539, 26.831, 21.465, 17.172, 13.737, 10.990, 8.792, 7.034, 5.627, 4.501, 3.601, 2.881, 2.305, 1.844, 1.475, 1.180, 0.944, 0.755, 0.604, 0.483, 0.387, 0.309, 0.247, 0.198, 0.158, 0.127, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.501) and 15 (σ=3.601).
# Keep 39783/93524 = 42.5% of the coarse cost matrix.
# Keep 24783/51529 = 48.1% of the coarse cost matrix.
# Keep 60040/169744 = 35.4% of the coarse cost matrix.
# OMT matching distance: 18.27050018310547, time elapsed: 3.234612226486206
# 234x423 clusters, computed at scale = 3.594
# Successive scales :  78.433, 78.433, 62.746, 50.197, 40.158, 32.126, 25.701, 20.561, 16.449, 13.159, 10.527, 8.422, 6.737, 5.390, 4.312, 3.450, 2.760, 2.208, 1.766, 1.413, 1.130, 0.904, 0.723, 0.579, 0.463, 0.370, 0.296, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.312) and 15 (σ=3.450).
# Keep 41107/98982 = 41.5% of the coarse cost matrix.
# Keep 25214/54756 = 46.0% of the coarse cost matrix.
# Keep 64519/178929 = 36.1% of the coarse cost matrix.
# OMT matching distance: 12.011691093444824, time elapsed: 2.876068592071533
# 234x391 clusters, computed at scale = 3.614
# Successive scales :  78.875, 78.875, 63.100, 50.480, 40.384, 32.307, 25.846, 20.677, 16.541, 13.233, 10.586, 8.469, 6.775, 5.420, 4.336, 3.469, 2.775, 2.220, 1.776, 1.421, 1.137, 0.909, 0.727, 0.582, 0.466, 0.372, 0.298, 0.238, 0.191, 0.153, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.336) and 15 (σ=3.469).
# Keep 38920/91494 = 42.5% of the coarse cost matrix.
# Keep 25490/54756 = 46.6% of the coarse cost matrix.
# Keep 56731/152881 = 37.1% of the coarse cost matrix.
# OMT matching distance: 14.4607572555542, time elapsed: 2.820617198944092
# 244x422 clusters, computed at scale = 3.573
# Successive scales :  77.969, 77.969, 62.375, 49.900, 39.920, 31.936, 25.549, 20.439, 16.351, 13.081, 10.465, 8.372, 6.697, 5.358, 4.286, 3.429, 2.743, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.286) and 15 (σ=3.429).
# Keep 43407/102968 = 42.2% of the coarse cost matrix.
# Keep 27090/59536 = 45.5% of the coarse cost matrix.
# Keep 66932/178084 = 37.6% of the coarse cost matrix.
# OMT matching distance: 9.98436450958252, time elapsed: 3.0558183193206787
# 256x428 clusters, computed at scale = 3.506
# Successive scales :  76.513, 76.513, 61.210, 48.968, 39.175, 31.340, 25.072, 20.057, 16.046, 12.837, 10.269, 8.216, 6.572, 5.258, 4.206, 3.365, 2.692, 2.154, 1.723, 1.378, 1.103, 0.882, 0.706, 0.565, 0.452, 0.361, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.206) and 15 (σ=3.365).
# Keep 43722/109568 = 39.9% of the coarse cost matrix.
# Keep 28506/65536 = 43.5% of the coarse cost matrix.
# Keep 64208/183184 = 35.1% of the coarse cost matrix.
# OMT matching distance: 11.555943489074707, time elapsed: 3.0555646419525146
# 292x423 clusters, computed at scale = 3.311
# Successive scales :  72.264, 72.264, 57.811, 46.249, 36.999, 29.599, 23.679, 18.943, 15.155, 12.124, 9.699, 7.759, 6.207, 4.966, 3.973, 3.178, 2.543, 2.034, 1.627, 1.302, 1.041, 0.833, 0.667, 0.533, 0.427, 0.341, 0.273, 0.218, 0.175, 0.140, 0.112, 0.089, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.973) and 15 (σ=3.178).
# Keep 46798/123516 = 37.9% of the coarse cost matrix.
# Keep 35098/85264 = 41.2% of the coarse cost matrix.
# Keep 61083/178929 = 34.1% of the coarse cost matrix.
# OMT matching distance: 10.699480056762695, time elapsed: 3.148804187774658
# 232x410 clusters, computed at scale = 3.670
# Successive scales :  80.082, 80.082, 64.065, 51.252, 41.002, 32.801, 26.241, 20.993, 16.794, 13.435, 10.748, 8.599, 6.879, 5.503, 4.403, 3.522, 2.818, 2.254, 1.803, 1.443, 1.154, 0.923, 0.739, 0.591, 0.473, 0.378, 0.303, 0.242, 0.194, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.403) and 15 (σ=3.522).
# Keep 39378/95120 = 41.4% of the coarse cost matrix.
# Keep 25376/53824 = 47.1% of the coarse cost matrix.
# Keep 57948/168100 = 34.5% of the coarse cost matrix.
# OMT matching distance: 16.227367401123047, time elapsed: 3.529039144515991
# 255x381 clusters, computed at scale = 3.509
# Successive scales :  76.576, 76.576, 61.261, 49.009, 39.207, 31.366, 25.092, 20.074, 16.059, 12.847, 10.278, 8.222, 6.578, 5.262, 4.210, 3.368, 2.694, 2.155, 1.724, 1.379, 1.104, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.210) and 15 (σ=3.368).
# Keep 38593/97155 = 39.7% of the coarse cost matrix.
# Keep 28387/65025 = 43.7% of the coarse cost matrix.
# Keep 50705/145161 = 34.9% of the coarse cost matrix.
# OMT matching distance: 10.748870849609375, time elapsed: 2.83768630027771

# %%
plab_sample_avg = np.stack(plab_sample).mean(0)

# %%
pd_sphere_opt_2 = vtk_set_cell_array(pd_sphere_opt, 'plab', softmax(plab_sample_avg * 10, axis=1))
save_vtk(pd_sphere_opt_2, 'tmp/ellipsoid_best_fit_plab.vtk')

# %%
# Use the sphere as a starting point for template fitting
md_src2 = MeshData(pd_sphere_opt_2, device)

# %%
# Map an array to new vertex locations
def vtk_sample_point_array_at_vertices(pd_src, array, x_samples):
    # Use the locator to sample from the halfway mesh
    loc = vtk.vtkCellLocator()
    loc.SetDataSet(pd_src)
    loc.BuildLocator()
    result = np.zeros((x_samples.shape[0], array.shape[1]))    
    cellId = vtk.reference(0)
    c = [0.0, 0.0, 0.0]
    subId = vtk.reference(0)
    d = vtk.reference(0.0)
    pcoord = [0.0, 0.0, 0.0]
    wgt = [0.0, 0.0, 0.0]
    xj = [0.0, 0.0, 0.0]
    for j in range(x_samples.shape[0]):
        loc.FindClosestPoint(x_samples[j,:], c, cellId, subId, d)
        cell = pd_src.GetCell(cellId)
        cell.EvaluatePosition(x_samples[j,:], c, subId, pcoord, d, wgt)
        result[j] = np.sum(np.stack([ array[cell.GetPointId(i),:] * w for i, w in enumerate(wgt) ]), 0)
    return result


# Given a set of sampling locations on a triangle mesh surface, generate arrays of
# vertex indices and weights that allow data from the source mesh to be sampled at
# the sampling locations. This can be used to interpolate point data, coordinates,
# etc from the source mesh or spatial transformations thereof 
def vtk_get_interpolation_arrays_for_sample(pd_src, x_samples):
    
    # Use the locator to sample from the halfway mesh
    loc = vtk.vtkCellLocator()
    loc.SetDataSet(pd_src)
    loc.BuildLocator()

    # Return data: array of vertex indices and weights
    v_res = np.zeros((x_samples.shape[0], 3), dtype=np.int32)
    w_res = np.zeros((x_samples.shape[0], 3), dtype=np.double)

    cellId = vtk.reference(0)
    c = [0.0, 0.0, 0.0]
    subId = vtk.reference(0)
    d = vtk.reference(0.0)
    pcoord = [0.0, 0.0, 0.0]
    wgt = [0.0, 0.0, 0.0]
    xj = [0.0, 0.0, 0.0]
    for j in range(x_samples.shape[0]):
        loc.FindClosestPoint(x_samples[j,:], c, cellId, subId, d)
        cell = pd_src.GetCell(cellId)
        cell.EvaluatePosition(x_samples[j,:], c, subId, pcoord, d, wgt)
        for i, w in enumerate(wgt):
            v_res[j,i], w_res[j,i] = cell.GetPointId(i), w

    return v_res, w_res



# Define a function that can fit a model to a population
def fit_model_to_population_nojac(md_root, md_targets, n_iter = 10, 
                                  sigma_lddmm=5, sigma_root=20, sigma_varifold=5, gamma_lddmm=0.1):

    # LDDMM kernels
    device = md_root.vt.device
    K_root = GaussKernel(sigma=torch.tensor(sigma_root, dtype=torch.float32, device=device))
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))
    K_vari = GaussLinKernelWithLabels(torch.tensor(sigma_varifold, dtype=torch.float32, device=device), md_root.lp.shape[1])

    # Create losses for each of the target meshes
    d_loss = { id: lossVarifoldSurfWithLabels(md_root.ft, v.vt, v.ft, md_root.lpt, v.lpt, K_vari) for id,v in md_targets.items() }
            
    # Create the root->template points/momentum, as well as the template->subject momenta
    q_root = torch.tensor(md_root.vt, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_root = torch.zeros(md_root.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_temp = torch.zeros((len(md_targets),) + md_root.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()

    # Create the optimizer
    start = time.time()
    optimizer = torch.optim.LBFGS([p_root, p_temp], max_eval=16, max_iter=16, line_search_fn='strong_wolfe')

    def closure():
        optimizer.zero_grad()

        # Shoot root->template
        _, q_temp = Shooting(p_root, q_root, K_root)[-1]

        # Make the momenta applied to the template average out to zero
        p_temp_z = p_temp - torch.mean(p_temp, 0, keepdim=True)

        # Compute the loss
        L = 0
        for i, (id,v) in enumerate(md_targets.items()):
            _, q_i = Shooting(p_temp_z[i,:], q_temp, K_temp)[-1]
            L = L + gamma_lddmm * Hamiltonian(K_temp)(p_temp_z[i,:], q_temp) + d_loss[id](q_i)
        L = L / len(md_targets.items())
        L.backward()
        return L

    # Perform optimization
    for i in range(n_iter):
        print(f'Iteration {i:03d}  Loss {closure()}')
        optimizer.step(closure)

    print(f'Optimization (L-BFGS) time: {round(time.time() - start, 2)} seconds')

    # Return the root model and the momenta
    p_temp_z = p_temp - torch.mean(p_temp, 0, keepdim=True)
    return p_root, p_temp_z 


# Define a function that can fit a model to a population
def fit_model_to_population(md_root, md_targets, n_iter = 10, 
                            sigma_lddmm=5, sigma_root=20, sigma_varifold=5, 
                            gamma_lddmm=0.1, w_jacobian_penalty=1.0):

    # LDDMM kernels
    device = md_root.vt.device
    K_root = GaussKernel(sigma=torch.tensor(sigma_root, dtype=torch.float32, device=device))
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))
    K_vari = GaussLinKernelWithLabels(torch.tensor(sigma_varifold, dtype=torch.float32, device=device), md_root.lp.shape[1])

    # Create losses for each of the target meshes
    d_loss = { id: lossVarifoldSurfWithLabels(md_root.ft, v.vt, v.ft, md_root.lpt, v.lpt, K_vari) for id,v in md_targets.items() }
            
    # Create the root->template points/momentum, as well as the template->subject momenta
    q_root = torch.tensor(md_root.vt, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_root = torch.zeros(md_root.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_temp = torch.zeros((len(md_targets),) + md_root.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()

    # Create the optimizer
    start = time.time()
    optimizer = torch.optim.LBFGS([p_root, p_temp], max_eval=16, max_iter=16, line_search_fn='strong_wolfe')
    n_subj = len(md_targets.items())

    def closure(detail = False):
        optimizer.zero_grad()

        # Shoot root->template
        _, q_temp = Shooting(p_root, q_root, K_root)[-1]

        # Compute the triangle areas for the template
        z0 = q_temp[md_root.ft]
        area_0 = torch.norm(torch.cross(z0[:,1,:] - z0[:,0,:], z0[:,2,:] - z0[:,0,:]),dim=1) 

        # Make the momenta applied to the template average out to zero
        p_temp_z = p_temp - torch.mean(p_temp, 0, keepdim=True)

        # Compute the loss
        l_ham, l_data, l_jac = 0, 0, 0
        for i, (id,v) in enumerate(md_targets.items()):
            _, q_i = Shooting(p_temp_z[i,:], q_temp, K_temp)[-1]

            z = q_i[md_root.ft]
            area = torch.norm(torch.cross(z[:,1,:] - z[:,0,:], z[:,2,:] - z[:,0,:]),dim=1)
            log_jac = torch.log10(area / area_0)

            l_ham = l_ham + gamma_lddmm * Hamiltonian(K_temp)(p_temp_z[i,:], q_temp)
            l_data = l_data + d_loss[id](q_i)
            l_jac = l_jac + torch.sum(log_jac ** 2) * w_jacobian_penalty

        l_ham, l_data, l_jac = l_ham / n_subj, l_data / n_subj, l_jac / n_subj
        L = l_ham + l_data + l_jac
        L.backward()

        # Return loss or detail
        if detail:
            return l_ham, l_data, l_jac, L
        else:
            return L

    # Perform optimization
    for i in range(n_iter):
        l_ham, l_data, l_jac, L = closure(True)
        print(f'Iteration {i:03d}  Loss H={l_ham:6.2f}  D={l_data:6.2f}  J={l_jac:6.2f}  Total={L:6.2f}')
        optimizer.step(closure)

    print(f'Optimization (L-BFGS) time: {round(time.time() - start, 2)} seconds')

    # Return the root model and the momenta
    p_temp_z = p_temp - torch.mean(p_temp, 0, keepdim=True)
    return p_root, p_temp_z 


# Compute label probability sampling using shooting and OMT
# def map_array_to_fittedect_shooting_omt(q_root, p_root, p_temp, md_targets, array):
#     _, q_temp = Shooting(p_root, q_root, K)[-1]
#     plab_sample = []
#     p_temp_z = p_temp - torch.mean(p_temp, 0, keepdim=True)
#     for (id, md_i) in md_aff.items():
#         _, q_i = Shooting(p_temp_z[i,:], q_temp, K)[-1]
#         f_omt, w_omt = match_omt(q_i, md_src2.ft, md_i.vt, md_i.ft)
#         lp_omt = vtk_sample_cell_array_at_vertices(md_i.pd, md_i.lp, w_omt.detach().cpu().numpy())
#         plab_sample.append(lp_omt)


def shoot_root_to_template(md_root, p_root, sigma_root=20):
    device = md_root.vt.device
    K_root = GaussKernel(sigma=torch.tensor(sigma_root, dtype=torch.float32, device=device))
    _, q_temp = Shooting(p_root, md_root.vt.clone().requires_grad_(True).contiguous(), K_root)[-1]
    pd = vtk_make_pd(q_temp.detach().cpu().numpy(), md_root.f)
    pd = vtk_set_cell_array(pd, 'plab', md_root.lp)
    return MeshData(pd, device=q_temp.device)


def shoot_template_to_subject(md_temp, p, sigma_root=20):
    device = md_temp.vt.device
    K_root = GaussKernel(sigma=torch.tensor(sigma_root, dtype=torch.float32, device=device))
    _, q = Shooting(p, md_temp.vt.clone().requires_grad_(True).contiguous(), K_root)[-1]
    pd = vtk_make_pd(q.detach().cpu().numpy(), md_temp.f)
    pd = vtk_set_cell_array(pd, 'plab', md_temp.lp)
    return MeshData(pd, device=device)


# Update the template by remeshing and updating probability labels
def update_model_by_remeshing(md_root, md_targets, p_root, p_temp_z, 
                              sigma_lddmm=5, sigma_root=20):

    # LDDMM kernels
    device = md_root.vt.device
    K_root = GaussKernel(sigma=torch.tensor(sigma_root, dtype=torch.float32, device=device))
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))

    # Shoot from root to obtain the template
    q_root = md_root.vt.clone().requires_grad_(True).contiguous()
    _, q_temp = Shooting(p_root, q_root, K_root)[-1]
    pd_template = vtk_make_pd(q_temp.detach().cpu().numpy(), md_root.f)

    # Sample and average the plab array from the subjects using OMT
    plab_sample = []
    for i, (id, md_i) in enumerate(md_targets.items()):
        _, q_i = Shooting(p_temp_z[i,:], q_temp, K_temp)[-1]
        _, w_omt = match_omt(q_i, md_root.ft, md_i.vt, md_i.ft)
        lp_omt = vtk_sample_cell_array_at_vertices(md_i.pd, md_i.lp, w_omt.detach().cpu().numpy())
        plab_sample.append(lp_omt)
    plab_sample_avg = np.stack(plab_sample).mean(0)

    # Apply remeshing to the template
    ms = pymeshlab.MeshSet()
    ms.add_mesh(pymeshlab.Mesh(vertex_matrix=q_temp.detach().cpu().numpy(), face_matrix=md_root.f))
    ms.meshing_isotropic_explicit_remeshing()
    v_remesh, f_remesh = ms.mesh(0).vertex_matrix(), ms.mesh(0).face_matrix()
    pd_remesh = vtk_make_pd(v_remesh, f_remesh)

    # Apply the remeshing to the plab array
    _, w_omt = match_omt(torch.tensor(v_remesh, dtype=torch.float32, device=device), 
                         torch.tensor(f_remesh, dtype=torch.long, device=device),
                         q_temp, md_root.ft)
    lp_remesh = vtk_sample_cell_array_at_vertices(pd_template, plab_sample_avg, w_omt.detach().cpu().numpy())
    pd_remesh = vtk_set_cell_array(pd_remesh, 'plab', softmax(lp_remesh * 10, 1))

    # Return the new template as MeshData
    return MeshData(pd_remesh, device=md_root.vt.device)


# After OMT matching, we get a mapping from triangles to triangles. This code
# converts this into a vertex to vertex mapping, returning for every vertex in
# the fitted mesh a set of source vertices and their weights in the target mesh
def omt_match_to_vertex_weights(pd_fitted, pd_target, w_omt):
    pd_omt = vtk_clone_pd(pd_fitted)
    pd_omt = vtk_set_cell_array(pd_omt, 'match', w_omt)
    vtk_cell_array_to_point_array(pd_omt, 'match')
    v_omt = vtk_get_point_array(pd_omt, 'match')
    v_int, w_int = vtk_get_interpolation_arrays_for_sample(pd_target, v_omt)
    return v_omt, v_int, w_int


# Map template into subject space and return mesh
def map_template_to_subject(md_temp, md_target, p_temp, sigma_lddmm=5):

    # LDDMM kernels
    device = md_temp.vt.device
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))

    # Shoot from template to subject and save as polydata/meshdata
    q_temp = md_temp.vt.clone().requires_grad_(True).contiguous()
    _, q_fitted = Shooting(p_temp, q_temp, K_temp)[-1]
    pd_fitted = vtk_make_pd(q_fitted.detach().cpu().numpy(), md_temp.f)
    pd_fitted = vtk_set_cell_array(pd_fitted, 'plab', md_temp.lp)

    # Match the subject via OMT, i.e. every template vertex is mapped to somewhere on the
    # subject mesh, this fits more closely than LDDMM but might break topology
    # _, w_omt = match_omt(md_target.vt, md_target.ft, q_fitted, md_temp.ft)
    _, w_omt = match_omt(q_fitted, md_temp.ft, md_target.vt, md_target.ft)
    v_omt, v_int, w_int = omt_match_to_vertex_weights(pd_fitted, md_target.pd, w_omt.detach().cpu().numpy())

    # Create a clean model to return
    pd_omt = vtk_make_pd(v_omt, md_temp.f)
    pd_omt = vtk_set_cell_array(pd_omt, 'plab', md_temp.lp)
    pd_omt = vtk_set_cell_array(pd_omt, 'match', w_omt.detach().cpu().numpy())

    # Get the interpolation arrays from the matching and place them into the fitted template
    pd_fitted = vtk_set_point_array(pd_fitted, 'omt_v_int', v_int)
    pd_fitted = vtk_set_point_array(pd_fitted, 'omt_w_int', w_int)

    return pd_fitted, pd_omt

# %%
def build_template_multistage(md_root, md_targets, schedule, 
                              sigma_lddmm=5, sigma_root=20, sigma_varifold=5,
                              gamma_lddmm=0.1, w_jacobian_penalty=1.0):

    # Iterate over the schedule
    for i, iter in enumerate(schedule):

        # Print iteration
        print(f'*** TEMPLATE BUILD STAGE {i} ***')

        # Fit the model to the population
        p_root, p_temp_z = fit_model_to_population(md_root, md_targets, iter,
                                                   sigma_lddmm=sigma_lddmm, sigma_root=sigma_root, 
                                                   sigma_varifold=sigma_varifold, 
                                                   gamma_lddmm=gamma_lddmm,
                                                   w_jacobian_penalty=w_jacobian_penalty)

        # Compute the template by forward shooting
        md_temp = shoot_root_to_template(md_root, p_root, sigma_root=sigma_root)
        save_vtk(md_temp.pd, f'tmp/template_iter{i:02d}.vtk')

        # Remesh the template
        md_remesh = update_model_by_remeshing(md_root, md_targets, p_root, p_temp_z, sigma_lddmm=sigma_lddmm, sigma_root=sigma_root)
        save_vtk(md_remesh.pd, f'tmp/template_iter{i:02d}_remesh.vtk')

        # Make the template the new root
        md_root = md_remesh

    # Return the model from the last iteration
    return md_temp, p_temp_z

# %%
template['left'].get_lddmm_gamma()
# Out:
# 1.0

# %%
# Run the whole template building pipeline
# template['left'].get_varifold_sigma()
md_temp, p_temp = build_template_multistage(md_src2, md_aff, schedule=[10, 10, 10, 50], 
                                            sigma_root = 2.4 * template['left'].get_lddmm_sigma(), 
                                            sigma_lddmm = template['left'].get_lddmm_sigma(), 
                                            sigma_varifold = 5,
                                            gamma_lddmm=0.05, w_jacobian_penalty=10.0)
# Out:
# *** TEMPLATE BUILD STAGE 0 ***
# /tmp/ipykernel_476292/2540121521.py:123: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Iteration 000  Loss H=  0.00  D=97949.55  J=  0.00  Total=97949.55
# Iteration 001  Loss H=  0.35  D=61498.59  J=112.11  Total=61611.04
# Iteration 002  Loss H=  3.46  D=42560.18  J=1072.43  Total=43636.07
# Iteration 003  Loss H=  7.07  D=31487.99  J=1997.64  Total=33492.70
# Iteration 004  Loss H= 10.79  D=23870.60  J=2663.31  Total=26544.71
# Iteration 005  Loss H= 14.80  D=17575.81  J=3486.48  Total=21077.09
# Iteration 006  Loss H= 17.06  D=13633.41  J=3604.33  Total=17254.79
# Iteration 007  Loss H= 19.54  D=10460.05  J=3769.55  Total=14249.14
# Iteration 008  Loss H= 19.92  D=9520.86  J=3700.99  Total=13241.77
# Iteration 009  Loss H= 20.91  D=8462.33  J=3720.27  Total=12203.51
# Optimization (L-BFGS) time: 546.64 seconds
# 385x408 clusters, computed at scale = 3.584
# Successive scales :  78.208, 78.208, 62.566, 50.053, 40.042, 32.034, 25.627, 20.502, 16.401, 13.121, 10.497, 8.397, 6.718, 5.374, 4.300, 3.440, 2.752, 2.201, 1.761, 1.409, 1.127, 0.902, 0.721, 0.577, 0.462, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.300) and 15 (σ=3.440).
# Keep 55128/157080 = 35.1% of the coarse cost matrix.
# Keep 52051/148225 = 35.1% of the coarse cost matrix.
# Keep 58446/166464 = 35.1% of the coarse cost matrix.
# OMT matching distance: 0.2747807502746582, time elapsed: 4.376020908355713
# 463x496 clusters, computed at scale = 3.279
# Successive scales :  71.553, 71.553, 57.242, 45.794, 36.635, 29.308, 23.446, 18.757, 15.006, 12.005, 9.604, 7.683, 6.146, 4.917, 3.934, 3.147, 2.518, 2.014, 1.611, 1.289, 1.031, 0.825, 0.660, 0.528, 0.422, 0.338, 0.270, 0.216, 0.173, 0.138, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.934) and 15 (σ=3.147).
# Keep 76898/229648 = 33.5% of the coarse cost matrix.
# Keep 71633/214369 = 33.4% of the coarse cost matrix.
# Keep 82732/246016 = 33.6% of the coarse cost matrix.
# OMT matching distance: 0.17115336656570435, time elapsed: 4.480077266693115
# 391x427 clusters, computed at scale = 3.612
# Successive scales :  78.833, 78.833, 63.067, 50.453, 40.363, 32.290, 25.832, 20.666, 16.533, 13.226, 10.581, 8.465, 6.772, 5.417, 4.334, 3.467, 2.774, 2.219, 1.775, 1.420, 1.136, 0.909, 0.727, 0.582, 0.465, 0.372, 0.298, 0.238, 0.191, 0.152, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.334) and 15 (σ=3.467).
# Keep 60150/166957 = 36.0% of the coarse cost matrix.
# Keep 55335/152881 = 36.2% of the coarse cost matrix.
# Keep 65277/182329 = 35.8% of the coarse cost matrix.
# OMT matching distance: 0.23536549508571625, time elapsed: 4.568892955780029
# 359x366 clusters, computed at scale = 3.538
# Successive scales :  77.216, 77.216, 61.773, 49.418, 39.535, 31.628, 25.302, 20.242, 16.193, 12.955, 10.364, 8.291, 6.633, 5.306, 4.245, 3.396, 2.717, 2.173, 1.739, 1.391, 1.113, 0.890, 0.712, 0.570, 0.456, 0.365, 0.292, 0.233, 0.187, 0.149, 0.119, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.245) and 15 (σ=3.396).
# Keep 46511/131394 = 35.4% of the coarse cost matrix.
# Keep 45297/128881 = 35.1% of the coarse cost matrix.
# Keep 47806/133956 = 35.7% of the coarse cost matrix.
# OMT matching distance: 0.1534683108329773, time elapsed: 3.3431901931762695
# 473x478 clusters, computed at scale = 3.164
# Successive scales :  69.042, 69.042, 55.234, 44.187, 35.349, 28.280, 22.624, 18.099, 14.479, 11.583, 9.267, 7.413, 5.931, 4.745, 3.796, 3.036, 2.429, 1.943, 1.555, 1.244, 0.995, 0.796, 0.637, 0.509, 0.408, 0.326, 0.261, 0.209, 0.167, 0.134, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=3.796) and 15 (σ=3.036).
# Keep 73670/226094 = 32.6% of the coarse cost matrix.
# Keep 73407/223729 = 32.8% of the coarse cost matrix.
# Keep 73624/228484 = 32.2% of the coarse cost matrix.
# OMT matching distance: 0.7298189401626587, time elapsed: 4.516505002975464
# 376x412 clusters, computed at scale = 3.754
# Successive scales :  81.912, 81.912, 65.530, 52.424, 41.939, 33.551, 26.841, 21.473, 17.178, 13.743, 10.994, 8.795, 7.036, 5.629, 4.503, 3.603, 2.882, 2.306, 1.844, 1.476, 1.180, 0.944, 0.756, 0.604, 0.484, 0.387, 0.309, 0.248, 0.198, 0.158, 0.127, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.503) and 15 (σ=3.603).
# Keep 55341/154912 = 35.7% of the coarse cost matrix.
# Keep 50758/141376 = 35.9% of the coarse cost matrix.
# Keep 60052/169744 = 35.4% of the coarse cost matrix.
# OMT matching distance: 0.6503399610519409, time elapsed: 4.228398561477661
# 408x423 clusters, computed at scale = 3.597
# Successive scales :  78.485, 78.485, 62.788, 50.231, 40.184, 32.148, 25.718, 20.574, 16.460, 13.168, 10.534, 8.427, 6.742, 5.393, 4.315, 3.452, 2.761, 2.209, 1.767, 1.414, 1.131, 0.905, 0.724, 0.579, 0.463, 0.371, 0.297, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.315) and 15 (σ=3.452).
# Keep 62593/172584 = 36.3% of the coarse cost matrix.
# Keep 60488/166464 = 36.3% of the coarse cost matrix.
# Keep 64621/178929 = 36.1% of the coarse cost matrix.
# OMT matching distance: 0.24502559006214142, time elapsed: 4.358019113540649
# 390x406 clusters, computed at scale = 3.543
# Successive scales :  77.318, 77.318, 61.854, 49.483, 39.587, 31.669, 25.335, 20.268, 16.215, 12.972, 10.377, 8.302, 6.642, 5.313, 4.251, 3.400, 2.720, 2.176, 1.741, 1.393, 1.114, 0.891, 0.713, 0.571, 0.456, 0.365, 0.292, 0.234, 0.187, 0.150, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.251) and 15 (σ=3.400).
# Keep 57139/158340 = 36.1% of the coarse cost matrix.
# Keep 55132/152100 = 36.2% of the coarse cost matrix.
# Keep 59056/164836 = 35.8% of the coarse cost matrix.
# OMT matching distance: 0.20911087095737457, time elapsed: 3.8300790786743164
# 385x426 clusters, computed at scale = 3.564
# Successive scales :  77.775, 77.775, 62.220, 49.776, 39.821, 31.856, 25.485, 20.388, 16.311, 13.048, 10.439, 8.351, 6.681, 5.345, 4.276, 3.421, 2.736, 2.189, 1.751, 1.401, 1.121, 0.897, 0.717, 0.574, 0.459, 0.367, 0.294, 0.235, 0.188, 0.150, 0.120, 0.096, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.276) and 15 (σ=3.421).
# Keep 62440/164010 = 38.1% of the coarse cost matrix.
# Keep 57249/148225 = 38.6% of the coarse cost matrix.
# Keep 67944/181476 = 37.4% of the coarse cost matrix.
# OMT matching distance: 0.3043983578681946, time elapsed: 4.335770130157471
# 391x424 clusters, computed at scale = 3.522
# Successive scales :  76.864, 76.864, 61.491, 49.193, 39.354, 31.483, 25.187, 20.149, 16.120, 12.896, 10.316, 8.253, 6.603, 5.282, 4.226, 3.381, 2.704, 2.164, 1.731, 1.385, 1.108, 0.886, 0.709, 0.567, 0.454, 0.363, 0.290, 0.232, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.226) and 15 (σ=3.381).
# Keep 58941/165784 = 35.6% of the coarse cost matrix.
# Keep 54627/152881 = 35.7% of the coarse cost matrix.
# Keep 63310/179776 = 35.2% of the coarse cost matrix.
# OMT matching distance: 0.6456587314605713, time elapsed: 3.839313268661499
# 403x425 clusters, computed at scale = 3.283
# Successive scales :  71.633, 71.633, 57.307, 45.845, 36.676, 29.341, 23.473, 18.778, 15.023, 12.018, 9.614, 7.692, 6.153, 4.923, 3.938, 3.150, 2.520, 2.016, 1.613, 1.290, 1.032, 0.826, 0.661, 0.529, 0.423, 0.338, 0.271, 0.216, 0.173, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.938) and 15 (σ=3.150).
# Keep 58123/171275 = 33.9% of the coarse cost matrix.
# Keep 54931/162409 = 33.8% of the coarse cost matrix.
# Keep 61527/180625 = 34.1% of the coarse cost matrix.
# OMT matching distance: 0.27104413509368896, time elapsed: 3.8065342903137207
# 377x415 clusters, computed at scale = 3.663
# Successive scales :  79.933, 79.933, 63.946, 51.157, 40.926, 32.741, 26.192, 20.954, 16.763, 13.411, 10.728, 8.583, 6.866, 5.493, 4.394, 3.515, 2.812, 2.250, 1.800, 1.440, 1.152, 0.922, 0.737, 0.590, 0.472, 0.377, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.394) and 15 (σ=3.515).
# Keep 54468/156455 = 34.8% of the coarse cost matrix.
# Keep 50207/142129 = 35.3% of the coarse cost matrix.
# Keep 59083/172225 = 34.3% of the coarse cost matrix.
# OMT matching distance: 0.7420831918716431, time elapsed: 4.794235944747925
# 370x380 clusters, computed at scale = 3.517
# Successive scales :  76.760, 76.760, 61.408, 49.126, 39.301, 31.441, 25.153, 20.122, 16.098, 12.878, 10.303, 8.242, 6.594, 5.275, 4.220, 3.376, 2.701, 2.161, 1.728, 1.383, 1.106, 0.885, 0.708, 0.566, 0.453, 0.362, 0.290, 0.232, 0.186, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.220) and 15 (σ=3.376).
# Keep 49416/140600 = 35.1% of the coarse cost matrix.
# Keep 48198/136900 = 35.2% of the coarse cost matrix.
# Keep 50724/144400 = 35.1% of the coarse cost matrix.
# OMT matching distance: 0.14178596436977386, time elapsed: 3.599144458770752
# 377x374 clusters, computed at scale = 3.260
# Successive scales :  71.144, 71.144, 56.915, 45.532, 36.426, 29.141, 23.312, 18.650, 14.920, 11.936, 9.549, 7.639, 6.111, 4.889, 3.911, 3.129, 2.503, 2.003, 1.602, 1.282, 1.025, 0.820, 0.656, 0.525, 0.420, 0.336, 0.269, 0.215, 0.172, 0.138, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=3.911) and 15 (σ=3.129).
# Keep 47603/140998 = 33.8% of the coarse cost matrix.
# Keep 48163/142129 = 33.9% of the coarse cost matrix.
# Keep 47072/139876 = 33.7% of the coarse cost matrix.
# OMT matching distance: 0.025286901742219925, time elapsed: 3.635246753692627
# *** TEMPLATE BUILD STAGE 1 ***
# Iteration 000  Loss H=  0.00  D=66367.56  J=  0.00  Total=66367.56
# Iteration 001  Loss H=  0.68  D=48381.83  J=239.12  Total=48621.63
# Iteration 002  Loss H=  4.42  D=32455.24  J=1444.55  Total=33904.20
# Iteration 003  Loss H=  8.46  D=22357.64  J=2511.45  Total=24877.56
# Iteration 004  Loss H= 11.19  D=15985.83  J=2989.25  Total=18986.27
# Iteration 005  Loss H= 13.58  D=11895.56  J=3288.88  Total=15198.02
# Iteration 006  Loss H= 15.59  D=9381.94  J=3319.92  Total=12717.45
# Iteration 007  Loss H= 17.31  D=7812.86  J=3338.53  Total=11168.71
# Iteration 008  Loss H= 17.96  D=7239.45  J=3274.01  Total=10531.42
# Iteration 009  Loss H= 19.33  D=6597.15  J=3292.52  Total=9909.00
# Optimization (L-BFGS) time: 569.41 seconds
# 381x410 clusters, computed at scale = 3.581
# Successive scales :  78.142, 78.142, 62.514, 50.011, 40.009, 32.007, 25.606, 20.484, 16.388, 13.110, 10.488, 8.390, 6.712, 5.370, 4.296, 3.437, 2.749, 2.200, 1.760, 1.408, 1.126, 0.901, 0.721, 0.577, 0.461, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.296) and 15 (σ=3.437).
# Keep 55379/156210 = 35.5% of the coarse cost matrix.
# Keep 51891/145161 = 35.7% of the coarse cost matrix.
# Keep 58880/168100 = 35.0% of the coarse cost matrix.
# OMT matching distance: 0.21627232432365417, time elapsed: 3.895822286605835
# 460x495 clusters, computed at scale = 3.287
# Successive scales :  71.728, 71.728, 57.383, 45.906, 36.725, 29.380, 23.504, 18.803, 15.043, 12.034, 9.627, 7.702, 6.161, 4.929, 3.943, 3.155, 2.524, 2.019, 1.615, 1.292, 1.034, 0.827, 0.662, 0.529, 0.423, 0.339, 0.271, 0.217, 0.173, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.943) and 15 (σ=3.155).
# Keep 76350/227700 = 33.5% of the coarse cost matrix.
# Keep 70752/211600 = 33.4% of the coarse cost matrix.
# Keep 82399/245025 = 33.6% of the coarse cost matrix.
# OMT matching distance: 0.1839119791984558, time elapsed: 4.773916959762573
# 387x423 clusters, computed at scale = 3.620
# Successive scales :  78.994, 78.994, 63.195, 50.556, 40.445, 32.356, 25.885, 20.708, 16.566, 13.253, 10.602, 8.482, 6.786, 5.428, 4.343, 3.474, 2.779, 2.223, 1.779, 1.423, 1.138, 0.911, 0.729, 0.583, 0.466, 0.373, 0.298, 0.239, 0.191, 0.153, 0.122, 0.098, 0.078, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=4.343) and 15 (σ=3.474).
# Keep 59447/163701 = 36.3% of the coarse cost matrix.
# Keep 55055/149769 = 36.8% of the coarse cost matrix.
# Keep 64195/178929 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.2137090563774109, time elapsed: 4.5478010177612305
# 364x364 clusters, computed at scale = 3.546
# Successive scales :  77.374, 77.374, 61.899, 49.519, 39.615, 31.692, 25.354, 20.283, 16.226, 12.981, 10.385, 8.308, 6.646, 5.317, 4.254, 3.403, 2.722, 2.178, 1.742, 1.394, 1.115, 0.892, 0.714, 0.571, 0.457, 0.365, 0.292, 0.234, 0.187, 0.150, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.254) and 15 (σ=3.403).
# Keep 47033/132496 = 35.5% of the coarse cost matrix.
# Keep 46696/132496 = 35.2% of the coarse cost matrix.
# Keep 47368/132496 = 35.8% of the coarse cost matrix.
# OMT matching distance: 0.12482944130897522, time elapsed: 3.6854770183563232
# 462x471 clusters, computed at scale = 3.187
# Successive scales :  69.548, 69.548, 55.638, 44.511, 35.608, 28.487, 22.789, 18.232, 14.585, 11.668, 9.335, 7.468, 5.974, 4.779, 3.823, 3.059, 2.447, 1.958, 1.566, 1.253, 1.002, 0.802, 0.641, 0.513, 0.411, 0.328, 0.263, 0.210, 0.168, 0.135, 0.108, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=3.823) and 15 (σ=3.059).
# Keep 71520/217602 = 32.9% of the coarse cost matrix.
# Keep 70264/213444 = 32.9% of the coarse cost matrix.
# Keep 72651/221841 = 32.7% of the coarse cost matrix.
# OMT matching distance: 0.7232226133346558, time elapsed: 4.74339747428894
# 377x411 clusters, computed at scale = 3.759
# Successive scales :  82.025, 82.025, 65.620, 52.496, 41.997, 33.597, 26.878, 21.502, 17.202, 13.761, 11.009, 8.807, 7.046, 5.637, 4.509, 3.607, 2.886, 2.309, 1.847, 1.478, 1.182, 0.946, 0.757, 0.605, 0.484, 0.387, 0.310, 0.248, 0.198, 0.159, 0.127, 0.102, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.509) and 15 (σ=3.607).
# Keep 55400/154947 = 35.8% of the coarse cost matrix.
# Keep 51351/142129 = 36.1% of the coarse cost matrix.
# Keep 59693/168921 = 35.3% of the coarse cost matrix.
# OMT matching distance: 0.5963464975357056, time elapsed: 4.321792364120483
# 392x423 clusters, computed at scale = 3.597
# Successive scales :  78.487, 78.487, 62.790, 50.232, 40.185, 32.148, 25.719, 20.575, 16.460, 13.168, 10.534, 8.427, 6.742, 5.394, 4.315, 3.452, 2.762, 2.209, 1.767, 1.414, 1.131, 0.905, 0.724, 0.579, 0.463, 0.371, 0.297, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.315) and 15 (σ=3.452).
# Keep 60291/165816 = 36.4% of the coarse cost matrix.
# Keep 56234/153664 = 36.6% of the coarse cost matrix.
# Keep 64619/178929 = 36.1% of the coarse cost matrix.
# OMT matching distance: 0.13780325651168823, time elapsed: 4.145305633544922
# 382x407 clusters, computed at scale = 3.540
# Successive scales :  77.241, 77.241, 61.793, 49.435, 39.548, 31.638, 25.310, 20.248, 16.199, 12.959, 10.367, 8.294, 6.635, 5.308, 4.246, 3.397, 2.718, 2.174, 1.739, 1.391, 1.113, 0.891, 0.712, 0.570, 0.456, 0.365, 0.292, 0.233, 0.187, 0.149, 0.120, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.246) and 15 (σ=3.397).
# Keep 56182/155474 = 36.1% of the coarse cost matrix.
# Keep 53002/145924 = 36.3% of the coarse cost matrix.
# Keep 59535/165649 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.13433997333049774, time elapsed: 4.161818027496338
# 384x422 clusters, computed at scale = 3.572
# Successive scales :  77.959, 77.959, 62.367, 49.894, 39.915, 31.932, 25.546, 20.437, 16.349, 13.079, 10.463, 8.371, 6.697, 5.357, 4.286, 3.429, 2.743, 2.194, 1.755, 1.404, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.188, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.286) and 15 (σ=3.429).
# Keep 62123/162048 = 38.3% of the coarse cost matrix.
# Keep 57564/147456 = 39.0% of the coarse cost matrix.
# Keep 66926/178084 = 37.6% of the coarse cost matrix.
# OMT matching distance: 0.12920360267162323, time elapsed: 4.183849811553955
# 382x424 clusters, computed at scale = 3.523
# Successive scales :  76.888, 76.888, 61.510, 49.208, 39.366, 31.493, 25.195, 20.156, 16.125, 12.900, 10.320, 8.256, 6.605, 5.284, 4.227, 3.382, 2.705, 2.164, 1.731, 1.385, 1.108, 0.886, 0.709, 0.567, 0.454, 0.363, 0.290, 0.232, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.227) and 15 (σ=3.382).
# Keep 57849/161968 = 35.7% of the coarse cost matrix.
# Keep 52700/145924 = 36.1% of the coarse cost matrix.
# Keep 63328/179776 = 35.2% of the coarse cost matrix.
# OMT matching distance: 0.8668764233589172, time elapsed: 4.3040971755981445
# 403x422 clusters, computed at scale = 3.299
# Successive scales :  72.000, 72.000, 57.600, 46.080, 36.864, 29.491, 23.593, 18.874, 15.100, 12.080, 9.664, 7.731, 6.185, 4.948, 3.958, 3.167, 2.533, 2.027, 1.621, 1.297, 1.038, 0.830, 0.664, 0.531, 0.425, 0.340, 0.272, 0.218, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.958) and 15 (σ=3.167).
# Keep 57318/170066 = 33.7% of the coarse cost matrix.
# Keep 54291/162409 = 33.4% of the coarse cost matrix.
# Keep 60600/178084 = 34.0% of the coarse cost matrix.
# OMT matching distance: 0.29511913657188416, time elapsed: 4.26617956161499
# 369x415 clusters, computed at scale = 3.663
# Successive scales :  79.933, 79.933, 63.946, 51.157, 40.926, 32.741, 26.192, 20.954, 16.763, 13.411, 10.728, 8.583, 6.866, 5.493, 4.394, 3.515, 2.812, 2.250, 1.800, 1.440, 1.152, 0.922, 0.737, 0.590, 0.472, 0.377, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.394) and 15 (σ=3.515).
# Keep 53380/153135 = 34.9% of the coarse cost matrix.
# Keep 48131/136161 = 35.3% of the coarse cost matrix.
# Keep 59083/172225 = 34.3% of the coarse cost matrix.
# OMT matching distance: 0.7267318367958069, time elapsed: 4.69574236869812
# 371x386 clusters, computed at scale = 3.507
# Successive scales :  76.534, 76.534, 61.227, 48.982, 39.185, 31.348, 25.079, 20.063, 16.050, 12.840, 10.272, 8.218, 6.574, 5.259, 4.208, 3.366, 2.693, 2.154, 1.723, 1.379, 1.103, 0.882, 0.706, 0.565, 0.452, 0.361, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.208) and 15 (σ=3.366).
# Keep 50353/143206 = 35.2% of the coarse cost matrix.
# Keep 48771/137641 = 35.4% of the coarse cost matrix.
# Keep 52006/148996 = 34.9% of the coarse cost matrix.
# OMT matching distance: 0.20057137310504913, time elapsed: 3.740617036819458
# 372x372 clusters, computed at scale = 3.314
# Successive scales :  72.320, 72.320, 57.856, 46.285, 37.028, 29.622, 23.698, 18.958, 15.167, 12.133, 9.707, 7.765, 6.212, 4.970, 3.976, 3.181, 2.545, 2.036, 1.629, 1.303, 1.042, 0.834, 0.667, 0.534, 0.427, 0.342, 0.273, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.976) and 15 (σ=3.181).
# Keep 47698/138384 = 34.5% of the coarse cost matrix.
# Keep 47782/138384 = 34.5% of the coarse cost matrix.
# Keep 47642/138384 = 34.4% of the coarse cost matrix.
# OMT matching distance: 0.015226513147354126, time elapsed: 3.595529794692993
# *** TEMPLATE BUILD STAGE 2 ***
# Iteration 000  Loss H=  0.00  D=61485.96  J=  0.00  Total=61485.96
# Iteration 001  Loss H=  1.20  D=42185.18  J=436.02  Total=42622.39
# Iteration 002  Loss H=  4.81  D=27726.39  J=1589.31  Total=29320.51
# Iteration 003  Loss H=  8.80  D=18407.90  J=2611.07  Total=21027.77
# Iteration 004  Loss H= 11.24  D=13528.89  J=3018.98  Total=16559.12
# Iteration 005  Loss H= 13.63  D=10100.69  J=3221.89  Total=13336.21
# Iteration 006  Loss H= 15.56  D=8176.15  J=3193.47  Total=11385.18
# Iteration 007  Loss H= 17.33  D=6993.86  J=3204.50  Total=10215.68
# Iteration 008  Loss H= 17.99  D=6548.61  J=3151.28  Total=9717.89
# Iteration 009  Loss H= 18.90  D=6145.88  J=3137.60  Total=9302.37
# Optimization (L-BFGS) time: 562.82 seconds
# 384x410 clusters, computed at scale = 3.577
# Successive scales :  78.053, 78.053, 62.442, 49.954, 39.963, 31.970, 25.576, 20.461, 16.369, 13.095, 10.476, 8.381, 6.705, 5.364, 4.291, 3.433, 2.746, 2.197, 1.758, 1.406, 1.125, 0.900, 0.720, 0.576, 0.461, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.291) and 15 (σ=3.433).
# Keep 55638/157440 = 35.3% of the coarse cost matrix.
# Keep 52366/147456 = 35.5% of the coarse cost matrix.
# Keep 58942/168100 = 35.1% of the coarse cost matrix.
# OMT matching distance: 0.20767426490783691, time elapsed: 3.9399240016937256
# 466x494 clusters, computed at scale = 3.290
# Successive scales :  71.797, 71.797, 57.438, 45.950, 36.760, 29.408, 23.526, 18.821, 15.057, 12.046, 9.636, 7.709, 6.167, 4.934, 3.947, 3.158, 2.526, 2.021, 1.617, 1.293, 1.035, 0.828, 0.662, 0.530, 0.424, 0.339, 0.271, 0.217, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.947) and 15 (σ=3.158).
# Keep 77373/230204 = 33.6% of the coarse cost matrix.
# Keep 72886/217156 = 33.6% of the coarse cost matrix.
# Keep 82128/244036 = 33.7% of the coarse cost matrix.
# OMT matching distance: 0.1596282422542572, time elapsed: 4.8291239738464355
# 381x421 clusters, computed at scale = 3.622
# Successive scales :  79.032, 79.032, 63.226, 50.580, 40.464, 32.372, 25.897, 20.718, 16.574, 13.259, 10.607, 8.486, 6.789, 5.431, 4.345, 3.476, 2.781, 2.225, 1.780, 1.424, 1.139, 0.911, 0.729, 0.583, 0.467, 0.373, 0.299, 0.239, 0.191, 0.153, 0.122, 0.098, 0.078, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=4.345) and 15 (σ=3.476).
# Keep 58348/160401 = 36.4% of the coarse cost matrix.
# Keep 53419/145161 = 36.8% of the coarse cost matrix.
# Keep 63723/177241 = 36.0% of the coarse cost matrix.
# OMT matching distance: 0.19272539019584656, time elapsed: 4.428385257720947
# 359x363 clusters, computed at scale = 3.549
# Successive scales :  77.438, 77.438, 61.950, 49.560, 39.648, 31.718, 25.375, 20.300, 16.240, 12.992, 10.394, 8.315, 6.652, 5.321, 4.257, 3.406, 2.725, 2.180, 1.744, 1.395, 1.116, 0.893, 0.714, 0.571, 0.457, 0.366, 0.293, 0.234, 0.187, 0.150, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.257) and 15 (σ=3.406).
# Keep 46385/130317 = 35.6% of the coarse cost matrix.
# Keep 45649/128881 = 35.4% of the coarse cost matrix.
# Keep 47147/131769 = 35.8% of the coarse cost matrix.
# OMT matching distance: 0.1392275094985962, time elapsed: 3.7969424724578857
# 459x467 clusters, computed at scale = 3.182
# Successive scales :  69.433, 69.433, 55.546, 44.437, 35.550, 28.440, 22.752, 18.201, 14.561, 11.649, 9.319, 7.455, 5.964, 4.771, 3.817, 3.054, 2.443, 1.954, 1.563, 1.251, 1.001, 0.801, 0.640, 0.512, 0.410, 0.328, 0.262, 0.210, 0.168, 0.134, 0.107, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=3.817) and 15 (σ=3.054).
# Keep 70493/214353 = 32.9% of the coarse cost matrix.
# Keep 69259/210681 = 32.9% of the coarse cost matrix.
# Keep 71349/218089 = 32.7% of the coarse cost matrix.
# OMT matching distance: 0.9053656458854675, time elapsed: 4.5697691440582275
# 381x411 clusters, computed at scale = 3.757
# Successive scales :  81.994, 81.994, 65.595, 52.476, 41.981, 33.585, 26.868, 21.494, 17.195, 13.756, 11.005, 8.804, 7.043, 5.635, 4.508, 3.606, 2.885, 2.308, 1.846, 1.477, 1.182, 0.945, 0.756, 0.605, 0.484, 0.387, 0.310, 0.248, 0.198, 0.159, 0.127, 0.102, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.508) and 15 (σ=3.606).
# Keep 56299/156591 = 36.0% of the coarse cost matrix.
# Keep 52933/145161 = 36.5% of the coarse cost matrix.
# Keep 59675/168921 = 35.3% of the coarse cost matrix.
# OMT matching distance: 0.669414222240448, time elapsed: 4.505991697311401
# 390x420 clusters, computed at scale = 3.601
# Successive scales :  78.574, 78.574, 62.859, 50.287, 40.230, 32.184, 25.747, 20.598, 16.478, 13.182, 10.546, 8.437, 6.749, 5.400, 4.320, 3.456, 2.765, 2.212, 1.769, 1.415, 1.132, 0.906, 0.725, 0.580, 0.464, 0.371, 0.297, 0.237, 0.190, 0.152, 0.122, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.320) and 15 (σ=3.456).
# Keep 59709/163800 = 36.5% of the coarse cost matrix.
# Keep 55648/152100 = 36.6% of the coarse cost matrix.
# Keep 63960/176400 = 36.3% of the coarse cost matrix.
# OMT matching distance: 0.18192552030086517, time elapsed: 4.00234580039978
# 382x407 clusters, computed at scale = 3.540
# Successive scales :  77.260, 77.260, 61.808, 49.447, 39.557, 31.646, 25.317, 20.253, 16.203, 12.962, 10.370, 8.296, 6.637, 5.309, 4.247, 3.398, 2.718, 2.175, 1.740, 1.392, 1.113, 0.891, 0.713, 0.570, 0.456, 0.365, 0.292, 0.234, 0.187, 0.149, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.247) and 15 (σ=3.398).
# Keep 55990/155474 = 36.0% of the coarse cost matrix.
# Keep 52604/145924 = 36.0% of the coarse cost matrix.
# Keep 59529/165649 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.16636638343334198, time elapsed: 4.22963285446167
# 390x422 clusters, computed at scale = 3.573
# Successive scales :  77.968, 77.968, 62.374, 49.899, 39.920, 31.936, 25.549, 20.439, 16.351, 13.081, 10.465, 8.372, 6.697, 5.358, 4.286, 3.429, 2.743, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.286) and 15 (σ=3.429).
# Keep 62979/164580 = 38.3% of the coarse cost matrix.
# Keep 59292/152100 = 39.0% of the coarse cost matrix.
# Keep 66932/178084 = 37.6% of the coarse cost matrix.
# OMT matching distance: 0.14178018271923065, time elapsed: 4.190110445022583
# 378x420 clusters, computed at scale = 3.530
# Successive scales :  77.029, 77.029, 61.624, 49.299, 39.439, 31.551, 25.241, 20.193, 16.154, 12.923, 10.339, 8.271, 6.617, 5.293, 4.235, 3.388, 2.710, 2.168, 1.735, 1.388, 1.110, 0.888, 0.710, 0.568, 0.455, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.235) and 15 (σ=3.388).
# Keep 56643/158760 = 35.7% of the coarse cost matrix.
# Keep 51414/142884 = 36.0% of the coarse cost matrix.
# Keep 62160/176400 = 35.2% of the coarse cost matrix.
# OMT matching distance: 0.8613041639328003, time elapsed: 4.082319259643555
# 406x423 clusters, computed at scale = 3.316
# Successive scales :  72.361, 72.361, 57.889, 46.311, 37.049, 29.639, 23.711, 18.969, 15.175, 12.140, 9.712, 7.770, 6.216, 4.973, 3.978, 3.182, 2.546, 2.037, 1.629, 1.304, 1.043, 0.834, 0.667, 0.534, 0.427, 0.342, 0.273, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.978) and 15 (σ=3.182).
# Keep 58269/171738 = 33.9% of the coarse cost matrix.
# Keep 55590/164836 = 33.7% of the coarse cost matrix.
# Keep 61041/178929 = 34.1% of the coarse cost matrix.
# OMT matching distance: 0.2656152546405792, time elapsed: 4.116966485977173
# 384x413 clusters, computed at scale = 3.664
# Successive scales :  79.950, 79.950, 63.960, 51.168, 40.934, 32.748, 26.198, 20.958, 16.767, 13.413, 10.731, 8.585, 6.868, 5.494, 4.395, 3.516, 2.813, 2.250, 1.800, 1.440, 1.152, 0.922, 0.737, 0.590, 0.472, 0.378, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.395) and 15 (σ=3.516).
# Keep 55378/158592 = 34.9% of the coarse cost matrix.
# Keep 52374/147456 = 35.5% of the coarse cost matrix.
# Keep 58581/170569 = 34.3% of the coarse cost matrix.
# OMT matching distance: 0.4832691550254822, time elapsed: 4.7482054233551025
# 379x382 clusters, computed at scale = 3.513
# Successive scales :  76.663, 76.663, 61.331, 49.065, 39.252, 31.401, 25.121, 20.097, 16.077, 12.862, 10.290, 8.232, 6.585, 5.268, 4.215, 3.372, 2.697, 2.158, 1.726, 1.381, 1.105, 0.884, 0.707, 0.566, 0.453, 0.362, 0.290, 0.232, 0.185, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.215) and 15 (σ=3.372).
# Keep 50907/144778 = 35.2% of the coarse cost matrix.
# Keep 50739/143641 = 35.3% of the coarse cost matrix.
# Keep 51068/145924 = 35.0% of the coarse cost matrix.
# OMT matching distance: 0.21478477120399475, time elapsed: 3.970883846282959
# 368x367 clusters, computed at scale = 3.328
# Successive scales :  72.636, 72.636, 58.109, 46.487, 37.190, 29.752, 23.801, 19.041, 15.233, 12.186, 9.749, 7.799, 6.239, 4.991, 3.993, 3.195, 2.556, 2.045, 1.636, 1.308, 1.047, 0.837, 0.670, 0.536, 0.429, 0.343, 0.274, 0.220, 0.176, 0.140, 0.112, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=3.993) and 15 (σ=3.195).
# Keep 46735/135056 = 34.6% of the coarse cost matrix.
# Keep 46986/135424 = 34.7% of the coarse cost matrix.
# Keep 46503/134689 = 34.5% of the coarse cost matrix.
# OMT matching distance: 0.01011357456445694, time elapsed: 3.548738956451416
# *** TEMPLATE BUILD STAGE 3 ***
# Iteration 000  Loss H=  0.00  D=59603.13  J=  0.00  Total=59603.13
# Iteration 001  Loss H=  1.17  D=40399.34  J=422.22  Total=40822.73
# Iteration 002  Loss H=  5.00  D=26258.82  J=1648.27  Total=27912.09
# Iteration 003  Loss H=  8.11  D=18655.20  J=2491.53  Total=21154.85
# Iteration 004  Loss H= 10.87  D=13230.51  J=2939.30  Total=16180.68
# Iteration 005  Loss H= 12.90  D=10248.07  J=3182.48  Total=13443.44
# Iteration 006  Loss H= 14.86  D=8221.43  J=3093.15  Total=11329.45
# Iteration 007  Loss H= 16.94  D=6885.07  J=3141.88  Total=10043.89
# Iteration 008  Loss H= 17.69  D=6442.37  J=3081.80  Total=9541.85
# Iteration 009  Loss H= 18.26  D=6103.49  J=3032.38  Total=9154.13
# Iteration 010  Loss H= 19.19  D=5674.95  J=3051.43  Total=8745.57
# Iteration 011  Loss H= 20.01  D=5356.06  J=3004.70  Total=8380.77
# Iteration 012  Loss H= 20.74  D=5054.03  J=2995.14  Total=8069.91
# Iteration 013  Loss H= 21.81  D=4726.69  J=2995.83  Total=7744.33
# Iteration 014  Loss H= 22.76  D=4460.66  J=2947.52  Total=7430.94
# Iteration 015  Loss H= 23.01  D=4350.34  J=2927.83  Total=7301.18
# Iteration 016  Loss H= 23.63  D=4167.39  J=2931.97  Total=7122.99
# Iteration 017  Loss H= 24.26  D=4001.03  J=2927.27  Total=6952.56
# Iteration 018  Loss H= 24.69  D=3846.43  J=2892.39  Total=6763.50
# Iteration 019  Loss H= 25.22  D=3698.50  J=2890.58  Total=6614.30
# Iteration 020  Loss H= 25.72  D=3571.28  J=2863.85  Total=6460.84
# Iteration 021  Loss H= 26.46  D=3430.18  J=2810.77  Total=6267.41
# Iteration 022  Loss H= 27.01  D=3311.30  J=2810.18  Total=6148.49
# Iteration 023  Loss H= 27.64  D=3217.60  J=2789.75  Total=6035.00
# Iteration 024  Loss H= 28.05  D=3136.91  J=2762.01  Total=5926.97
# Iteration 025  Loss H= 28.65  D=3039.44  J=2757.49  Total=5825.58
# Iteration 026  Loss H= 29.15  D=2941.76  J=2732.31  Total=5703.21
# Iteration 027  Loss H= 29.77  D=2843.36  J=2707.58  Total=5580.71
# Iteration 028  Loss H= 29.98  D=2796.37  J=2663.70  Total=5490.04
# Iteration 029  Loss H= 30.48  D=2716.39  J=2630.66  Total=5377.53
# Iteration 030  Loss H= 30.76  D=2688.00  J=2596.65  Total=5315.41
# Iteration 031  Loss H= 31.16  D=2630.33  J=2594.44  Total=5255.94
# Iteration 032  Loss H= 31.52  D=2590.82  J=2564.78  Total=5187.12
# Iteration 033  Loss H= 31.91  D=2545.04  J=2543.00  Total=5119.96
# Iteration 034  Loss H= 32.52  D=2487.27  J=2518.35  Total=5038.14
# Iteration 035  Loss H= 33.04  D=2443.49  J=2486.29  Total=4962.82
# Iteration 036  Loss H= 33.54  D=2402.80  J=2462.50  Total=4898.84
# Iteration 037  Loss H= 34.00  D=2367.22  J=2437.80  Total=4839.02
# Iteration 038  Loss H= 34.30  D=2338.99  J=2426.26  Total=4799.56
# Iteration 039  Loss H= 34.87  D=2295.68  J=2401.44  Total=4731.98
# Iteration 040  Loss H= 35.43  D=2250.84  J=2385.30  Total=4671.57
# Iteration 041  Loss H= 35.90  D=2212.06  J=2359.45  Total=4607.41
# Iteration 042  Loss H= 36.28  D=2182.80  J=2332.09  Total=4551.17
# Iteration 043  Loss H= 36.71  D=2146.90  J=2309.47  Total=4493.08
# Iteration 044  Loss H= 37.08  D=2117.74  J=2294.88  Total=4449.70
# Iteration 045  Loss H= 37.20  D=2108.74  J=2270.21  Total=4416.15
# Iteration 046  Loss H= 37.61  D=2084.12  J=2258.20  Total=4379.93
# Iteration 047  Loss H= 37.94  D=2060.10  J=2241.35  Total=4339.39
# Iteration 048  Loss H= 38.25  D=2043.72  J=2216.35  Total=4298.32
# Iteration 049  Loss H= 38.81  D=2016.54  J=2193.85  Total=4249.21
# Optimization (L-BFGS) time: 2784.78 seconds
# 385x410 clusters, computed at scale = 3.573
# Successive scales :  77.975, 77.975, 62.380, 49.904, 39.923, 31.939, 25.551, 20.441, 16.353, 13.082, 10.466, 8.373, 6.698, 5.358, 4.287, 3.429, 2.744, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.287) and 15 (σ=3.429).
# Keep 55103/157850 = 34.9% of the coarse cost matrix.
# Keep 51579/148225 = 34.8% of the coarse cost matrix.
# Keep 58802/168100 = 35.0% of the coarse cost matrix.
# OMT matching distance: 0.19189345836639404, time elapsed: 4.096075534820557
# 462x497 clusters, computed at scale = 3.277
# Successive scales :  71.518, 71.518, 57.215, 45.772, 36.617, 29.294, 23.435, 18.748, 14.999, 11.999, 9.599, 7.679, 6.143, 4.915, 3.932, 3.145, 2.516, 2.013, 1.610, 1.288, 1.031, 0.825, 0.660, 0.528, 0.422, 0.338, 0.270, 0.216, 0.173, 0.138, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.932) and 15 (σ=3.145).
# Keep 77309/229614 = 33.7% of the coarse cost matrix.
# Keep 71724/213444 = 33.6% of the coarse cost matrix.
# Keep 83147/247009 = 33.7% of the coarse cost matrix.
# OMT matching distance: 0.08306698501110077, time elapsed: 4.84003758430481
# 389x426 clusters, computed at scale = 3.612
# Successive scales :  78.817, 78.817, 63.053, 50.443, 40.354, 32.283, 25.827, 20.661, 16.529, 13.223, 10.579, 8.463, 6.770, 5.416, 4.333, 3.466, 2.773, 2.218, 1.775, 1.420, 1.136, 0.909, 0.727, 0.582, 0.465, 0.372, 0.298, 0.238, 0.191, 0.152, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.333) and 15 (σ=3.466).
# Keep 59778/165714 = 36.1% of the coarse cost matrix.
# Keep 54883/151321 = 36.3% of the coarse cost matrix.
# Keep 65134/181476 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.0905398577451706, time elapsed: 4.326081275939941
# 364x366 clusters, computed at scale = 3.535
# Successive scales :  77.133, 77.133, 61.706, 49.365, 39.492, 31.594, 25.275, 20.220, 16.176, 12.941, 10.353, 8.282, 6.626, 5.301, 4.240, 3.392, 2.714, 2.171, 1.737, 1.390, 1.112, 0.889, 0.711, 0.569, 0.455, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.240) and 15 (σ=3.392).
# Keep 47389/133224 = 35.6% of the coarse cost matrix.
# Keep 47066/132496 = 35.5% of the coarse cost matrix.
# Keep 47718/133956 = 35.6% of the coarse cost matrix.
# OMT matching distance: 0.09408099949359894, time elapsed: 3.805072784423828
# 463x471 clusters, computed at scale = 3.187
# Successive scales :  69.542, 69.542, 55.633, 44.507, 35.605, 28.484, 22.787, 18.230, 14.584, 11.667, 9.334, 7.467, 5.974, 4.779, 3.823, 3.058, 2.447, 1.957, 1.566, 1.253, 1.002, 0.802, 0.641, 0.513, 0.411, 0.328, 0.263, 0.210, 0.168, 0.135, 0.108, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=3.823) and 15 (σ=3.058).
# Keep 71452/218073 = 32.8% of the coarse cost matrix.
# Keep 69835/214369 = 32.6% of the coarse cost matrix.
# Keep 72645/221841 = 32.7% of the coarse cost matrix.
# OMT matching distance: 0.6525201797485352, time elapsed: 4.695016622543335
# 385x412 clusters, computed at scale = 3.753
# Successive scales :  81.906, 81.906, 65.525, 52.420, 41.936, 33.549, 26.839, 21.471, 17.177, 13.742, 10.993, 8.795, 7.036, 5.629, 4.503, 3.602, 2.882, 2.305, 1.844, 1.475, 1.180, 0.944, 0.755, 0.604, 0.483, 0.387, 0.309, 0.248, 0.198, 0.158, 0.127, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.503) and 15 (σ=3.602).
# Keep 56507/158620 = 35.6% of the coarse cost matrix.
# Keep 53117/148225 = 35.8% of the coarse cost matrix.
# Keep 60042/169744 = 35.4% of the coarse cost matrix.
# OMT matching distance: 0.12135935574769974, time elapsed: 5.755356788635254
# 405x423 clusters, computed at scale = 3.594
# Successive scales :  78.438, 78.438, 62.751, 50.200, 40.160, 32.128, 25.703, 20.562, 16.450, 13.160, 10.528, 8.422, 6.738, 5.390, 4.312, 3.450, 2.760, 2.208, 1.766, 1.413, 1.130, 0.904, 0.723, 0.579, 0.463, 0.370, 0.296, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.312) and 15 (σ=3.450).
# Keep 62201/171315 = 36.3% of the coarse cost matrix.
# Keep 59939/164025 = 36.5% of the coarse cost matrix.
# Keep 64517/178929 = 36.1% of the coarse cost matrix.
# OMT matching distance: 0.07716632634401321, time elapsed: 4.167932748794556
# 389x407 clusters, computed at scale = 3.539
# Successive scales :  77.238, 77.238, 61.791, 49.432, 39.546, 31.637, 25.309, 20.248, 16.198, 12.958, 10.367, 8.293, 6.635, 5.308, 4.246, 3.397, 2.718, 2.174, 1.739, 1.391, 1.113, 0.890, 0.712, 0.570, 0.456, 0.365, 0.292, 0.233, 0.187, 0.149, 0.120, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.246) and 15 (σ=3.397).
# Keep 57202/158323 = 36.1% of the coarse cost matrix.
# Keep 54905/151321 = 36.3% of the coarse cost matrix.
# Keep 59539/165649 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.14875710010528564, time elapsed: 4.010544776916504
# 388x423 clusters, computed at scale = 3.574
# Successive scales :  77.988, 77.988, 62.391, 49.913, 39.930, 31.944, 25.555, 20.444, 16.355, 13.084, 10.467, 8.374, 6.699, 5.359, 4.287, 3.430, 2.744, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.287) and 15 (σ=3.430).
# Keep 62598/164124 = 38.1% of the coarse cost matrix.
# Keep 58302/150544 = 38.7% of the coarse cost matrix.
# Keep 67315/178929 = 37.6% of the coarse cost matrix.
# OMT matching distance: 0.0818093866109848, time elapsed: 4.24782919883728
# 393x425 clusters, computed at scale = 3.509
# Successive scales :  76.583, 76.583, 61.266, 49.013, 39.210, 31.368, 25.095, 20.076, 16.061, 12.848, 10.279, 8.223, 6.578, 5.263, 4.210, 3.368, 2.695, 2.156, 1.724, 1.380, 1.104, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.210) and 15 (σ=3.368).
# Keep 58945/167025 = 35.3% of the coarse cost matrix.
# Keep 54769/154449 = 35.5% of the coarse cost matrix.
# Keep 63331/180625 = 35.1% of the coarse cost matrix.
# OMT matching distance: 0.3700762093067169, time elapsed: 4.035475730895996
# 408x420 clusters, computed at scale = 3.307
# Successive scales :  72.174, 72.174, 57.740, 46.192, 36.953, 29.563, 23.650, 18.920, 15.136, 12.109, 9.687, 7.750, 6.200, 4.960, 3.968, 3.174, 2.539, 2.032, 1.625, 1.300, 1.040, 0.832, 0.666, 0.533, 0.426, 0.341, 0.273, 0.218, 0.175, 0.140, 0.112, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.968) and 15 (σ=3.174).
# Keep 58436/171360 = 34.1% of the coarse cost matrix.
# Keep 56490/166464 = 33.9% of the coarse cost matrix.
# Keep 60358/176400 = 34.2% of the coarse cost matrix.
# OMT matching distance: 0.11446395516395569, time elapsed: 4.108949899673462
# 386x415 clusters, computed at scale = 3.663
# Successive scales :  79.933, 79.933, 63.946, 51.157, 40.926, 32.741, 26.192, 20.954, 16.763, 13.411, 10.728, 8.583, 6.866, 5.493, 4.394, 3.515, 2.812, 2.250, 1.800, 1.440, 1.152, 0.922, 0.737, 0.590, 0.472, 0.377, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.394) and 15 (σ=3.515).
# Keep 55503/160190 = 34.6% of the coarse cost matrix.
# Keep 52084/148996 = 35.0% of the coarse cost matrix.
# Keep 59083/172225 = 34.3% of the coarse cost matrix.
# OMT matching distance: 0.16130943596363068, time elapsed: 4.926912784576416
# 374x383 clusters, computed at scale = 3.508
# Successive scales :  76.562, 76.562, 61.249, 49.000, 39.200, 31.360, 25.088, 20.070, 16.056, 12.845, 10.276, 8.221, 6.577, 5.261, 4.209, 3.367, 2.694, 2.155, 1.724, 1.379, 1.103, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.209) and 15 (σ=3.367).
# Keep 49878/143242 = 34.8% of the coarse cost matrix.
# Keep 48608/139876 = 34.8% of the coarse cost matrix.
# Keep 51083/146689 = 34.8% of the coarse cost matrix.
# OMT matching distance: 0.05775117129087448, time elapsed: 3.701655626296997
# 404x400 clusters, computed at scale = 3.316
# Successive scales :  72.358, 72.358, 57.886, 46.309, 37.047, 29.638, 23.710, 18.968, 15.175, 12.140, 9.712, 7.769, 6.215, 4.972, 3.978, 3.182, 2.546, 2.037, 1.629, 1.303, 1.043, 0.834, 0.667, 0.534, 0.427, 0.342, 0.273, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.978) and 15 (σ=3.182).
# Keep 53864/161600 = 33.3% of the coarse cost matrix.
# Keep 54428/163216 = 33.3% of the coarse cost matrix.
# Keep 53270/160000 = 33.3% of the coarse cost matrix.
# OMT matching distance: 0.014755809679627419, time elapsed: 4.1297783851623535

# %%
# Save the template and the momenta
pd_temp_save = vtk_clone_pd(md_temp.pd)
for i, (id, md_i) in enumerate(md_aff.items()):
    vtk_set_point_array(pd_temp_save, f'momenta_{id}', p_temp[i,:,:].detach().cpu().numpy())
save_vtk(pd_temp_save, 'tmp/template_final_with_momenta.vtk')

# %%
# Match template to each subject and save the resulting meshes
for i, (id, md_i) in enumerate(md_aff.items()):
    # We want to map the template to the halfway surface of the MTL cortex in subject space
    # But that mesh has different number of vertices than the meshes we fitted in the template
    # building process. So we need to apply affine transform to the full-resolution inflated
    # mesh, then do OMT matching between the warped template and this target, then use this to
    # get coordinates of template vertices the space of the native halfway surface
    pd_infl_fullres = load_vtk(data[id]['workspace'].affine_moving)
    A = np.loadtxt(f'tmp/affine_to_template_{id}.mat')
    v_infl_fullres = vtk_get_points(pd_infl_fullres)
    v_infl_fullres_affine = (A[0:3,0:3] @ v_infl_fullres.T).T + A[0:3,3]

    # Send this mesh to the device
    vtk_set_points(pd_infl_fullres, v_infl_fullres_affine)
    vtk_set_cell_array(pd_infl_fullres, 'plab', np.zeros((v_infl_fullres_affine.shape[0],1)))
    md_infl_fullres = MeshData(pd_infl_fullres, device)

    # Get template mesh and OMT fitted mesh
    pd_i_fit, pd_i_omt = map_template_to_subject(md_temp, md_i, p_temp[i], 
                                                 sigma_lddmm = template['left'].get_lddmm_sigma())
    
    # These interpolation arrays map every template vertex to a face on the subject mesh. 
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # We also want to go all the way back to the original space. Load the original space mesh
    pd_hw_native = load_vtk(data[id]['workspace'].fn_cruise('mtl_avg_l2m-mesh-ras.vtk'))
    v_native = vtk_get_points(pd_hw_native)
    
    # Now we need to perform two interpolations
    v_temp_to_native = np.einsum('vij,vi->vj', v_native[v_int,:], w_int)

    #pd_i_fit, pd_i_omt = map_template_to_subject(md_temp, md_infl_fullres, p_temp[i], 
    #                                             sigma_lddmm = template['left'].get_lddmm_sigma())
    
    # The original mesh has a different number of vertices compared to the 
    # v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    # w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')
    # v_temp_to_native = np.einsum('vij,vi->vj', v_native[v_int,:], w_int)
    pd_temp_omt_to_native = vtk_make_pd(v_temp_to_native, vtk_get_triangles(pd_i_fit))
    pd_temp_omt_to_native = vtk_set_cell_array(pd_temp_omt_to_native, 'plab', vtk_get_cell_array(pd_i_fit, 'plab'))

    save_vtk(pd_i_fit, f'tmp/template_fit_to_{id}.vtk')
    save_vtk(pd_i_omt, f'tmp/template_omt_to_{id}.vtk')
    save_vtk(pd_temp_omt_to_native, f'tmp/template_omt_to_avg_ras_{id}.vtk')
# Out:
# 385x410 clusters, computed at scale = 3.573
# Successive scales :  77.975, 77.975, 62.380, 49.904, 39.923, 31.939, 25.551, 20.441, 16.353, 13.082, 10.466, 8.373, 6.698, 5.358, 4.287, 3.429, 2.744, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.287) and 15 (σ=3.429).
# Keep 55103/157850 = 34.9% of the coarse cost matrix.
# Keep 51577/148225 = 34.8% of the coarse cost matrix.
# Keep 58802/168100 = 35.0% of the coarse cost matrix.
# OMT matching distance: 0.19189341366291046, time elapsed: 4.253779888153076
# 462x497 clusters, computed at scale = 3.277
# Successive scales :  71.518, 71.518, 57.215, 45.772, 36.617, 29.294, 23.435, 18.748, 14.999, 11.999, 9.599, 7.679, 6.143, 4.915, 3.932, 3.145, 2.516, 2.013, 1.610, 1.288, 1.031, 0.825, 0.660, 0.528, 0.422, 0.338, 0.270, 0.216, 0.173, 0.138, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.932) and 15 (σ=3.145).
# Keep 77309/229614 = 33.7% of the coarse cost matrix.
# Keep 71724/213444 = 33.6% of the coarse cost matrix.
# Keep 83147/247009 = 33.7% of the coarse cost matrix.
# OMT matching distance: 0.08306694775819778, time elapsed: 4.878769636154175
# 389x426 clusters, computed at scale = 3.612
# Successive scales :  78.817, 78.817, 63.053, 50.443, 40.354, 32.283, 25.827, 20.661, 16.529, 13.223, 10.579, 8.463, 6.770, 5.416, 4.333, 3.466, 2.773, 2.218, 1.775, 1.420, 1.136, 0.909, 0.727, 0.582, 0.465, 0.372, 0.298, 0.238, 0.191, 0.152, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.333) and 15 (σ=3.466).
# Keep 59778/165714 = 36.1% of the coarse cost matrix.
# Keep 54883/151321 = 36.3% of the coarse cost matrix.
# Keep 65134/181476 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.09053988009691238, time elapsed: 4.318037986755371
# 364x366 clusters, computed at scale = 3.535
# Successive scales :  77.133, 77.133, 61.706, 49.365, 39.492, 31.594, 25.275, 20.220, 16.176, 12.941, 10.353, 8.282, 6.626, 5.301, 4.240, 3.392, 2.714, 2.171, 1.737, 1.390, 1.112, 0.889, 0.711, 0.569, 0.455, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.240) and 15 (σ=3.392).
# Keep 47389/133224 = 35.6% of the coarse cost matrix.
# Keep 47066/132496 = 35.5% of the coarse cost matrix.
# Keep 47718/133956 = 35.6% of the coarse cost matrix.
# OMT matching distance: 0.09408099204301834, time elapsed: 3.8360555171966553
# 463x471 clusters, computed at scale = 3.187
# Successive scales :  69.542, 69.542, 55.633, 44.507, 35.605, 28.484, 22.787, 18.230, 14.584, 11.667, 9.334, 7.467, 5.974, 4.779, 3.823, 3.058, 2.447, 1.957, 1.566, 1.253, 1.002, 0.802, 0.641, 0.513, 0.411, 0.328, 0.263, 0.210, 0.168, 0.135, 0.108, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=3.823) and 15 (σ=3.058).
# Keep 71452/218073 = 32.8% of the coarse cost matrix.
# Keep 69835/214369 = 32.6% of the coarse cost matrix.
# Keep 72645/221841 = 32.7% of the coarse cost matrix.
# OMT matching distance: 0.6525200605392456, time elapsed: 4.689083576202393
# 385x412 clusters, computed at scale = 3.753
# Successive scales :  81.906, 81.906, 65.525, 52.420, 41.936, 33.549, 26.839, 21.471, 17.177, 13.742, 10.993, 8.795, 7.036, 5.629, 4.503, 3.602, 2.882, 2.305, 1.844, 1.475, 1.180, 0.944, 0.755, 0.604, 0.483, 0.387, 0.309, 0.248, 0.198, 0.158, 0.127, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=4.503) and 15 (σ=3.602).
# Keep 56507/158620 = 35.6% of the coarse cost matrix.
# Keep 53117/148225 = 35.8% of the coarse cost matrix.
# Keep 60042/169744 = 35.4% of the coarse cost matrix.
# OMT matching distance: 0.12135934829711914, time elapsed: 4.644935846328735
# 405x423 clusters, computed at scale = 3.594
# Successive scales :  78.438, 78.438, 62.751, 50.200, 40.160, 32.128, 25.703, 20.562, 16.450, 13.160, 10.528, 8.422, 6.738, 5.390, 4.312, 3.450, 2.760, 2.208, 1.766, 1.413, 1.130, 0.904, 0.723, 0.579, 0.463, 0.370, 0.296, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.312) and 15 (σ=3.450).
# Keep 62201/171315 = 36.3% of the coarse cost matrix.
# Keep 59939/164025 = 36.5% of the coarse cost matrix.
# Keep 64517/178929 = 36.1% of the coarse cost matrix.
# OMT matching distance: 0.07716631889343262, time elapsed: 4.252687454223633
# 389x407 clusters, computed at scale = 3.539
# Successive scales :  77.238, 77.238, 61.791, 49.432, 39.546, 31.637, 25.309, 20.248, 16.198, 12.958, 10.367, 8.293, 6.635, 5.308, 4.246, 3.397, 2.718, 2.174, 1.739, 1.391, 1.113, 0.890, 0.712, 0.570, 0.456, 0.365, 0.292, 0.233, 0.187, 0.149, 0.120, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.246) and 15 (σ=3.397).
# Keep 57202/158323 = 36.1% of the coarse cost matrix.
# Keep 54905/151321 = 36.3% of the coarse cost matrix.
# Keep 59539/165649 = 35.9% of the coarse cost matrix.
# OMT matching distance: 0.14875707030296326, time elapsed: 3.8482720851898193
# 388x423 clusters, computed at scale = 3.574
# Successive scales :  77.988, 77.988, 62.391, 49.913, 39.930, 31.944, 25.555, 20.444, 16.355, 13.084, 10.467, 8.374, 6.699, 5.359, 4.287, 3.430, 2.744, 2.195, 1.756, 1.405, 1.124, 0.899, 0.719, 0.575, 0.460, 0.368, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=4.287) and 15 (σ=3.430).
# Keep 62598/164124 = 38.1% of the coarse cost matrix.
# Keep 58302/150544 = 38.7% of the coarse cost matrix.
# Keep 67315/178929 = 37.6% of the coarse cost matrix.
# OMT matching distance: 0.0818093940615654, time elapsed: 4.2588183879852295
# 393x425 clusters, computed at scale = 3.509
# Successive scales :  76.583, 76.583, 61.266, 49.013, 39.210, 31.368, 25.095, 20.076, 16.061, 12.848, 10.279, 8.223, 6.578, 5.263, 4.210, 3.368, 2.695, 2.156, 1.724, 1.380, 1.104, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.210) and 15 (σ=3.368).
# Keep 58945/167025 = 35.3% of the coarse cost matrix.
# Keep 54769/154449 = 35.5% of the coarse cost matrix.
# Keep 63331/180625 = 35.1% of the coarse cost matrix.
# OMT matching distance: 0.37007611989974976, time elapsed: 4.120910882949829
# 408x420 clusters, computed at scale = 3.307
# Successive scales :  72.174, 72.174, 57.740, 46.192, 36.953, 29.563, 23.650, 18.920, 15.136, 12.109, 9.687, 7.750, 6.200, 4.960, 3.968, 3.174, 2.539, 2.032, 1.625, 1.300, 1.040, 0.832, 0.666, 0.533, 0.426, 0.341, 0.273, 0.218, 0.175, 0.140, 0.112, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=3.968) and 15 (σ=3.174).
# Keep 58436/171360 = 34.1% of the coarse cost matrix.
# Keep 56490/166464 = 33.9% of the coarse cost matrix.
# Keep 60358/176400 = 34.2% of the coarse cost matrix.
# OMT matching distance: 0.11446401476860046, time elapsed: 4.158622980117798
# 386x415 clusters, computed at scale = 3.663
# Successive scales :  79.933, 79.933, 63.946, 51.157, 40.926, 32.741, 26.192, 20.954, 16.763, 13.411, 10.728, 8.583, 6.866, 5.493, 4.394, 3.515, 2.812, 2.250, 1.800, 1.440, 1.152, 0.922, 0.737, 0.590, 0.472, 0.377, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=4.394) and 15 (σ=3.515).
# Keep 55503/160190 = 34.6% of the coarse cost matrix.
# Keep 52084/148996 = 35.0% of the coarse cost matrix.
# Keep 59083/172225 = 34.3% of the coarse cost matrix.
# OMT matching distance: 0.16130946576595306, time elapsed: 4.747527599334717
# 374x383 clusters, computed at scale = 3.508
# Successive scales :  76.562, 76.562, 61.249, 49.000, 39.200, 31.360, 25.088, 20.070, 16.056, 12.845, 10.276, 8.221, 6.577, 5.261, 4.209, 3.367, 2.694, 2.155, 1.724, 1.379, 1.103, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=4.209) and 15 (σ=3.367).
# Keep 49878/143242 = 34.8% of the coarse cost matrix.
# Keep 48608/139876 = 34.8% of the coarse cost matrix.
# Keep 51083/146689 = 34.8% of the coarse cost matrix.
# OMT matching distance: 0.05775117501616478, time elapsed: 3.8036208152770996

# %%
# Destination folder for the template
temp_save_folder = 'tmp/crashs_template'
os.makedirs(temp_save_folder, exist_ok=True)

# Compute curvature measures on the template
ms = pymeshlab.MeshSet()
ms.add_mesh(pymeshlab.Mesh(vertex_matrix=md_temp.v, face_matrix=md_temp.f))

for c_id,c_nm in { 0: 'Mean', 1: 'Gaussian', 4: 'ShapeIndex', 5: 'Curvedness' }.items():
    ms.compute_curvature_principal_directions_per_vertex(
        method='Scale Dependent Quadric Fitting', 
        curvcolormethod=c_id,
        scale=pymeshlab.AbsoluteValue(3.0))
    q = ms.mesh(0)
    vtk_set_point_array(md_temp.pd, f'Curvature_{c_nm}', ms.mesh(0).vertex_scalar_array())

# Set the label array in the template by taking argmax over plab
vtk_set_cell_array(md_temp.pd, 'label', np.argmax(md_temp.lp, axis=1))

# Save the left template
save_vtk(md_temp.pd, f'{temp_save_folder}/template_shoot_left.vtk')

# Apply a flip to the left template
pd_template_flip = vtk_clone_pd(md_temp.pd)
vtk_set_points(pd_template_flip,
               np.einsum('ij,kj->ki', flip_lr[:3,:3].T, md_temp.v) + flip_lr[:3,3])
save_vtk(pd_template_flip, f'{temp_save_folder}/template_shoot_right.vtk')

# Save the JSON
with open(f'{temp_save_folder}/template.json','wt') as fd:
    json.dump(template['left'].json, fd)
# Out:
# average vertex num in each fit: 58.576469
# average vertex num in each fit: 58.599689
# average vertex num in each fit: 58.599537
# average vertex num in each fit: 58.599537

# %%
with open(f'{temp_save_folder}/template.json','wt') as fd:
    json.dump(template.json, fd)

# %% [markdown]
# # Compute consensus labeling

# %%
import SimpleITK as sitk

# Load the template again


# Ok, so we have the template in native space, we can now sample the complete selection of labels. Load the scans.
xvashs_label = np.zeros((md_temp.v.shape[0], len(md_aff)))
for i, (id, md_i) in enumerate(md_aff.items()):
    # Read the global segmentation
    fn_global_seg = f'/data/pauly2/ashs_xv/input/{id}/{id}_label_global.nii.gz'
    img = sitk.ReadImage(fn_global_seg, outputPixelType=sitk.sitkFloat32)

    # Load the mesh
    pd_temp_omt_to_native = load_vtk(f'tmp/template_omt_to_avg_ras_{id}.vtk')

    # Sample all the vertices - nearest neighbor
    v = vtk_get_points(pd_temp_omt_to_native)
    for j in range(v.shape[0]):
        x = [ -v[j,0], -v[j,1], v[j,2] ]
        try:
            l = img.EvaluateAtPhysicalPoint(x, sitk.sitkNearestNeighbor)
        except:
            l = 0
        xvashs_label[j,i] = l

    # Assign to the mesh
    vtk_set_point_array(pd_temp_omt_to_native, 'label_xv', xvashs_label[:,i]);
    save_vtk(pd_temp_omt_to_native, f'tmp/template_omt_to_avg_ras_withlabel_{id}.vtk')
    # break
        
# Consensus labeling
lab_consensus = np.argmax([np.sum(xvashs_label == v, 1) for v in range(69)], 0)
pd_consensus = vtk_clone_pd(md_temp.pd)
vtk_set_point_array(pd_consensus, 'xvashs', lab_consensus)

save_vtk(pd_consensus, 'tmp/template_global_label.vtk')

# %% [markdown]
# # More serious consensus labeling, using all Cruise layers

# %%
# Implements marching cubes with remeshing in voxel space
def layer_to_mesh(layer, edge_len_pct=0.75):
    pix_raw = sitk.GetArrayFromImage(layer)
    img = vtk.vtkImageData()
    img.GetPointData().SetScalars(numpy_to_vtk(pix_raw.flatten(), array_type=vtk.VTK_FLOAT))
    img.SetDimensions(layer.GetSize()[0], layer.GetSize()[1], layer.GetSize()[2]) 
    # img.SetOrigin(layer.GetOrigin()[0],layer.GetOrigin()[1],layer.GetOrigin()[2])
    # img.SetSpacing(layer.GetSpacing()[0],layer.GetSpacing()[1],layer.GetSpacing()[2])
    # img.SetDirectionMatrix(*layer.GetDirection())

    cube = vtk.vtkMarchingCubes()
    cube.SetInputData(img)
    cube.SetNumberOfContours(1)
    cube.SetValue(0, 0.0)

    tri1 = vtk.vtkTriangleFilter()
    tri1.SetInputConnection(cube.GetOutputPort())
    tri1.PassLinesOff()
    tri1.PassVertsOff()

    clean = vtk.vtkCleanPolyData()
    clean.SetInputConnection(tri1.GetOutputPort())
    clean.PointMergingOn()
    clean.SetTolerance(0.0)

    tri2 = vtk.vtkTriangleFilter()
    tri2.SetInputConnection(clean.GetOutputPort())
    tri2.PassLinesOff()
    tri2.PassVertsOff()

    tri2.Update()
    pd_cubes = tri2.GetOutput()

    # Apply remeshing to the template
    ms = pymeshlab.MeshSet()
    ms.add_mesh(pymeshlab.Mesh(vertex_matrix=vtk_get_points(pd_cubes), face_matrix=vtk_get_triangles(pd_cubes)))
    ms.meshing_isotropic_explicit_remeshing(targetlen = pymeshlab.Percentage(edge_len_pct))
    v_remesh, f_remesh = ms.mesh(0).vertex_matrix(), ms.mesh(0).face_matrix()
    return vtk_make_pd(v_remesh, f_remesh)


# Propagate a mesh through the levelset shells using OMT, starting with the 
# specified level. If no level specified, middle level will be used
def profile_meshing_omt(img_ls, source_mesh=None, init_layer=None):

    # The OMT algorithm that is called repeatedly
    def do_omt(l_src, l_trg):
        _, w_omt = match_omt(
            torch.tensor(vtk_get_points(l_src), dtype=torch.float32, device=device),
            torch.tensor(vtk_get_triangles(l_src), dtype=torch.int32, device=device),
            torch.tensor(vtk_get_points(l_trg), dtype=torch.float32, device=device),
            torch.tensor(vtk_get_triangles(l_trg), dtype=torch.int32, device=device))
        v_omt, _, _ = omt_match_to_vertex_weights(l_src, l_trg, w_omt.detach().cpu().numpy())
        return vtk_make_pd(v_omt, vtk_get_triangles(l_src))
    
    # Extract all the isolayers from the image 
    layers = [ layer_to_mesh(img_ls[:,:,:,k]) for k in range(img_ls.GetSize()[3]) ]
    matched = [ None for k in layers ]

    # Determine init layer
    if init_layer is None:
        init_layer = img_ls.GetSize()[3] // 2

    # Propagate from the mesh to the initial layer (unless we want to use a layer as source)
    matched[init_layer] = do_omt(source_mesh, layers[init_layer]) if source_mesh else layers[init_layer]

    # Propagate in both directions
    seq1 = reversed(range(0, init_layer))
    seq2 = reversed(range(img_ls.GetSize()[3]-1, init_layer, -1))
    for seq in seq1, seq2:
        prop_source = matched[init_layer]
        for k in seq:
            print(f'Propagating to layer {k}')
            matched[k] = do_omt(prop_source, layers[k])
            prop_source = matched[k]

    # Return the propagated meshes
    return matched, init_layer

# %%
# Load the CSV with the label descriptions
import pandas as pd
df_uclm = pd.read_csv('/data/pauly2/ashs_xv/manifest/label_grouping_ashs.csv',
                      names=('uclm','group','uclm_desc','group_desc'))

# These are the gray matter labels
uclm_group_labels_gm = (1,3,4,5,7,8,9)

# Label to group map
uclm_label_grouping = { q['uclm']: q['group'] for _, q in df_uclm.iterrows() if q['group'] in uclm_group_labels_gm }

# %%
# (re)load template
temp_save_folder = 'tmp/crashs_template'
md_temp = MeshData(load_vtk(f'{temp_save_folder}/template_shoot_left.vtk'), device)
v_temp, f_temp = md_temp.v, md_temp.f

# %%
# Define the list of labels that we care about
uclm_labels = uclm_label_grouping.keys()

# Create a label map tensor. For each template vertex, we store for the five Nighres layers
# the probability of each label, plus the background probability
uclm_label_map = np.zeros((v_temp.shape[0], 11, len(md_aff), len(uclm_labels) + 1))

# Load each segmentation in turn
for i, (id, md_i) in enumerate(md_aff.items()):

    # Read the global segmentation
    fn_global_seg = f'/data/pauly2/ashs_xv/input/{id}/{id}_label_global.nii.gz'
    img = sitk.ReadImage(fn_global_seg, outputPixelType=sitk.sitkFloat32)

    # Read the cortex image - because it has the dimensions that match the mesh
    img_ref = sitk.ReadImage(data[id]['workspace'].cruise_gm_prob)

    # Split the segmentation into binary images
    x_img = sitk.GetArrayFromImage(img)
    p_lab = np.stack([ x_img == l for l in uclm_labels])
    p_lab = np.append(p_lab, [1 - p_lab.sum(0)], axis=0)

    # Put it back into a vector ITK image (not very efficient)
    img_p = sitk.GetImageFromArray(p_lab.transpose(1,2,3,0), isVector=True)
    img_p.CopyInformation(img)

    # Smooth the image a bit
    img_p = sitk.SmoothingRecursiveGaussian(img_p, [0.4, 0.4, 0.4])

    # Load the fitted mesh and its interpolation arrays
    pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the midsurface mesh from cruise and map the template to this space
    pd_hw_nighres = load_vtk(data[id]['workspace'].fn_cruise('mtl_avg_l2m-mesh.vtk'))
    v_temp_to_hw_nighres = np.einsum('vij,vi->vj', vtk_get_points(pd_hw_nighres)[v_int,:], w_int)
    pd_temp_to_hw_nighres = vtk_make_pd(v_temp_to_hw_nighres, vtk_get_triangles(pd_i_fit))

    # Propagate this fitted mesh through the levelset layers using OMT
    img_ls = sitk.ReadImage(data[id]['workspace'].fn_cruise('mtl_layering-boundaries.nii.gz'))
    prof_meshes, mid_layer = profile_meshing_omt(img_ls, source_mesh=pd_temp_to_hw_nighres)

    # Repeat for each mesh layer
    print(f'Sampling {id}')
    for layer, pd_layer in enumerate(prof_meshes):

        # Load the mesh for that layer
        # pd_layer = load_vtk(data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))
        # pd_layer = load_vtk(f'tmp/template_subdiv_{id}_mesh-p{layer}.vtk')
        v_layer = vtk_get_points(pd_layer)

        # Sample the label map at this layer, keeping in mind that the layer is going to
        # be in image coordinate space, not physical space
        n_hit, n_miss = 0, 0
        for j in range(v_layer.shape[0]):
            # Transform to physical point via reference image
            p_j = img_ref.TransformContinuousIndexToPhysicalPoint(v_layer[j, :].tolist())
            try:
                l = img_p.EvaluateAtPhysicalPoint(p_j, sitk.sitkLinear)
                n_hit = n_hit + 1
            except:
                n_miss = n_miss + 1
                l = 0
            uclm_label_map[j, layer, i, :] = l
# Out:
# 517x538 clusters, computed at scale = 7.212
# Successive scales :  157.380, 157.380, 125.904, 100.723, 80.579, 64.463, 51.570, 41.256, 33.005, 26.404, 21.123, 16.899, 13.519, 10.815, 8.652, 6.922, 5.537, 4.430, 3.544, 2.835, 2.268, 1.814, 1.452, 1.161, 0.929, 0.743, 0.595, 0.476, 0.381, 0.304, 0.244, 0.195, 0.156, 0.125, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.652) and 15 (σ=6.922).
# Keep 84964/278146 = 30.5% of the coarse cost matrix.
# Keep 82501/267289 = 30.9% of the coarse cost matrix.
# Keep 87660/289444 = 30.3% of the coarse cost matrix.
# OMT matching distance: 0.8265379667282104, time elapsed: 1.4615063667297363
# Propagating to layer 4
# 513x528 clusters, computed at scale = 7.191
# Successive scales :  156.919, 156.919, 125.535, 100.428, 80.342, 64.274, 51.419, 41.135, 32.908, 26.327, 21.061, 16.849, 13.479, 10.783, 8.627, 6.901, 5.521, 4.417, 3.533, 2.827, 2.261, 1.809, 1.447, 1.158, 0.926, 0.741, 0.593, 0.474, 0.379, 0.304, 0.243, 0.194, 0.155, 0.124, 0.099, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.627) and 15 (σ=6.901).
# Keep 83214/270864 = 30.7% of the coarse cost matrix.
# Keep 81253/263169 = 30.9% of the coarse cost matrix.
# Keep 84996/278784 = 30.5% of the coarse cost matrix.
# OMT matching distance: 0.7890581488609314, time elapsed: 1.4426443576812744
# Propagating to layer 3
# 502x513 clusters, computed at scale = 7.173
# Successive scales :  156.539, 156.539, 125.231, 100.185, 80.148, 64.118, 51.295, 41.036, 32.829, 26.263, 21.010, 16.808, 13.447, 10.757, 8.606, 6.885, 5.508, 4.406, 3.525, 2.820, 2.256, 1.805, 1.444, 1.155, 0.924, 0.739, 0.591, 0.473, 0.378, 0.303, 0.242, 0.194, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.606) and 15 (σ=6.885).
# Keep 79787/257526 = 31.0% of the coarse cost matrix.
# Keep 77970/252004 = 30.9% of the coarse cost matrix.
# Keep 81497/263169 = 31.0% of the coarse cost matrix.
# OMT matching distance: 0.7752686142921448, time elapsed: 1.420574426651001
# Propagating to layer 2
# 491x506 clusters, computed at scale = 7.159
# Successive scales :  156.234, 156.234, 124.987, 99.990, 79.992, 63.993, 51.195, 40.956, 32.765, 26.212, 20.969, 16.776, 13.420, 10.736, 8.589, 6.871, 5.497, 4.398, 3.518, 2.814, 2.252, 1.801, 1.441, 1.153, 0.922, 0.738, 0.590, 0.472, 0.378, 0.302, 0.242, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.589) and 15 (σ=6.871).
# Keep 78152/248446 = 31.5% of the coarse cost matrix.
# Keep 76365/241081 = 31.7% of the coarse cost matrix.
# Keep 80102/256036 = 31.3% of the coarse cost matrix.
# OMT matching distance: 0.849593997001648, time elapsed: 3.2141475677490234
# Propagating to layer 1
# 472x481 clusters, computed at scale = 7.150
# Successive scales :  156.021, 156.021, 124.817, 99.854, 79.883, 63.906, 51.125, 40.900, 32.720, 26.176, 20.941, 16.753, 13.402, 10.722, 8.577, 6.862, 5.490, 4.392, 3.513, 2.811, 2.249, 1.799, 1.439, 1.151, 0.921, 0.737, 0.589, 0.472, 0.377, 0.302, 0.241, 0.193, 0.155, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.577) and 15 (σ=6.862).
# Keep 71344/227032 = 31.4% of the coarse cost matrix.
# Keep 70778/222784 = 31.8% of the coarse cost matrix.
# Keep 72131/231361 = 31.2% of the coarse cost matrix.
# OMT matching distance: 0.9602922201156616, time elapsed: 4.769550323486328
# Propagating to layer 0
# 457x458 clusters, computed at scale = 7.143
# Successive scales :  155.885, 155.885, 124.708, 99.767, 79.813, 63.851, 51.080, 40.864, 32.692, 26.153, 20.923, 16.738, 13.390, 10.712, 8.570, 6.856, 5.485, 4.388, 3.510, 2.808, 2.247, 1.797, 1.438, 1.150, 0.920, 0.736, 0.589, 0.471, 0.377, 0.302, 0.241, 0.193, 0.154, 0.124, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.570) and 15 (σ=6.856).
# Keep 65393/209306 = 31.2% of the coarse cost matrix.
# Keep 66033/208849 = 31.6% of the coarse cost matrix.
# Keep 64826/209764 = 30.9% of the coarse cost matrix.
# OMT matching distance: 1.103407621383667, time elapsed: 4.60041618347168
# Propagating to layer 6
# 503x554 clusters, computed at scale = 7.243
# Successive scales :  158.060, 158.060, 126.448, 101.159, 80.927, 64.741, 51.793, 41.435, 33.148, 26.518, 21.214, 16.972, 13.577, 10.862, 8.689, 6.952, 5.561, 4.449, 3.559, 2.847, 2.278, 1.822, 1.458, 1.166, 0.933, 0.746, 0.597, 0.478, 0.382, 0.306, 0.245, 0.196, 0.157, 0.125, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.689) and 15 (σ=6.952).
# Keep 85469/278662 = 30.7% of the coarse cost matrix.
# Keep 78659/253009 = 31.1% of the coarse cost matrix.
# Keep 92830/306916 = 30.2% of the coarse cost matrix.
# OMT matching distance: 1.224608302116394, time elapsed: 1.4582805633544922
# Propagating to layer 7
# 527x566 clusters, computed at scale = 7.288
# Successive scales :  159.042, 159.042, 127.234, 101.787, 81.430, 65.144, 52.115, 41.692, 33.354, 26.683, 21.346, 17.077, 13.662, 10.929, 8.743, 6.995, 5.596, 4.477, 3.581, 2.865, 2.292, 1.834, 1.467, 1.174, 0.939, 0.751, 0.601, 0.481, 0.385, 0.308, 0.246, 0.197, 0.158, 0.126, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=8.743) and 15 (σ=6.995).
# Keep 91007/298282 = 30.5% of the coarse cost matrix.
# Keep 86301/277729 = 31.1% of the coarse cost matrix.
# Keep 95450/320356 = 29.8% of the coarse cost matrix.
# OMT matching distance: 1.5779757499694824, time elapsed: 1.5165307521820068
# Propagating to layer 8
# 520x574 clusters, computed at scale = 7.348
# Successive scales :  160.349, 160.349, 128.280, 102.624, 82.099, 65.679, 52.543, 42.035, 33.628, 26.902, 21.522, 17.217, 13.774, 11.019, 8.815, 7.052, 5.642, 4.513, 3.611, 2.889, 2.311, 1.849, 1.479, 1.183, 0.947, 0.757, 0.606, 0.485, 0.388, 0.310, 0.248, 0.199, 0.159, 0.127, 0.102, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=8.815) and 15 (σ=7.052).
# Keep 89050/298480 = 29.8% of the coarse cost matrix.
# Keep 82620/270400 = 30.6% of the coarse cost matrix.
# Keep 95492/329476 = 29.0% of the coarse cost matrix.
# OMT matching distance: 2.146406650543213, time elapsed: 1.5116593837738037
# Propagating to layer 9
# 526x599 clusters, computed at scale = 7.430
# Successive scales :  162.142, 162.142, 129.714, 103.771, 83.017, 66.413, 53.131, 42.505, 34.004, 27.203, 21.762, 17.410, 13.928, 11.142, 8.914, 7.131, 5.705, 4.564, 3.651, 2.921, 2.337, 1.869, 1.495, 1.196, 0.957, 0.766, 0.613, 0.490, 0.392, 0.314, 0.251, 0.201, 0.161, 0.128, 0.103, 0.082, 0.066, 0.053, 0.050
# Jump from coarse to fine between indices 14 (σ=8.914) and 15 (σ=7.131).
# Keep 92324/315074 = 29.3% of the coarse cost matrix.
# Keep 82532/276676 = 29.8% of the coarse cost matrix.
# Keep 102751/358801 = 28.6% of the coarse cost matrix.
# OMT matching distance: 2.5737123489379883, time elapsed: 1.583554983139038
# Propagating to layer 10
# 541x644 clusters, computed at scale = 7.514
# Successive scales :  163.982, 163.982, 131.185, 104.948, 83.959, 67.167, 53.734, 42.987, 34.389, 27.512, 22.009, 17.607, 14.086, 11.269, 9.015, 7.212, 5.770, 4.616, 3.693, 2.954, 2.363, 1.891, 1.512, 1.210, 0.968, 0.774, 0.620, 0.496, 0.396, 0.317, 0.254, 0.203, 0.162, 0.130, 0.104, 0.083, 0.067, 0.053, 0.050
# Jump from coarse to fine between indices 14 (σ=9.015) and 15 (σ=7.212).
# Keep 100658/348404 = 28.9% of the coarse cost matrix.
# Keep 86367/292681 = 29.5% of the coarse cost matrix.
# Keep 116500/414736 = 28.1% of the coarse cost matrix.
# OMT matching distance: 5.083898067474365, time elapsed: 1.7014214992523193
# Sampling 104937L
# 648x683 clusters, computed at scale = 6.680
# Successive scales :  145.771, 145.771, 116.616, 93.293, 74.635, 59.708, 47.766, 38.213, 30.570, 24.456, 19.565, 15.652, 12.522, 10.017, 8.014, 6.411, 5.129, 4.103, 3.282, 2.626, 2.101, 1.681, 1.344, 1.076, 0.860, 0.688, 0.551, 0.441, 0.352, 0.282, 0.226, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.014) and 15 (σ=6.411).
# Keep 127768/442584 = 28.9% of the coarse cost matrix.
# Keep 121090/419904 = 28.8% of the coarse cost matrix.
# Keep 134827/466489 = 28.9% of the coarse cost matrix.
# OMT matching distance: 0.32673949003219604, time elapsed: 1.7222297191619873
# Propagating to layer 4
# 655x676 clusters, computed at scale = 6.636
# Successive scales :  144.810, 144.810, 115.848, 92.679, 74.143, 59.314, 47.451, 37.961, 30.369, 24.295, 19.436, 15.549, 12.439, 9.951, 7.961, 6.369, 5.095, 4.076, 3.261, 2.609, 2.087, 1.670, 1.336, 1.069, 0.855, 0.684, 0.547, 0.438, 0.350, 0.280, 0.224, 0.179, 0.143, 0.115, 0.092, 0.073, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=7.961) and 15 (σ=6.369).
# Keep 127343/442780 = 28.8% of the coarse cost matrix.
# Keep 122547/429025 = 28.6% of the coarse cost matrix.
# Keep 132236/456976 = 28.9% of the coarse cost matrix.
# OMT matching distance: 0.7328566908836365, time elapsed: 1.7220284938812256
# Propagating to layer 3
# 642x665 clusters, computed at scale = 6.595
# Successive scales :  143.928, 143.928, 115.142, 92.114, 73.691, 58.953, 47.162, 37.730, 30.184, 24.147, 19.318, 15.454, 12.363, 9.891, 7.913, 6.330, 5.064, 4.051, 3.241, 2.593, 2.074, 1.659, 1.327, 1.062, 0.850, 0.680, 0.544, 0.435, 0.348, 0.278, 0.223, 0.178, 0.143, 0.114, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.913) and 15 (σ=6.330).
# Keep 124398/426930 = 29.1% of the coarse cost matrix.
# Keep 119812/412164 = 29.1% of the coarse cost matrix.
# Keep 129045/442225 = 29.2% of the coarse cost matrix.
# OMT matching distance: 0.6881662607192993, time elapsed: 1.6997566223144531
# Propagating to layer 2
# 634x653 clusters, computed at scale = 6.563
# Successive scales :  143.225, 143.225, 114.580, 91.664, 73.331, 58.665, 46.932, 37.546, 30.036, 24.029, 19.223, 15.379, 12.303, 9.842, 7.874, 6.299, 5.039, 4.031, 3.225, 2.580, 2.064, 1.651, 1.321, 1.057, 0.845, 0.676, 0.541, 0.433, 0.346, 0.277, 0.222, 0.177, 0.142, 0.113, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.874) and 15 (σ=6.299).
# Keep 120977/414002 = 29.2% of the coarse cost matrix.
# Keep 116808/401956 = 29.1% of the coarse cost matrix.
# Keep 125337/426409 = 29.4% of the coarse cost matrix.
# OMT matching distance: 0.6845225095748901, time elapsed: 1.6747453212738037
# Propagating to layer 1
# 623x643 clusters, computed at scale = 6.544
# Successive scales :  142.802, 142.802, 114.241, 91.393, 73.114, 58.492, 46.793, 37.435, 29.948, 23.958, 19.166, 15.333, 12.267, 9.813, 7.851, 6.280, 5.024, 4.020, 3.216, 2.572, 2.058, 1.646, 1.317, 1.054, 0.843, 0.674, 0.539, 0.432, 0.345, 0.276, 0.221, 0.177, 0.141, 0.113, 0.091, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.851) and 15 (σ=6.280).
# Keep 118148/400589 = 29.5% of the coarse cost matrix.
# Keep 114181/388129 = 29.4% of the coarse cost matrix.
# Keep 122187/413449 = 29.6% of the coarse cost matrix.
# OMT matching distance: 0.6903163194656372, time elapsed: 1.6592326164245605
# Propagating to layer 0
# 610x633 clusters, computed at scale = 6.534
# Successive scales :  142.582, 142.582, 114.066, 91.252, 73.002, 58.402, 46.721, 37.377, 29.902, 23.921, 19.137, 15.310, 12.248, 9.798, 7.839, 6.271, 5.017, 4.013, 3.211, 2.569, 2.055, 1.644, 1.315, 1.052, 0.842, 0.673, 0.539, 0.431, 0.345, 0.276, 0.221, 0.177, 0.141, 0.113, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.839) and 15 (σ=6.271).
# Keep 113288/386130 = 29.3% of the coarse cost matrix.
# Keep 109202/372100 = 29.3% of the coarse cost matrix.
# Keep 117347/400689 = 29.3% of the coarse cost matrix.
# OMT matching distance: 0.7226459980010986, time elapsed: 1.6441621780395508
# Propagating to layer 6
# 622x694 clusters, computed at scale = 6.739
# Successive scales :  147.071, 147.071, 117.657, 94.126, 75.301, 60.240, 48.192, 38.554, 30.843, 24.674, 19.740, 15.792, 12.633, 10.107, 8.085, 6.468, 5.175, 4.140, 3.312, 2.649, 2.120, 1.696, 1.356, 1.085, 0.868, 0.695, 0.556, 0.444, 0.356, 0.284, 0.228, 0.182, 0.146, 0.117, 0.093, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.085) and 15 (σ=6.468).
# Keep 123797/431668 = 28.7% of the coarse cost matrix.
# Keep 110922/386884 = 28.7% of the coarse cost matrix.
# Keep 137944/481636 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.9625053405761719, time elapsed: 1.7108852863311768
# Propagating to layer 7
# 634x697 clusters, computed at scale = 6.808
# Successive scales :  148.568, 148.568, 118.855, 95.084, 76.067, 60.854, 48.683, 38.946, 31.157, 24.926, 19.940, 15.952, 12.762, 10.210, 8.168, 6.534, 5.227, 4.182, 3.345, 2.676, 2.141, 1.713, 1.370, 1.096, 0.877, 0.702, 0.561, 0.449, 0.359, 0.287, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.168) and 15 (σ=6.534).
# Keep 125721/441898 = 28.5% of the coarse cost matrix.
# Keep 114974/401956 = 28.6% of the coarse cost matrix.
# Keep 137165/485809 = 28.2% of the coarse cost matrix.
# OMT matching distance: 1.2391574382781982, time elapsed: 1.7328076362609863
# Propagating to layer 8
# 619x690 clusters, computed at scale = 6.878
# Successive scales :  150.094, 150.094, 120.075, 96.060, 76.848, 61.478, 49.183, 39.346, 31.477, 25.182, 20.145, 16.116, 12.893, 10.314, 8.251, 6.601, 5.281, 4.225, 3.380, 2.704, 2.163, 1.730, 1.384, 1.107, 0.886, 0.709, 0.567, 0.454, 0.363, 0.290, 0.232, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.251) and 15 (σ=6.601).
# Keep 119682/427110 = 28.0% of the coarse cost matrix.
# Keep 108741/383161 = 28.4% of the coarse cost matrix.
# Keep 131608/476100 = 27.6% of the coarse cost matrix.
# OMT matching distance: 1.4789291620254517, time elapsed: 1.7134554386138916
# Propagating to layer 9
# 630x718 clusters, computed at scale = 6.995
# Successive scales :  152.638, 152.638, 122.111, 97.689, 78.151, 62.521, 50.017, 40.013, 32.011, 25.608, 20.487, 16.389, 13.112, 10.489, 8.391, 6.713, 5.370, 4.296, 3.437, 2.750, 2.200, 1.760, 1.408, 1.126, 0.901, 0.721, 0.577, 0.461, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.391) and 15 (σ=6.713).
# Keep 125198/452340 = 27.7% of the coarse cost matrix.
# Keep 112042/396900 = 28.2% of the coarse cost matrix.
# Keep 139388/515524 = 27.0% of the coarse cost matrix.
# OMT matching distance: 4.497883319854736, time elapsed: 1.7747809886932373
# Propagating to layer 10
# 649x751 clusters, computed at scale = 7.122
# Successive scales :  155.425, 155.425, 124.340, 99.472, 79.577, 63.662, 50.930, 40.744, 32.595, 26.076, 20.861, 16.689, 13.351, 10.681, 8.545, 6.836, 5.469, 4.375, 3.500, 2.800, 2.240, 1.792, 1.434, 1.147, 0.917, 0.734, 0.587, 0.470, 0.376, 0.301, 0.241, 0.192, 0.154, 0.123, 0.099, 0.079, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=8.545) and 15 (σ=6.836).
# Keep 132362/487399 = 27.2% of the coarse cost matrix.
# Keep 116815/421201 = 27.7% of the coarse cost matrix.
# Keep 149193/564001 = 26.5% of the coarse cost matrix.
# OMT matching distance: 7.108180999755859, time elapsed: 1.953495740890503
# Sampling 106049L
# 578x610 clusters, computed at scale = 7.973
# Successive scales :  173.992, 173.992, 139.193, 111.355, 89.084, 71.267, 57.014, 45.611, 36.489, 29.191, 23.353, 18.682, 14.946, 11.957, 9.565, 7.652, 6.122, 4.897, 3.918, 3.134, 2.507, 2.006, 1.605, 1.284, 1.027, 0.822, 0.657, 0.526, 0.421, 0.337, 0.269, 0.215, 0.172, 0.138, 0.110, 0.088, 0.071, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=9.565) and 15 (σ=7.652).
# Keep 108914/352580 = 30.9% of the coarse cost matrix.
# Keep 103634/334084 = 31.0% of the coarse cost matrix.
# Keep 114300/372100 = 30.7% of the coarse cost matrix.
# OMT matching distance: 0.43065276741981506, time elapsed: 1.6400022506713867
# Propagating to layer 4
# 577x599 clusters, computed at scale = 7.923
# Successive scales :  172.892, 172.892, 138.313, 110.651, 88.521, 70.816, 56.653, 45.323, 36.258, 29.006, 23.205, 18.564, 14.851, 11.881, 9.505, 7.604, 6.083, 4.866, 3.893, 3.115, 2.492, 1.993, 1.595, 1.276, 1.021, 0.816, 0.653, 0.523, 0.418, 0.334, 0.268, 0.214, 0.171, 0.137, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=9.505) and 15 (σ=7.604).
# Keep 106889/345623 = 30.9% of the coarse cost matrix.
# Keep 102987/332929 = 30.9% of the coarse cost matrix.
# Keep 110921/358801 = 30.9% of the coarse cost matrix.
# OMT matching distance: 0.7662848234176636, time elapsed: 1.629014492034912
# Propagating to layer 3
# 566x580 clusters, computed at scale = 7.888
# Successive scales :  172.144, 172.144, 137.715, 110.172, 88.138, 70.510, 56.408, 45.126, 36.101, 28.881, 23.105, 18.484, 14.787, 11.830, 9.464, 7.571, 6.057, 4.845, 3.876, 3.101, 2.481, 1.985, 1.588, 1.270, 1.016, 0.813, 0.650, 0.520, 0.416, 0.333, 0.266, 0.213, 0.170, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=9.464) and 15 (σ=7.571).
# Keep 102529/328280 = 31.2% of the coarse cost matrix.
# Keep 99614/320356 = 31.1% of the coarse cost matrix.
# Keep 105514/336400 = 31.4% of the coarse cost matrix.
# OMT matching distance: 0.7717787623405457, time elapsed: 1.6058447360992432
# Propagating to layer 2
# 559x571 clusters, computed at scale = 7.866
# Successive scales :  171.647, 171.647, 137.317, 109.854, 87.883, 70.307, 56.245, 44.996, 35.997, 28.798, 23.038, 18.430, 14.744, 11.795, 9.436, 7.549, 6.039, 4.831, 3.865, 3.092, 2.474, 1.979, 1.583, 1.267, 1.013, 0.811, 0.648, 0.519, 0.415, 0.332, 0.266, 0.212, 0.170, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=9.436) and 15 (σ=7.549).
# Keep 100626/319189 = 31.5% of the coarse cost matrix.
# Keep 98463/312481 = 31.5% of the coarse cost matrix.
# Keep 102835/326041 = 31.5% of the coarse cost matrix.
# OMT matching distance: 0.7708579301834106, time elapsed: 1.58357572555542
# Propagating to layer 1
# 548x556 clusters, computed at scale = 7.842
# Successive scales :  171.137, 171.137, 136.910, 109.528, 87.622, 70.098, 56.078, 44.863, 35.890, 28.712, 22.970, 18.376, 14.701, 11.760, 9.408, 7.527, 6.021, 4.817, 3.854, 3.083, 2.466, 1.973, 1.578, 1.263, 1.010, 0.808, 0.647, 0.517, 0.414, 0.331, 0.265, 0.212, 0.169, 0.136, 0.108, 0.087, 0.069, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=9.408) and 15 (σ=7.527).
# Keep 95479/304688 = 31.3% of the coarse cost matrix.
# Keep 94446/300304 = 31.5% of the coarse cost matrix.
# Keep 96554/309136 = 31.2% of the coarse cost matrix.
# OMT matching distance: 0.7839359045028687, time elapsed: 1.562978982925415
# Propagating to layer 0
# 528x536 clusters, computed at scale = 7.828
# Successive scales :  170.827, 170.827, 136.662, 109.329, 87.463, 69.971, 55.977, 44.781, 35.825, 28.660, 22.928, 18.342, 14.674, 11.739, 9.391, 7.513, 6.010, 4.808, 3.847, 3.077, 2.462, 1.970, 1.576, 1.260, 1.008, 0.807, 0.645, 0.516, 0.413, 0.330, 0.264, 0.211, 0.169, 0.135, 0.108, 0.087, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=9.391) and 15 (σ=7.513).
# Keep 89321/283008 = 31.6% of the coarse cost matrix.
# Keep 88720/278784 = 31.8% of the coarse cost matrix.
# Keep 89948/287296 = 31.3% of the coarse cost matrix.
# OMT matching distance: 0.8445212841033936, time elapsed: 1.5354528427124023
# Propagating to layer 6
# 566x614 clusters, computed at scale = 8.033
# Successive scales :  175.290, 175.290, 140.232, 112.185, 89.748, 71.799, 57.439, 45.951, 36.761, 29.409, 23.527, 18.822, 15.057, 12.046, 9.637, 7.709, 6.167, 4.934, 3.947, 3.158, 2.526, 2.021, 1.617, 1.293, 1.035, 0.828, 0.662, 0.530, 0.424, 0.339, 0.271, 0.217, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.637) and 15 (σ=7.709).
# Keep 107440/347524 = 30.9% of the coarse cost matrix.
# Keep 99958/320356 = 31.2% of the coarse cost matrix.
# Keep 115396/376996 = 30.6% of the coarse cost matrix.
# OMT matching distance: 1.178382396697998, time elapsed: 1.6339001655578613
# Propagating to layer 7
# 567x617 clusters, computed at scale = 8.100
# Successive scales :  176.769, 176.769, 141.415, 113.132, 90.506, 72.405, 57.924, 46.339, 37.071, 29.657, 23.726, 18.980, 15.184, 12.147, 9.718, 7.774, 6.220, 4.976, 3.980, 3.184, 2.548, 2.038, 1.630, 1.304, 1.043, 0.835, 0.668, 0.534, 0.427, 0.342, 0.274, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.718) and 15 (σ=7.774).
# Keep 107831/349839 = 30.8% of the coarse cost matrix.
# Keep 100641/321489 = 31.3% of the coarse cost matrix.
# Keep 115281/380689 = 30.3% of the coarse cost matrix.
# OMT matching distance: 1.4834299087524414, time elapsed: 1.641343355178833
# Propagating to layer 8
# 581x632 clusters, computed at scale = 8.169
# Successive scales :  178.278, 178.278, 142.622, 114.098, 91.278, 73.023, 58.418, 46.734, 37.388, 29.910, 23.928, 19.142, 15.314, 12.251, 9.801, 7.841, 6.273, 5.018, 4.014, 3.212, 2.569, 2.055, 1.644, 1.315, 1.052, 0.842, 0.674, 0.539, 0.431, 0.345, 0.276, 0.221, 0.177, 0.141, 0.113, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.801) and 15 (σ=7.841).
# Keep 111769/367192 = 30.4% of the coarse cost matrix.
# Keep 104429/337561 = 30.9% of the coarse cost matrix.
# Keep 119488/399424 = 29.9% of the coarse cost matrix.
# OMT matching distance: 1.9215502738952637, time elapsed: 1.6770298480987549
# Propagating to layer 9
# 583x633 clusters, computed at scale = 8.244
# Successive scales :  179.894, 179.894, 143.915, 115.132, 92.106, 73.685, 58.948, 47.158, 37.727, 30.181, 24.145, 19.316, 15.453, 12.362, 9.890, 7.912, 6.329, 5.064, 4.051, 3.241, 2.593, 2.074, 1.659, 1.327, 1.062, 0.850, 0.680, 0.544, 0.435, 0.348, 0.278, 0.223, 0.178, 0.143, 0.114, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.890) and 15 (σ=7.912).
# Keep 111104/369039 = 30.1% of the coarse cost matrix.
# Keep 104021/339889 = 30.6% of the coarse cost matrix.
# Keep 118357/400689 = 29.5% of the coarse cost matrix.
# OMT matching distance: 2.3104937076568604, time elapsed: 1.6901767253875732
# Propagating to layer 10
# 584x651 clusters, computed at scale = 8.311
# Successive scales :  181.364, 181.364, 145.091, 116.073, 92.858, 74.287, 59.429, 47.543, 38.035, 30.428, 24.342, 19.474, 15.579, 12.463, 9.971, 7.976, 6.381, 5.105, 4.084, 3.267, 2.614, 2.091, 1.673, 1.338, 1.071, 0.856, 0.685, 0.548, 0.439, 0.351, 0.281, 0.225, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=9.971) and 15 (σ=7.976).
# Keep 112931/380184 = 29.7% of the coarse cost matrix.
# Keep 103720/341056 = 30.4% of the coarse cost matrix.
# Keep 122753/423801 = 29.0% of the coarse cost matrix.
# OMT matching distance: 4.031499862670898, time elapsed: 1.7610204219818115
# Sampling 106312R
# 527x543 clusters, computed at scale = 6.711
# Successive scales :  146.450, 146.450, 117.160, 93.728, 74.982, 59.986, 47.989, 38.391, 30.713, 24.570, 19.656, 15.725, 12.580, 10.064, 8.051, 6.441, 5.153, 4.122, 3.298, 2.638, 2.111, 1.688, 1.351, 1.081, 0.864, 0.692, 0.553, 0.443, 0.354, 0.283, 0.227, 0.181, 0.145, 0.116, 0.093, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.051) and 15 (σ=6.441).
# Keep 82401/286161 = 28.8% of the coarse cost matrix.
# Keep 80601/277729 = 29.0% of the coarse cost matrix.
# Keep 84367/294849 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.23948132991790771, time elapsed: 1.3976588249206543
# Propagating to layer 4
# 525x539 clusters, computed at scale = 6.685
# Successive scales :  145.873, 145.873, 116.698, 93.358, 74.687, 59.749, 47.800, 38.240, 30.592, 24.473, 19.579, 15.663, 12.530, 10.024, 8.019, 6.416, 5.132, 4.106, 3.285, 2.628, 2.102, 1.682, 1.345, 1.076, 0.861, 0.689, 0.551, 0.441, 0.353, 0.282, 0.226, 0.181, 0.144, 0.116, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.019) and 15 (σ=6.416).
# Keep 81610/282975 = 28.8% of the coarse cost matrix.
# Keep 79987/275625 = 29.0% of the coarse cost matrix.
# Keep 83405/290521 = 28.7% of the coarse cost matrix.
# OMT matching distance: 0.42288488149642944, time elapsed: 1.3911783695220947
# Propagating to layer 3
# 503x514 clusters, computed at scale = 6.674
# Successive scales :  145.648, 145.648, 116.519, 93.215, 74.572, 59.658, 47.726, 38.181, 30.545, 24.436, 19.549, 15.639, 12.511, 10.009, 8.007, 6.406, 5.125, 4.100, 3.280, 2.624, 2.099, 1.679, 1.343, 1.075, 0.860, 0.688, 0.550, 0.440, 0.352, 0.282, 0.225, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.007) and 15 (σ=6.406).
# Keep 75229/258542 = 29.1% of the coarse cost matrix.
# Keep 73861/253009 = 29.2% of the coarse cost matrix.
# Keep 76538/264196 = 29.0% of the coarse cost matrix.
# OMT matching distance: 0.42191851139068604, time elapsed: 1.3522756099700928
# Propagating to layer 2
# 493x504 clusters, computed at scale = 6.666
# Successive scales :  145.460, 145.460, 116.368, 93.094, 74.476, 59.580, 47.664, 38.131, 30.505, 24.404, 19.523, 15.619, 12.495, 9.996, 7.997, 6.397, 5.118, 4.094, 3.275, 2.620, 2.096, 1.677, 1.342, 1.073, 0.859, 0.687, 0.550, 0.440, 0.352, 0.281, 0.225, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=7.997) and 15 (σ=6.397).
# Keep 72360/248472 = 29.1% of the coarse cost matrix.
# Keep 71283/243049 = 29.3% of the coarse cost matrix.
# Keep 73516/254016 = 28.9% of the coarse cost matrix.
# OMT matching distance: 0.4320443868637085, time elapsed: 3.0600383281707764
# Propagating to layer 1
# 483x494 clusters, computed at scale = 6.660
# Successive scales :  145.342, 145.342, 116.274, 93.019, 74.415, 59.532, 47.626, 38.101, 30.481, 24.384, 19.508, 15.606, 12.485, 9.988, 7.990, 6.392, 5.114, 4.091, 3.273, 2.618, 2.095, 1.676, 1.341, 1.072, 0.858, 0.686, 0.549, 0.439, 0.351, 0.281, 0.225, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=7.990) and 15 (σ=6.392).
# Keep 69968/238602 = 29.3% of the coarse cost matrix.
# Keep 68861/233289 = 29.5% of the coarse cost matrix.
# Keep 71034/244036 = 29.1% of the coarse cost matrix.
# OMT matching distance: 0.4455634355545044, time elapsed: 4.687413454055786
# Propagating to layer 0
# 479x489 clusters, computed at scale = 6.659
# Successive scales :  145.307, 145.307, 116.246, 92.996, 74.397, 59.518, 47.614, 38.091, 30.473, 24.378, 19.503, 15.602, 12.482, 9.985, 7.988, 6.391, 5.113, 4.090, 3.272, 2.618, 2.094, 1.675, 1.340, 1.072, 0.858, 0.686, 0.549, 0.439, 0.351, 0.281, 0.225, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=7.988) and 15 (σ=6.391).
# Keep 68633/234231 = 29.3% of the coarse cost matrix.
# Keep 67865/229441 = 29.6% of the coarse cost matrix.
# Keep 69361/239121 = 29.0% of the coarse cost matrix.
# OMT matching distance: 0.5057007074356079, time elapsed: 4.664261102676392
# Propagating to layer 6
# 522x570 clusters, computed at scale = 6.739
# Successive scales :  147.070, 147.070, 117.656, 94.125, 75.300, 60.240, 48.192, 38.553, 30.843, 24.674, 19.739, 15.791, 12.633, 10.107, 8.085, 6.468, 5.175, 4.140, 3.312, 2.649, 2.119, 1.696, 1.356, 1.085, 0.868, 0.695, 0.556, 0.444, 0.356, 0.284, 0.228, 0.182, 0.146, 0.117, 0.093, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.085) and 15 (σ=6.468).
# Keep 86482/297540 = 29.1% of the coarse cost matrix.
# Keep 79984/272484 = 29.4% of the coarse cost matrix.
# Keep 93338/324900 = 28.7% of the coarse cost matrix.
# OMT matching distance: 0.7114993333816528, time elapsed: 1.42470383644104
# Propagating to layer 7
# 531x596 clusters, computed at scale = 6.775
# Successive scales :  147.854, 147.854, 118.283, 94.627, 75.701, 60.561, 48.449, 38.759, 31.007, 24.806, 19.845, 15.876, 12.701, 10.160, 8.128, 6.503, 5.202, 4.162, 3.329, 2.664, 2.131, 1.705, 1.364, 1.091, 0.873, 0.698, 0.559, 0.447, 0.357, 0.286, 0.229, 0.183, 0.146, 0.117, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.128) and 15 (σ=6.503).
# Keep 91033/316476 = 28.8% of the coarse cost matrix.
# Keep 82501/281961 = 29.3% of the coarse cost matrix.
# Keep 100502/355216 = 28.3% of the coarse cost matrix.
# OMT matching distance: 0.9362589120864868, time elapsed: 1.4617183208465576
# Propagating to layer 8
# 536x589 clusters, computed at scale = 6.835
# Successive scales :  149.153, 149.153, 119.323, 95.458, 76.366, 61.093, 48.875, 39.100, 31.280, 25.024, 20.019, 16.015, 12.812, 10.250, 8.200, 6.560, 5.248, 4.198, 3.359, 2.687, 2.150, 1.720, 1.376, 1.101, 0.880, 0.704, 0.563, 0.451, 0.361, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.200) and 15 (σ=6.560).
# Keep 91015/315704 = 28.8% of the coarse cost matrix.
# Keep 84294/287296 = 29.3% of the coarse cost matrix.
# Keep 98289/346921 = 28.3% of the coarse cost matrix.
# OMT matching distance: 1.267536997795105, time elapsed: 1.4802260398864746
# Propagating to layer 9
# 553x623 clusters, computed at scale = 6.890
# Successive scales :  150.359, 150.359, 120.287, 96.230, 76.984, 61.587, 49.270, 39.416, 31.533, 25.226, 20.181, 16.145, 12.916, 10.333, 8.266, 6.613, 5.290, 4.232, 3.386, 2.709, 2.167, 1.734, 1.387, 1.109, 0.888, 0.710, 0.568, 0.454, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.266) and 15 (σ=6.613).
# Keep 97774/344519 = 28.4% of the coarse cost matrix.
# Keep 88099/305809 = 28.8% of the coarse cost matrix.
# Keep 107969/388129 = 27.8% of the coarse cost matrix.
# OMT matching distance: 3.038808584213257, time elapsed: 1.5516295433044434
# Propagating to layer 10
# 580x665 clusters, computed at scale = 6.958
# Successive scales :  151.833, 151.833, 121.467, 97.173, 77.739, 62.191, 49.753, 39.802, 31.842, 25.473, 20.379, 16.303, 13.042, 10.434, 8.347, 6.678, 5.342, 4.274, 3.419, 2.735, 2.188, 1.751, 1.400, 1.120, 0.896, 0.717, 0.574, 0.459, 0.367, 0.294, 0.235, 0.188, 0.150, 0.120, 0.096, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.347) and 15 (σ=6.678).
# Keep 108203/385700 = 28.1% of the coarse cost matrix.
# Keep 96102/336400 = 28.6% of the coarse cost matrix.
# Keep 120953/442225 = 27.4% of the coarse cost matrix.
# OMT matching distance: 4.493500709533691, time elapsed: 1.6791160106658936
# Sampling 113909R
# 559x600 clusters, computed at scale = 6.345
# Successive scales :  138.453, 138.453, 110.763, 88.610, 70.888, 56.711, 45.368, 36.295, 29.036, 23.229, 18.583, 14.866, 11.893, 9.514, 7.612, 6.089, 4.871, 3.897, 3.118, 2.494, 1.995, 1.596, 1.277, 1.022, 0.817, 0.654, 0.523, 0.418, 0.335, 0.268, 0.214, 0.171, 0.137, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.612) and 15 (σ=6.089).
# Keep 100346/335400 = 29.9% of the coarse cost matrix.
# Keep 93589/312481 = 30.0% of the coarse cost matrix.
# Keep 107376/360000 = 29.8% of the coarse cost matrix.
# OMT matching distance: 0.9690208435058594, time elapsed: 1.5255801677703857
# Propagating to layer 4
# 564x587 clusters, computed at scale = 6.291
# Successive scales :  137.291, 137.291, 109.833, 87.866, 70.293, 56.234, 44.988, 35.990, 28.792, 23.034, 18.427, 14.742, 11.793, 9.435, 7.548, 6.038, 4.830, 3.864, 3.092, 2.473, 1.979, 1.583, 1.266, 1.013, 0.810, 0.648, 0.519, 0.415, 0.332, 0.266, 0.212, 0.170, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.548) and 15 (σ=6.038).
# Keep 99973/331068 = 30.2% of the coarse cost matrix.
# Keep 95100/318096 = 29.9% of the coarse cost matrix.
# Keep 104841/344569 = 30.4% of the coarse cost matrix.
# OMT matching distance: 1.3094992637634277, time elapsed: 1.5193724632263184
# Propagating to layer 3
# 565x593 clusters, computed at scale = 6.243
# Successive scales :  136.244, 136.244, 108.995, 87.196, 69.757, 55.806, 44.644, 35.716, 28.572, 22.858, 18.286, 14.629, 11.703, 9.363, 7.490, 5.992, 4.794, 3.835, 3.068, 2.454, 1.963, 1.571, 1.257, 1.005, 0.804, 0.643, 0.515, 0.412, 0.329, 0.264, 0.211, 0.169, 0.135, 0.108, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=7.490) and 15 (σ=5.992).
# Keep 102228/335045 = 30.5% of the coarse cost matrix.
# Keep 96589/319225 = 30.3% of the coarse cost matrix.
# Keep 108031/351649 = 30.7% of the coarse cost matrix.
# OMT matching distance: 1.4074434041976929, time elapsed: 1.539459228515625
# Propagating to layer 2
# 566x582 clusters, computed at scale = 6.213
# Successive scales :  135.589, 135.589, 108.471, 86.777, 69.421, 55.537, 44.430, 35.544, 28.435, 22.748, 18.198, 14.559, 11.647, 9.318, 7.454, 5.963, 4.771, 3.816, 3.053, 2.443, 1.954, 1.563, 1.251, 1.000, 0.800, 0.640, 0.512, 0.410, 0.328, 0.262, 0.210, 0.168, 0.134, 0.107, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=7.454) and 15 (σ=5.963).
# Keep 99620/329412 = 30.2% of the coarse cost matrix.
# Keep 96676/320356 = 30.2% of the coarse cost matrix.
# Keep 102510/338724 = 30.3% of the coarse cost matrix.
# OMT matching distance: 1.506756067276001, time elapsed: 1.5197770595550537
# Propagating to layer 1
# 553x576 clusters, computed at scale = 6.197
# Successive scales :  135.243, 135.243, 108.195, 86.556, 69.245, 55.396, 44.317, 35.453, 28.363, 22.690, 18.152, 14.522, 11.617, 9.294, 7.435, 5.948, 4.758, 3.807, 3.045, 2.436, 1.949, 1.559, 1.247, 0.998, 0.798, 0.639, 0.511, 0.409, 0.327, 0.262, 0.209, 0.167, 0.134, 0.107, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=7.435) and 15 (σ=5.948).
# Keep 96407/318528 = 30.3% of the coarse cost matrix.
# Keep 92249/305809 = 30.2% of the coarse cost matrix.
# Keep 100708/331776 = 30.4% of the coarse cost matrix.
# OMT matching distance: 1.6929926872253418, time elapsed: 1.5099353790283203
# Propagating to layer 0
# 549x563 clusters, computed at scale = 6.189
# Successive scales :  135.055, 135.055, 108.044, 86.435, 69.148, 55.318, 44.255, 35.404, 28.323, 22.658, 18.127, 14.501, 11.601, 9.281, 7.425, 5.940, 4.752, 3.801, 3.041, 2.433, 1.946, 1.557, 1.246, 0.997, 0.797, 0.638, 0.510, 0.408, 0.327, 0.261, 0.209, 0.167, 0.134, 0.107, 0.086, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=7.425) and 15 (σ=5.940).
# Keep 93848/309087 = 30.4% of the coarse cost matrix.
# Keep 91197/301401 = 30.3% of the coarse cost matrix.
# Keep 96563/316969 = 30.5% of the coarse cost matrix.
# OMT matching distance: 1.768381118774414, time elapsed: 1.514885425567627
# Propagating to layer 6
# 554x617 clusters, computed at scale = 6.408
# Successive scales :  139.839, 139.839, 111.871, 89.497, 71.598, 57.278, 45.823, 36.658, 29.326, 23.461, 18.769, 15.015, 12.012, 9.610, 7.688, 6.150, 4.920, 3.936, 3.149, 2.519, 2.015, 1.612, 1.290, 1.032, 0.825, 0.660, 0.528, 0.423, 0.338, 0.270, 0.216, 0.173, 0.138, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.688) and 15 (σ=6.150).
# Keep 102308/341818 = 29.9% of the coarse cost matrix.
# Keep 93766/306916 = 30.6% of the coarse cost matrix.
# Keep 111633/380689 = 29.3% of the coarse cost matrix.
# OMT matching distance: 1.6410436630249023, time elapsed: 1.5314092636108398
# Propagating to layer 7
# 557x632 clusters, computed at scale = 6.498
# Successive scales :  141.805, 141.805, 113.444, 90.755, 72.604, 58.083, 46.467, 37.173, 29.739, 23.791, 19.033, 15.226, 12.181, 9.745, 7.796, 6.237, 4.989, 3.991, 3.193, 2.555, 2.044, 1.635, 1.308, 1.046, 0.837, 0.670, 0.536, 0.429, 0.343, 0.274, 0.219, 0.176, 0.140, 0.112, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.796) and 15 (σ=6.237).
# Keep 104394/352024 = 29.7% of the coarse cost matrix.
# Keep 92997/310249 = 30.0% of the coarse cost matrix.
# Keep 117092/399424 = 29.3% of the coarse cost matrix.
# OMT matching distance: 1.8247222900390625, time elapsed: 1.5588371753692627
# Propagating to layer 8
# 563x628 clusters, computed at scale = 6.603
# Successive scales :  144.089, 144.089, 115.271, 92.217, 73.773, 59.019, 47.215, 37.772, 30.218, 24.174, 19.339, 15.471, 12.377, 9.902, 7.921, 6.337, 5.070, 4.056, 3.245, 2.596, 2.077, 1.661, 1.329, 1.063, 0.851, 0.680, 0.544, 0.435, 0.348, 0.279, 0.223, 0.178, 0.143, 0.114, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.921) and 15 (σ=6.337).
# Keep 104434/353564 = 29.5% of the coarse cost matrix.
# Keep 95781/316969 = 30.2% of the coarse cost matrix.
# Keep 114060/394384 = 28.9% of the coarse cost matrix.
# OMT matching distance: 2.129812240600586, time elapsed: 1.5674517154693604
# Propagating to layer 9
# 568x651 clusters, computed at scale = 6.679
# Successive scales :  145.751, 145.751, 116.601, 93.281, 74.625, 59.700, 47.760, 38.208, 30.566, 24.453, 19.562, 15.650, 12.520, 10.016, 8.013, 6.410, 5.128, 4.103, 3.282, 2.626, 2.100, 1.680, 1.344, 1.075, 0.860, 0.688, 0.551, 0.441, 0.352, 0.282, 0.226, 0.180, 0.144, 0.115, 0.092, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.013) and 15 (σ=6.410).
# Keep 107895/369768 = 29.2% of the coarse cost matrix.
# Keep 96232/322624 = 29.8% of the coarse cost matrix.
# Keep 119953/423801 = 28.3% of the coarse cost matrix.
# OMT matching distance: 3.4836225509643555, time elapsed: 1.6074984073638916
# Propagating to layer 10
# 592x674 clusters, computed at scale = 6.771
# Successive scales :  147.758, 147.758, 118.207, 94.565, 75.652, 60.522, 48.417, 38.734, 30.987, 24.790, 19.832, 15.865, 12.692, 10.154, 8.123, 6.498, 5.199, 4.159, 3.327, 2.662, 2.129, 1.704, 1.363, 1.090, 0.872, 0.698, 0.558, 0.447, 0.357, 0.286, 0.229, 0.183, 0.146, 0.117, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.123) and 15 (σ=6.498).
# Keep 113327/399008 = 28.4% of the coarse cost matrix.
# Keep 102100/350464 = 29.1% of the coarse cost matrix.
# Keep 125370/454276 = 27.6% of the coarse cost matrix.
# OMT matching distance: 4.298679351806641, time elapsed: 1.7071120738983154
# Sampling 116748R
# 482x501 clusters, computed at scale = 8.868
# Successive scales :  193.533, 193.533, 154.826, 123.861, 99.089, 79.271, 63.417, 50.733, 40.587, 32.469, 25.975, 20.780, 16.624, 13.299, 10.640, 8.512, 6.809, 5.447, 4.358, 3.486, 2.789, 2.231, 1.785, 1.428, 1.142, 0.914, 0.731, 0.585, 0.468, 0.374, 0.299, 0.240, 0.192, 0.153, 0.123, 0.098, 0.079, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=10.640) and 15 (σ=8.512).
# Keep 76894/241482 = 31.8% of the coarse cost matrix.
# Keep 74460/232324 = 32.1% of the coarse cost matrix.
# Keep 79387/251001 = 31.6% of the coarse cost matrix.
# OMT matching distance: 0.4550895690917969, time elapsed: 3.2563962936401367
# Propagating to layer 4
# 477x489 clusters, computed at scale = 8.835
# Successive scales :  192.795, 192.795, 154.236, 123.389, 98.711, 78.969, 63.175, 50.540, 40.432, 32.346, 25.876, 20.701, 16.561, 13.249, 10.599, 8.479, 6.783, 5.427, 4.341, 3.473, 2.778, 2.223, 1.778, 1.423, 1.138, 0.910, 0.728, 0.583, 0.466, 0.373, 0.298, 0.239, 0.191, 0.153, 0.122, 0.098, 0.078, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=10.599) and 15 (σ=8.479).
# Keep 74329/233253 = 31.9% of the coarse cost matrix.
# Keep 72556/227529 = 31.9% of the coarse cost matrix.
# Keep 76097/239121 = 31.8% of the coarse cost matrix.
# OMT matching distance: 0.8363173604011536, time elapsed: 4.984201431274414
# Propagating to layer 3
# 471x485 clusters, computed at scale = 8.816
# Successive scales :  192.384, 192.384, 153.907, 123.126, 98.501, 78.801, 63.040, 50.432, 40.346, 32.277, 25.821, 20.657, 16.526, 13.221, 10.576, 8.461, 6.769, 5.415, 4.332, 3.466, 2.773, 2.218, 1.774, 1.420, 1.136, 0.909, 0.727, 0.581, 0.465, 0.372, 0.298, 0.238, 0.191, 0.152, 0.122, 0.098, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=10.576) and 15 (σ=8.461).
# Keep 73168/228435 = 32.0% of the coarse cost matrix.
# Keep 71499/221841 = 32.2% of the coarse cost matrix.
# Keep 74843/235225 = 31.8% of the coarse cost matrix.
# OMT matching distance: 0.827802300453186, time elapsed: 4.75318455696106
# Propagating to layer 2
# 466x475 clusters, computed at scale = 8.808
# Successive scales :  192.213, 192.213, 153.770, 123.016, 98.413, 78.730, 62.984, 50.387, 40.310, 32.248, 25.798, 20.639, 16.511, 13.209, 10.567, 8.454, 6.763, 5.410, 4.328, 3.463, 2.770, 2.216, 1.773, 1.418, 1.135, 0.908, 0.726, 0.581, 0.465, 0.372, 0.297, 0.238, 0.190, 0.152, 0.122, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=10.567) and 15 (σ=8.454).
# Keep 70979/221350 = 32.1% of the coarse cost matrix.
# Keep 69890/217156 = 32.2% of the coarse cost matrix.
# Keep 72035/225625 = 31.9% of the coarse cost matrix.
# OMT matching distance: 0.8075178265571594, time elapsed: 4.68295431137085
# Propagating to layer 1
# 458x461 clusters, computed at scale = 8.804
# Successive scales :  192.132, 192.132, 153.705, 122.964, 98.371, 78.697, 62.958, 50.366, 40.293, 32.234, 25.787, 20.630, 16.504, 13.203, 10.563, 8.450, 6.760, 5.408, 4.326, 3.461, 2.769, 2.215, 1.772, 1.418, 1.134, 0.907, 0.726, 0.581, 0.465, 0.372, 0.297, 0.238, 0.190, 0.152, 0.122, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=10.563) and 15 (σ=8.450).
# Keep 67740/211138 = 32.1% of the coarse cost matrix.
# Keep 67798/209764 = 32.3% of the coarse cost matrix.
# Keep 67667/212521 = 31.8% of the coarse cost matrix.
# OMT matching distance: 0.8072532415390015, time elapsed: 4.589524030685425
# Propagating to layer 0
# 434x447 clusters, computed at scale = 8.808
# Successive scales :  192.208, 192.208, 153.767, 123.013, 98.411, 78.728, 62.983, 50.386, 40.309, 32.247, 25.798, 20.638, 16.511, 13.208, 10.567, 8.453, 6.763, 5.410, 4.328, 3.463, 2.770, 2.216, 1.773, 1.418, 1.135, 0.908, 0.726, 0.581, 0.465, 0.372, 0.297, 0.238, 0.190, 0.152, 0.122, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=10.567) and 15 (σ=8.453).
# Keep 62504/193998 = 32.2% of the coarse cost matrix.
# Keep 61282/188356 = 32.5% of the coarse cost matrix.
# Keep 63847/199809 = 32.0% of the coarse cost matrix.
# OMT matching distance: 0.8849455118179321, time elapsed: 4.745577335357666
# Propagating to layer 6
# 458x503 clusters, computed at scale = 8.922
# Successive scales :  194.700, 194.700, 155.760, 124.608, 99.687, 79.749, 63.799, 51.040, 40.832, 32.665, 26.132, 20.906, 16.725, 13.380, 10.704, 8.563, 6.850, 5.480, 4.384, 3.507, 2.806, 2.245, 1.796, 1.437, 1.149, 0.919, 0.736, 0.588, 0.471, 0.377, 0.301, 0.241, 0.193, 0.154, 0.123, 0.099, 0.079, 0.063, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=10.704) and 15 (σ=8.563).
# Keep 74707/230374 = 32.4% of the coarse cost matrix.
# Keep 69058/209764 = 32.9% of the coarse cost matrix.
# Keep 80705/253009 = 31.9% of the coarse cost matrix.
# OMT matching distance: 1.4700819253921509, time elapsed: 3.1277694702148438
# Propagating to layer 7
# 469x528 clusters, computed at scale = 8.967
# Successive scales :  195.685, 195.685, 156.548, 125.238, 100.190, 80.152, 64.122, 51.298, 41.038, 32.830, 26.264, 21.011, 16.809, 13.447, 10.758, 8.606, 6.885, 5.508, 4.406, 3.525, 2.820, 2.256, 1.805, 1.444, 1.155, 0.924, 0.739, 0.591, 0.473, 0.379, 0.303, 0.242, 0.194, 0.155, 0.124, 0.099, 0.079, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=10.758) and 15 (σ=8.606).
# Keep 79211/247632 = 32.0% of the coarse cost matrix.
# Keep 70893/219961 = 32.2% of the coarse cost matrix.
# Keep 88340/278784 = 31.7% of the coarse cost matrix.
# OMT matching distance: 1.697930097579956, time elapsed: 3.2255547046661377
# Propagating to layer 8
# 489x547 clusters, computed at scale = 9.001
# Successive scales :  196.419, 196.419, 157.135, 125.708, 100.567, 80.453, 64.363, 51.490, 41.192, 32.954, 26.363, 21.090, 16.872, 13.498, 10.798, 8.639, 6.911, 5.529, 4.423, 3.538, 2.831, 2.265, 1.812, 1.449, 1.159, 0.928, 0.742, 0.594, 0.475, 0.380, 0.304, 0.243, 0.195, 0.156, 0.124, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=10.798) and 15 (σ=8.639).
# Keep 84646/267483 = 31.6% of the coarse cost matrix.
# Keep 76463/239121 = 32.0% of the coarse cost matrix.
# Keep 93623/299209 = 31.3% of the coarse cost matrix.
# OMT matching distance: 1.9801225662231445, time elapsed: 3.3427653312683105
# Propagating to layer 9
# 509x578 clusters, computed at scale = 9.051
# Successive scales :  197.508, 197.508, 158.006, 126.405, 101.124, 80.899, 64.719, 51.776, 41.420, 33.136, 26.509, 21.207, 16.966, 13.573, 10.858, 8.686, 6.949, 5.559, 4.447, 3.558, 2.846, 2.277, 1.822, 1.457, 1.166, 0.933, 0.746, 0.597, 0.478, 0.382, 0.306, 0.245, 0.196, 0.156, 0.125, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=10.858) and 15 (σ=8.686).
# Keep 92091/294202 = 31.3% of the coarse cost matrix.
# Keep 82151/259081 = 31.7% of the coarse cost matrix.
# Keep 102580/334084 = 30.7% of the coarse cost matrix.
# OMT matching distance: 3.6374878883361816, time elapsed: 1.5786786079406738
# Propagating to layer 10
# 534x617 clusters, computed at scale = 9.131
# Successive scales :  199.259, 199.259, 159.407, 127.526, 102.020, 81.616, 65.293, 52.234, 41.788, 33.430, 26.744, 21.395, 17.116, 13.693, 10.954, 8.763, 7.011, 5.609, 4.487, 3.590, 2.872, 2.297, 1.838, 1.470, 1.176, 0.941, 0.753, 0.602, 0.482, 0.385, 0.308, 0.247, 0.197, 0.158, 0.126, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=10.954) and 15 (σ=8.763).
# Keep 101482/329478 = 30.8% of the coarse cost matrix.
# Keep 89196/285156 = 31.3% of the coarse cost matrix.
# Keep 114623/380689 = 30.1% of the coarse cost matrix.
# OMT matching distance: 5.932856559753418, time elapsed: 1.750521183013916
# Sampling 117243R
# 603x647 clusters, computed at scale = 5.588
# Successive scales :  121.940, 121.940, 97.552, 78.042, 62.434, 49.947, 39.957, 31.966, 25.573, 20.458, 16.367, 13.093, 10.475, 8.380, 6.704, 5.363, 4.290, 3.432, 2.746, 2.197, 1.757, 1.406, 1.125, 0.900, 0.720, 0.576, 0.461, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=6.704) and 15 (σ=5.363).
# Keep 111532/390141 = 28.6% of the coarse cost matrix.
# Keep 105243/363609 = 28.9% of the coarse cost matrix.
# Keep 118221/418609 = 28.2% of the coarse cost matrix.
# OMT matching distance: 0.2710763216018677, time elapsed: 1.5457041263580322
# Propagating to layer 4
# 602x635 clusters, computed at scale = 5.556
# Successive scales :  121.239, 121.239, 96.991, 77.593, 62.074, 49.659, 39.728, 31.782, 25.426, 20.340, 16.272, 13.018, 10.414, 8.331, 6.665, 5.332, 4.266, 3.413, 2.730, 2.184, 1.747, 1.398, 1.118, 0.895, 0.716, 0.573, 0.458, 0.366, 0.293, 0.235, 0.188, 0.150, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=6.665) and 15 (σ=5.332).
# Keep 110250/382270 = 28.8% of the coarse cost matrix.
# Keep 104240/362404 = 28.8% of the coarse cost matrix.
# Keep 116621/403225 = 28.9% of the coarse cost matrix.
# OMT matching distance: 0.45027244091033936, time elapsed: 1.5420498847961426
# Propagating to layer 3
# 607x639 clusters, computed at scale = 5.526
# Successive scales :  120.598, 120.598, 96.479, 77.183, 61.746, 49.397, 39.518, 31.614, 25.291, 20.233, 16.186, 12.949, 10.359, 8.287, 6.630, 5.304, 4.243, 3.395, 2.716, 2.173, 1.738, 1.390, 1.112, 0.890, 0.712, 0.570, 0.456, 0.364, 0.292, 0.233, 0.187, 0.149, 0.119, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=6.630) and 15 (σ=5.304).
# Keep 112328/387873 = 29.0% of the coarse cost matrix.
# Keep 106561/368449 = 28.9% of the coarse cost matrix.
# Keep 118387/408321 = 29.0% of the coarse cost matrix.
# OMT matching distance: 0.43004733324050903, time elapsed: 1.5466854572296143
# Propagating to layer 2
# 606x634 clusters, computed at scale = 5.516
# Successive scales :  120.379, 120.379, 96.303, 77.043, 61.634, 49.307, 39.446, 31.557, 25.245, 20.196, 16.157, 12.926, 10.340, 8.272, 6.618, 5.294, 4.235, 3.388, 2.711, 2.169, 1.735, 1.388, 1.110, 0.888, 0.711, 0.568, 0.455, 0.364, 0.291, 0.233, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=6.618) and 15 (σ=5.294).
# Keep 111571/384204 = 29.0% of the coarse cost matrix.
# Keep 106930/367236 = 29.1% of the coarse cost matrix.
# Keep 116502/401956 = 29.0% of the coarse cost matrix.
# OMT matching distance: 0.4445737600326538, time elapsed: 1.5464239120483398
# Propagating to layer 1
# 606x610 clusters, computed at scale = 5.507
# ...
# OMT matching distance: 3.563371181488037, time elapsed: 1.5833446979522705
# Propagating to layer 10
# 584x694 clusters, computed at scale = 7.199
# Successive scales :  157.100, 157.100, 125.680, 100.544, 80.435, 64.348, 51.479, 41.183, 32.946, 26.357, 21.086, 16.869, 13.495, 10.796, 8.637, 6.909, 5.527, 4.422, 3.538, 2.830, 2.264, 1.811, 1.449, 1.159, 0.927, 0.742, 0.594, 0.475, 0.380, 0.304, 0.243, 0.194, 0.156, 0.124, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.637) and 15 (σ=6.909).
# Keep 113639/405296 = 28.0% of the coarse cost matrix.
# Keep 99110/341056 = 29.1% of the coarse cost matrix.
# Keep 128844/481636 = 26.8% of the coarse cost matrix.
# OMT matching distance: 7.708976745605469, time elapsed: 1.8085815906524658
# Sampling 120267L
# 330x348 clusters, computed at scale = 12.066
# Successive scales :  263.309, 263.309, 210.647, 168.518, 134.814, 107.851, 86.281, 69.025, 55.220, 44.176, 35.341, 28.273, 22.618, 18.094, 14.476, 11.580, 9.264, 7.411, 5.929, 4.743, 3.795, 3.036, 2.429, 1.943, 1.554, 1.243, 0.995, 0.796, 0.637, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.134, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.476) and 15 (σ=11.580).
# Keep 39328/114840 = 34.2% of the coarse cost matrix.
# Keep 37526/108900 = 34.5% of the coarse cost matrix.
# Keep 41240/121104 = 34.1% of the coarse cost matrix.
# OMT matching distance: 0.8053271770477295, time elapsed: 3.697857141494751
# Propagating to layer 4
# 329x337 clusters, computed at scale = 12.061
# Successive scales :  263.198, 263.198, 210.559, 168.447, 134.758, 107.806, 86.245, 68.996, 55.197, 44.157, 35.326, 28.261, 22.609, 18.087, 14.469, 11.576, 9.260, 7.408, 5.927, 4.741, 3.793, 3.034, 2.428, 1.942, 1.554, 1.243, 0.994, 0.795, 0.636, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.133, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.469) and 15 (σ=11.576).
# Keep 38051/110873 = 34.3% of the coarse cost matrix.
# Keep 37387/108241 = 34.5% of the coarse cost matrix.
# Keep 38763/113569 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.2117801904678345, time elapsed: 3.615190029144287
# Propagating to layer 3
# 318x330 clusters, computed at scale = 12.063
# Successive scales :  263.239, 263.239, 210.591, 168.473, 134.778, 107.823, 86.258, 69.007, 55.205, 44.164, 35.331, 28.265, 22.612, 18.090, 14.472, 11.577, 9.262, 7.410, 5.928, 4.742, 3.794, 3.035, 2.428, 1.942, 1.554, 1.243, 0.994, 0.796, 0.636, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.133, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.472) and 15 (σ=11.577).
# Keep 35960/104940 = 34.3% of the coarse cost matrix.
# Keep 34784/101124 = 34.4% of the coarse cost matrix.
# Keep 37158/108900 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.2489778995513916, time elapsed: 3.5356948375701904
# Propagating to layer 2
# 316x320 clusters, computed at scale = 12.060
# Successive scales :  263.175, 263.175, 210.540, 168.432, 134.746, 107.797, 86.237, 68.990, 55.192, 44.153, 35.323, 28.258, 22.607, 18.085, 14.468, 11.575, 9.260, 7.408, 5.926, 4.741, 3.793, 3.034, 2.427, 1.942, 1.554, 1.243, 0.994, 0.795, 0.636, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.133, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.468) and 15 (σ=11.575).
# Keep 34626/101120 = 34.2% of the coarse cost matrix.
# Keep 34250/99856 = 34.3% of the coarse cost matrix.
# Keep 34968/102400 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.3051562309265137, time elapsed: 3.4760046005249023
# Propagating to layer 1
# 306x316 clusters, computed at scale = 12.060
# Successive scales :  263.168, 263.168, 210.535, 168.428, 134.742, 107.794, 86.235, 68.988, 55.190, 44.152, 35.322, 28.257, 22.606, 18.085, 14.468, 11.574, 9.259, 7.408, 5.926, 4.741, 3.793, 3.034, 2.427, 1.942, 1.553, 1.243, 0.994, 0.795, 0.636, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.133, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.468) and 15 (σ=11.574).
# Keep 32943/96696 = 34.1% of the coarse cost matrix.
# Keep 31940/93636 = 34.1% of the coarse cost matrix.
# Keep 33970/99856 = 34.0% of the coarse cost matrix.
# OMT matching distance: 1.611785888671875, time elapsed: 3.4321792125701904
# Propagating to layer 0
# 304x309 clusters, computed at scale = 12.063
# Successive scales :  263.250, 263.250, 210.600, 168.480, 134.784, 107.827, 86.262, 69.009, 55.208, 44.166, 35.333, 28.266, 22.613, 18.090, 14.472, 11.578, 9.262, 7.410, 5.928, 4.742, 3.794, 3.035, 2.428, 1.942, 1.554, 1.243, 0.995, 0.796, 0.637, 0.509, 0.407, 0.326, 0.261, 0.209, 0.167, 0.133, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.472) and 15 (σ=11.578).
# Keep 31980/93936 = 34.0% of the coarse cost matrix.
# Keep 31430/92416 = 34.0% of the coarse cost matrix.
# Keep 32453/95481 = 34.0% of the coarse cost matrix.
# OMT matching distance: 3.9812240600585938, time elapsed: 3.3692407608032227
# Propagating to layer 6
# 329x359 clusters, computed at scale = 12.069
# Successive scales :  263.366, 263.366, 210.693, 168.554, 134.844, 107.875, 86.300, 69.040, 55.232, 44.186, 35.348, 28.279, 22.623, 18.098, 14.479, 11.583, 9.266, 7.413, 5.930, 4.744, 3.796, 3.036, 2.429, 1.943, 1.555, 1.244, 0.995, 0.796, 0.637, 0.509, 0.408, 0.326, 0.261, 0.209, 0.167, 0.134, 0.107, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.479) and 15 (σ=11.583).
# Keep 40513/118111 = 34.3% of the coarse cost matrix.
# Keep 37379/108241 = 34.5% of the coarse cost matrix.
# Keep 43925/128881 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.468995213508606, time elapsed: 3.736055374145508
# Propagating to layer 7
# 337x367 clusters, computed at scale = 12.084
# Successive scales :  263.709, 263.709, 210.967, 168.774, 135.019, 108.015, 86.412, 69.130, 55.304, 44.243, 35.394, 28.316, 22.652, 18.122, 14.498, 11.598, 9.278, 7.423, 5.938, 4.751, 3.800, 3.040, 2.432, 1.946, 1.557, 1.245, 0.996, 0.797, 0.638, 0.510, 0.408, 0.326, 0.261, 0.209, 0.167, 0.134, 0.107, 0.086, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.498) and 15 (σ=11.598).
# Keep 42364/123679 = 34.3% of the coarse cost matrix.
# Keep 39081/113569 = 34.4% of the coarse cost matrix.
# Keep 45907/134689 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.5798362493515015, time elapsed: 3.836700677871704
# Propagating to layer 8
# 350x380 clusters, computed at scale = 12.097
# Successive scales :  263.977, 263.977, 211.182, 168.945, 135.156, 108.125, 86.500, 69.200, 55.360, 44.288, 35.430, 28.344, 22.675, 18.140, 14.512, 11.610, 9.288, 7.430, 5.944, 4.755, 3.804, 3.043, 2.435, 1.948, 1.558, 1.247, 0.997, 0.798, 0.638, 0.511, 0.408, 0.327, 0.261, 0.209, 0.167, 0.134, 0.107, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.512) and 15 (σ=11.610).
# Keep 45380/133000 = 34.1% of the coarse cost matrix.
# Keep 41826/122500 = 34.1% of the coarse cost matrix.
# Keep 49248/144400 = 34.1% of the coarse cost matrix.
# OMT matching distance: 1.5446727275848389, time elapsed: 3.9575088024139404
# Propagating to layer 9
# 372x398 clusters, computed at scale = 12.113
# Successive scales :  264.343, 264.343, 211.474, 169.179, 135.343, 108.275, 86.620, 69.296, 55.437, 44.349, 35.479, 28.384, 22.707, 18.165, 14.532, 11.626, 9.301, 7.441, 5.952, 4.762, 3.810, 3.048, 2.438, 1.951, 1.560, 1.248, 0.999, 0.799, 0.639, 0.511, 0.409, 0.327, 0.262, 0.209, 0.168, 0.134, 0.107, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.532) and 15 (σ=11.626).
# Keep 50625/148056 = 34.2% of the coarse cost matrix.
# Keep 47294/138384 = 34.2% of the coarse cost matrix.
# Keep 54164/158404 = 34.2% of the coarse cost matrix.
# OMT matching distance: 1.649872064590454, time elapsed: 4.172422647476196
# Propagating to layer 10
# 382x426 clusters, computed at scale = 12.148
# Successive scales :  265.093, 265.093, 212.074, 169.659, 135.728, 108.582, 86.866, 69.493, 55.594, 44.475, 35.580, 28.464, 22.771, 18.217, 14.574, 11.659, 9.327, 7.462, 5.969, 4.775, 3.820, 3.056, 2.445, 1.956, 1.565, 1.252, 1.001, 0.801, 0.641, 0.513, 0.410, 0.328, 0.263, 0.210, 0.168, 0.134, 0.108, 0.086, 0.069, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=14.574) and 15 (σ=11.659).
# Keep 55609/162732 = 34.2% of the coarse cost matrix.
# Keep 49868/145924 = 34.2% of the coarse cost matrix.
# Keep 62258/181476 = 34.3% of the coarse cost matrix.
# OMT matching distance: 3.3944060802459717, time elapsed: 4.396569490432739
# Sampling 120937L
# 528x571 clusters, computed at scale = 6.426
# Successive scales :  140.242, 140.242, 112.193, 89.755, 71.804, 57.443, 45.954, 36.764, 29.411, 23.529, 18.823, 15.058, 12.047, 9.637, 7.710, 6.168, 4.934, 3.947, 3.158, 2.526, 2.021, 1.617, 1.294, 1.035, 0.828, 0.662, 0.530, 0.424, 0.339, 0.271, 0.217, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.710) and 15 (σ=6.168).
# Keep 86784/301488 = 28.8% of the coarse cost matrix.
# Keep 81294/278784 = 29.2% of the coarse cost matrix.
# Keep 92693/326041 = 28.4% of the coarse cost matrix.
# OMT matching distance: 0.28699925541877747, time elapsed: 1.419666051864624
# Propagating to layer 4
# 542x563 clusters, computed at scale = 6.386
# Successive scales :  139.348, 139.348, 111.479, 89.183, 71.346, 57.077, 45.662, 36.529, 29.223, 23.379, 18.703, 14.962, 11.970, 9.576, 7.661, 6.129, 4.903, 3.922, 3.138, 2.510, 2.008, 1.607, 1.285, 1.028, 0.823, 0.658, 0.526, 0.421, 0.337, 0.270, 0.216, 0.173, 0.138, 0.110, 0.088, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.661) and 15 (σ=6.129).
# Keep 87672/305146 = 28.7% of the coarse cost matrix.
# Keep 84858/293764 = 28.9% of the coarse cost matrix.
# Keep 90651/316969 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.5586225986480713, time elapsed: 1.4466121196746826
# Propagating to layer 3
# 534x548 clusters, computed at scale = 6.337
# Successive scales :  138.290, 138.290, 110.632, 88.506, 70.805, 56.644, 45.315, 36.252, 29.002, 23.201, 18.561, 14.849, 11.879, 9.503, 7.603, 6.082, 4.866, 3.893, 3.114, 2.491, 1.993, 1.594, 1.276, 1.020, 0.816, 0.653, 0.522, 0.418, 0.334, 0.267, 0.214, 0.171, 0.137, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.603) and 15 (σ=6.082).
# Keep 84353/292632 = 28.8% of the coarse cost matrix.
# Keep 82754/285156 = 29.0% of the coarse cost matrix.
# Keep 85996/300304 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.5084991455078125, time elapsed: 1.422323226928711
# Propagating to layer 2
# 539x553 clusters, computed at scale = 6.302
# Successive scales :  137.523, 137.523, 110.018, 88.015, 70.412, 56.329, 45.063, 36.051, 28.841, 23.072, 18.458, 14.766, 11.813, 9.450, 7.560, 6.048, 4.839, 3.871, 3.097, 2.477, 1.982, 1.586, 1.268, 1.015, 0.812, 0.649, 0.520, 0.416, 0.333, 0.266, 0.213, 0.170, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.560) and 15 (σ=6.048).
# Keep 85510/298067 = 28.7% of the coarse cost matrix.
# Keep 83999/290521 = 28.9% of the coarse cost matrix.
# Keep 86981/305809 = 28.4% of the coarse cost matrix.
# OMT matching distance: 0.5029457807540894, time elapsed: 1.4353344440460205
# Propagating to layer 1
# 527x541 clusters, computed at scale = 6.279
# Successive scales :  137.034, 137.034, 109.627, 87.701, 70.161, 56.129, 44.903, 35.923, 28.738, 22.990, 18.392, 14.714, 11.771, 9.417, 7.533, 6.027, 4.821, 3.857, 3.086, 2.469, 1.975, 1.580, 1.264, 1.011, 0.809, 0.647, 0.518, 0.414, 0.331, 0.265, 0.212, 0.170, 0.136, 0.109, 0.087, 0.069, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.533) and 15 (σ=6.027).
# Keep 81988/285107 = 28.8% of the coarse cost matrix.
# Keep 80591/277729 = 29.0% of the coarse cost matrix.
# Keep 83267/292681 = 28.4% of the coarse cost matrix.
# OMT matching distance: 0.5202993154525757, time elapsed: 1.4093959331512451
# Propagating to layer 0
# 504x520 clusters, computed at scale = 6.279
# Successive scales :  137.024, 137.024, 109.619, 87.695, 70.156, 56.125, 44.900, 35.920, 28.736, 22.989, 18.391, 14.713, 11.770, 9.416, 7.533, 6.026, 4.821, 3.857, 3.086, 2.468, 1.975, 1.580, 1.264, 1.011, 0.809, 0.647, 0.518, 0.414, 0.331, 0.265, 0.212, 0.170, 0.136, 0.109, 0.087, 0.069, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.533) and 15 (σ=6.026).
# Keep 75122/262080 = 28.7% of the coarse cost matrix.
# Keep 73708/254016 = 29.0% of the coarse cost matrix.
# Keep 76598/270400 = 28.3% of the coarse cost matrix.
# OMT matching distance: 0.5974957346916199, time elapsed: 1.373020887374878
# Propagating to layer 6
# 511x578 clusters, computed at scale = 6.494
# Successive scales :  141.717, 141.717, 113.374, 90.699, 72.559, 58.047, 46.438, 37.150, 29.720, 23.776, 19.021, 15.217, 12.173, 9.739, 7.791, 6.233, 4.986, 3.989, 3.191, 2.553, 2.042, 1.634, 1.307, 1.046, 0.837, 0.669, 0.535, 0.428, 0.343, 0.274, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.791) and 15 (σ=6.233).
# Keep 85768/295358 = 29.0% of the coarse cost matrix.
# Keep 77395/261121 = 29.6% of the coarse cost matrix.
# Keep 94762/334084 = 28.4% of the coarse cost matrix.
# OMT matching distance: 1.1606924533843994, time elapsed: 1.4346141815185547
# Propagating to layer 7
# 531x595 clusters, computed at scale = 6.603
# Successive scales :  144.102, 144.102, 115.281, 92.225, 73.780, 59.024, 47.219, 37.775, 30.220, 24.176, 19.341, 15.473, 12.378, 9.903, 7.922, 6.338, 5.070, 4.056, 3.245, 2.596, 2.077, 1.661, 1.329, 1.063, 0.851, 0.681, 0.544, 0.436, 0.348, 0.279, 0.223, 0.178, 0.143, 0.114, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.922) and 15 (σ=6.338).
# Keep 90987/315945 = 28.8% of the coarse cost matrix.
# Keep 83691/281961 = 29.7% of the coarse cost matrix.
# Keep 98633/354025 = 27.9% of the coarse cost matrix.
# OMT matching distance: 1.7042210102081299, time elapsed: 1.4867017269134521
# Propagating to layer 8
# 535x616 clusters, computed at scale = 6.750
# Successive scales :  147.296, 147.296, 117.837, 94.270, 75.416, 60.333, 48.266, 38.613, 30.890, 24.712, 19.770, 15.816, 12.653, 10.122, 8.098, 6.478, 5.183, 4.146, 3.317, 2.653, 2.123, 1.698, 1.359, 1.087, 0.869, 0.696, 0.556, 0.445, 0.356, 0.285, 0.228, 0.182, 0.146, 0.117, 0.093, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.098) and 15 (σ=6.478).
# Keep 95751/329560 = 29.1% of the coarse cost matrix.
# Keep 85373/286225 = 29.8% of the coarse cost matrix.
# Keep 106884/379456 = 28.2% of the coarse cost matrix.
# OMT matching distance: 2.635570526123047, time elapsed: 1.5234849452972412
# Propagating to layer 9
# 524x641 clusters, computed at scale = 6.989
# Successive scales :  152.527, 152.527, 122.022, 97.618, 78.094, 62.475, 49.980, 39.984, 31.987, 25.590, 20.472, 16.378, 13.102, 10.482, 8.385, 6.708, 5.367, 4.293, 3.435, 2.748, 2.198, 1.759, 1.407, 1.125, 0.900, 0.720, 0.576, 0.461, 0.369, 0.295, 0.236, 0.189, 0.151, 0.121, 0.097, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.385) and 15 (σ=6.708).
# Keep 97890/335884 = 29.1% of the coarse cost matrix.
# Keep 81816/274576 = 29.8% of the coarse cost matrix.
# Keep 115869/410881 = 28.2% of the coarse cost matrix.
# OMT matching distance: 4.456437110900879, time elapsed: 1.5524213314056396
# Propagating to layer 10
# 559x690 clusters, computed at scale = 7.194
# Successive scales :  156.989, 156.989, 125.591, 100.473, 80.378, 64.303, 51.442, 41.154, 32.923, 26.338, 21.071, 16.857, 13.485, 10.788, 8.631, 6.904, 5.524, 4.419, 3.535, 2.828, 2.262, 1.810, 1.448, 1.158, 0.927, 0.741, 0.593, 0.474, 0.380, 0.304, 0.243, 0.194, 0.155, 0.124, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.631) and 15 (σ=6.904).
# Keep 110308/385710 = 28.6% of the coarse cost matrix.
# Keep 92961/312481 = 29.7% of the coarse cost matrix.
# Keep 129260/476100 = 27.1% of the coarse cost matrix.
# OMT matching distance: 8.218006134033203, time elapsed: 1.7802772521972656
# Sampling 121250L

# %%
# Average the map between subjects
uclm_label_consensus = np.mean(uclm_label_map, 2)

# Consensus labeling
pd_consensus = vtk_make_pd(v_temp, f_temp)
for label in range(uclm_label_consensus.shape[2]):
    layer_prob = uclm_label_consensus[:,:,label].astype(np.float32)
    vtk_set_point_array(pd_consensus, f'uclm_plab_{label:03d}', layer_prob)

save_vtk(pd_consensus, 'tmp/template_ec_test.vtk', binary=True)

# %% [markdown]
# ### Now do the same for the nnU-Net segmentations!

# %%
import glob
test_ids = [ os.path.basename(x) for x in glob.glob('/data/pauly2/ashs_xv/work/fold_0/nnunet/*') ]

# %%
# Keep track of ASHS importers and workspaces created
test_data = {}

# Run basic Nighres for each subject
for id in test_ids:
    # Get the side
    side = 'left' if id.endswith('L') else 'right'

    # Create the output dir
    crashs_dir = os.path.join('/data/pauly2/ashs_xv/work/fold_0/crashs_apply_nnunet', id)
    workspace = Workspace(crashs_dir, id, side)

    # Store the data
    test_data[id] = { 'side': side, 'workspace': workspace }

# %%
from pykeops.torch import LazyTensor
def laplacian_kernel(x, y, sigma=0.1):
    x_i = LazyTensor(x[:, None, :])  # (M, 1, 1)
    y_j = LazyTensor(y[None, :, :])  # (1, N, 1)
    D_ij = ((x_i - y_j) ** 2).sum(-1)  # (M, N) symbolic matrix of squared distances
    return (-D_ij.sqrt() / sigma).exp()

# %%
for i, id in enumerate(test_ids):

    # Read the segmentation that we want to apply this labeling to
    fn_target = f'/data/pauly2/ashs_xv/work/fold_0/nnunet/{id}/{id}_ivseg_ashs_upsample.nii.gz'
    img = sitk.ReadImage(fn_target, outputPixelType=sitk.sitkFloat32)

    # Extract pixels of interest
    x_img = sitk.GetArrayViewFromImage(img)
    x_img = np.sum(np.stack([x_img == l for l in uclm_group_labels_gm]), axis=0)

    # Get the pixel coordinates - these are flipped so they correspond to ITK
    nz = np.flip(np.transpose(np.stack(np.nonzero(x_img)).astype(np.float32)), 1)

    # Map each of these coordinates into the Nighres mesh coordinates
    img_ref = sitk.ReadImage(test_data[id]['workspace'].cruise_gm_prob)
    y = np.array([img_ref.TransformPhysicalPointToContinuousIndex(
        img.TransformContinuousIndexToPhysicalPoint(nz[j,:].tolist())) for j in range(nz.shape[0]) ])
    
    # Load the fitted template with its interpolation arrays
    pd_i_fit = load_vtk(test_data[id]['workspace'].fit_omt_match)
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the midsurface mesh from cruise and map the template to this space
    pd_hw_nighres = load_vtk(test_data[id]['workspace'].fn_cruise('mtl_avg_l2m-mesh.vtk'))
    v_temp_to_hw_nighres = np.einsum('vij,vi->vj', vtk_get_points(pd_hw_nighres)[v_int,:], w_int)
    pd_temp_to_hw_nighres = vtk_make_pd(v_temp_to_hw_nighres, vtk_get_triangles(pd_i_fit))

    # Propagate this fitted mesh through the levelset layers using OMT
    img_ls = sitk.ReadImage(test_data[id]['workspace'].fn_cruise('mtl_layering-boundaries.nii.gz'))
    prof_meshes, mid_layer = profile_meshing_omt(img_ls, source_mesh=pd_temp_to_hw_nighres)

    # Load the Nighres meshes - these are the coordinates from which we wish to interpolate
    mesh_coord, mesh_label = [], []
    for layer, pd_layer in enumerate(prof_meshes):

        # Map template vertices to that layer and append to list of all interpolated coords
        mesh_coord.append(vtk_get_points(pd_layer))
        mesh_label.append(uclm_label_consensus[:,layer,:])

    # Put the coordinates together - these are the points we want to interpolate from
    x = np.concatenate(mesh_coord)

    # Put the label probabilities together - these are the values we want to propagate
    b = np.concatenate(mesh_label)

    # Perform RBF interpolation, so easy!
    K_yx = laplacian_kernel(
        torch.tensor(y, dtype=torch.float32, device=device), 
        torch.tensor(x, dtype=torch.float32, device=device),
        sigma=1.0)
    b_y = (K_yx @ torch.tensor(b, dtype=torch.float32, device=device)).detach().cpu().numpy()

    # Assign the values to the vertices
    l_best = np.argmax(b_y[:,:-1], 1)
    l_best_remap = np.zeros_like(l_best)
    for k, label in enumerate(uclm_label_grouping.keys()):
        l_best_remap[l_best == k] = label
    x_img[x_img != 0] = l_best_remap

    img_result = sitk.GetImageFromArray(x_img)
    img_result.CopyInformation(img)

    # Save the image
    sitk.WriteImage(img_result, f'tmp/crashs_nnunet_fill_labels_{id}.nii.gz')
# Out:
# 609x655 clusters, computed at scale = 6.835
# Successive scales :  149.151, 149.151, 119.321, 95.457, 76.365, 61.092, 48.874, 39.099, 31.279, 25.023, 20.019, 16.015, 12.812, 10.250, 8.200, 6.560, 5.248, 4.198, 3.359, 2.687, 2.149, 1.720, 1.376, 1.101, 0.880, 0.704, 0.563, 0.451, 0.361, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.200) and 15 (σ=6.560).
# Keep 114380/398895 = 28.7% of the coarse cost matrix.
# Keep 106887/370881 = 28.8% of the coarse cost matrix.
# Keep 122079/429025 = 28.5% of the coarse cost matrix.
# OMT matching distance: 1.2052192687988281, time elapsed: 1.6201815605163574
# Propagating to layer 4
# 611x632 clusters, computed at scale = 6.820
# Successive scales :  148.825, 148.825, 119.060, 95.248, 76.198, 60.959, 48.767, 39.014, 31.211, 24.969, 19.975, 15.980, 12.784, 10.227, 8.182, 6.545, 5.236, 4.189, 3.351, 2.681, 2.145, 1.716, 1.373, 1.098, 0.879, 0.703, 0.562, 0.450, 0.360, 0.288, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.182) and 15 (σ=6.545).
# Keep 110791/386152 = 28.7% of the coarse cost matrix.
# Keep 107315/373321 = 28.7% of the coarse cost matrix.
# Keep 114456/399424 = 28.7% of the coarse cost matrix.
# OMT matching distance: 0.6603965759277344, time elapsed: 1.6064422130584717
# Propagating to layer 3
# 598x607 clusters, computed at scale = 6.815
# Successive scales :  148.718, 148.718, 118.974, 95.180, 76.144, 60.915, 48.732, 38.986, 31.188, 24.951, 19.961, 15.968, 12.775, 10.220, 8.176, 6.541, 5.233, 4.186, 3.349, 2.679, 2.143, 1.715, 1.372, 1.097, 0.878, 0.702, 0.562, 0.449, 0.360, 0.288, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.176) and 15 (σ=6.541).
# Keep 104662/362986 = 28.8% of the coarse cost matrix.
# Keep 103858/357604 = 29.0% of the coarse cost matrix.
# Keep 105545/368449 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.6306694746017456, time elapsed: 1.5644652843475342
# Propagating to layer 2
# 585x600 clusters, computed at scale = 6.808
# Successive scales :  148.571, 148.571, 118.857, 95.085, 76.068, 60.855, 48.684, 38.947, 31.158, 24.926, 19.941, 15.953, 12.762, 10.210, 8.168, 6.534, 5.227, 4.182, 3.346, 2.676, 2.141, 1.713, 1.370, 1.096, 0.877, 0.702, 0.561, 0.449, 0.359, 0.287, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.168) and 15 (σ=6.534).
# Keep 100856/351000 = 28.7% of the coarse cost matrix.
# Keep 98951/342225 = 28.9% of the coarse cost matrix.
# Keep 102786/360000 = 28.6% of the coarse cost matrix.
# OMT matching distance: 0.6184346675872803, time elapsed: 1.5389094352722168
# Propagating to layer 1
# 579x600 clusters, computed at scale = 6.808
# Successive scales :  148.575, 148.575, 118.860, 95.088, 76.070, 60.856, 48.685, 38.948, 31.158, 24.927, 19.941, 15.953, 12.762, 10.210, 8.168, 6.534, 5.228, 4.182, 3.346, 2.676, 2.141, 1.713, 1.370, 1.096, 0.877, 0.702, 0.561, 0.449, 0.359, 0.287, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.168) and 15 (σ=6.534).
# Keep 99870/347400 = 28.7% of the coarse cost matrix.
# Keep 96267/335241 = 28.7% of the coarse cost matrix.
# Keep 103502/360000 = 28.8% of the coarse cost matrix.
# OMT matching distance: 0.6460015177726746, time elapsed: 1.5409836769104004
# Propagating to layer 0
# 564x584 clusters, computed at scale = 6.810
# Successive scales :  148.605, 148.605, 118.884, 95.107, 76.086, 60.869, 48.695, 38.956, 31.165, 24.932, 19.945, 15.956, 12.765, 10.212, 8.170, 6.536, 5.229, 4.183, 3.346, 2.677, 2.142, 1.713, 1.371, 1.097, 0.877, 0.702, 0.561, 0.449, 0.359, 0.287, 0.230, 0.184, 0.147, 0.118, 0.094, 0.075, 0.060, 0.050
# Jump from coarse to fine between indices 14 (σ=8.170) and 15 (σ=6.536).
# Keep 95316/329376 = 28.9% of the coarse cost matrix.
# Keep 92248/318096 = 29.0% of the coarse cost matrix.
# Keep 98450/341056 = 28.9% of the coarse cost matrix.
# OMT matching distance: 0.6882182359695435, time elapsed: 1.5280876159667969
# Propagating to layer 6
# 593x665 clusters, computed at scale = 6.884
# Successive scales :  150.217, 150.217, 120.174, 96.139, 76.911, 61.529, 49.223, 39.379, 31.503, 25.202, 20.162, 16.129, 12.904, 10.323, 8.258, 6.607, 5.285, 4.228, 3.383, 2.706, 2.165, 1.732, 1.386, 1.108, 0.887, 0.709, 0.568, 0.454, 0.363, 0.291, 0.232, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.258) and 15 (σ=6.607).
# Keep 113960/394345 = 28.9% of the coarse cost matrix.
# Keep 103237/351649 = 29.4% of the coarse cost matrix.
# Keep 125839/442225 = 28.5% of the coarse cost matrix.
# OMT matching distance: 0.9895147085189819, time elapsed: 1.632425308227539
# Propagating to layer 7
# 584x674 clusters, computed at scale = 6.973
# Successive scales :  152.170, 152.170, 121.736, 97.389, 77.911, 62.329, 49.863, 39.890, 31.912, 25.530, 20.424, 16.339, 13.071, 10.457, 8.366, 6.693, 5.354, 4.283, 3.427, 2.741, 2.193, 1.754, 1.404, 1.123, 0.898, 0.719, 0.575, 0.460, 0.368, 0.294, 0.235, 0.188, 0.151, 0.121, 0.096, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.366) and 15 (σ=6.693).
# Keep 114469/393616 = 29.1% of the coarse cost matrix.
# Keep 100888/341056 = 29.6% of the coarse cost matrix.
# Keep 129626/454276 = 28.5% of the coarse cost matrix.
# OMT matching distance: 1.3424153327941895, time elapsed: 1.6351585388183594
# Propagating to layer 8
# 590x674 clusters, computed at scale = 7.091
# Successive scales :  154.754, 154.754, 123.803, 99.042, 79.234, 63.387, 50.710, 40.568, 32.454, 25.963, 20.771, 16.617, 13.293, 10.635, 8.508, 6.806, 5.445, 4.356, 3.485, 2.788, 2.230, 1.784, 1.427, 1.142, 0.914, 0.731, 0.585, 0.468, 0.374, 0.299, 0.239, 0.192, 0.153, 0.123, 0.098, 0.078, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=8.508) and 15 (σ=6.806).
# Keep 115945/397660 = 29.2% of the coarse cost matrix.
# Keep 103502/348100 = 29.7% of the coarse cost matrix.
# Keep 129620/454276 = 28.5% of the coarse cost matrix.
# OMT matching distance: 1.8872933387756348, time elapsed: 1.7258381843566895
# Propagating to layer 9
# 602x686 clusters, computed at scale = 7.205
# Successive scales :  157.229, 157.229, 125.783, 100.627, 80.501, 64.401, 51.521, 41.217, 32.973, 26.379, 21.103, 16.882, 13.506, 10.805, 8.644, 6.915, 5.532, 4.426, 3.540, 2.832, 2.266, 1.813, 1.450, 1.160, 0.928, 0.742, 0.594, 0.475, 0.380, 0.304, 0.243, 0.195, 0.156, 0.125, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.644) and 15 (σ=6.915).
# Keep 117403/412972 = 28.4% of the coarse cost matrix.
# Keep 105350/362404 = 29.1% of the coarse cost matrix.
# Keep 130242/470596 = 27.7% of the coarse cost matrix.
# OMT matching distance: 2.7256016731262207, time elapsed: 1.7858293056488037
# Propagating to layer 10
# 614x714 clusters, computed at scale = 7.296
# Successive scales :  159.222, 159.222, 127.378, 101.902, 81.522, 65.217, 52.174, 41.739, 33.391, 26.713, 21.370, 17.096, 13.677, 10.942, 8.753, 7.003, 5.602, 4.482, 3.585, 2.868, 2.295, 1.836, 1.469, 1.175, 0.940, 0.752, 0.602, 0.481, 0.385, 0.308, 0.246, 0.197, 0.158, 0.126, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=8.753) and 15 (σ=7.003).
# Keep 123814/438396 = 28.2% of the coarse cost matrix.
# Keep 108498/376996 = 28.8% of the coarse cost matrix.
# Keep 140280/509796 = 27.5% of the coarse cost matrix.
# OMT matching distance: 3.8314380645751953, time elapsed: 1.8800065517425537
# 538x565 clusters, computed at scale = 6.375
# Successive scales :  139.127, 139.127, 111.302, 89.042, 71.233, 56.987, 45.589, 36.471, 29.177, 23.342, 18.673, 14.939, 11.951, 9.561, 7.649, 6.119, 4.895, 3.916, 3.133, 2.506, 2.005, 1.604, 1.283, 1.027, 0.821, 0.657, 0.526, 0.420, 0.336, 0.269, 0.215, 0.172, 0.138, 0.110, 0.088, 0.071, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.649) and 15 (σ=6.119).
# Keep 96491/303970 = 31.7% of the coarse cost matrix.
# Keep 92252/289444 = 31.9% of the coarse cost matrix.
# Keep 100917/319225 = 31.6% of the coarse cost matrix.
# OMT matching distance: 0.31116238236427307, time elapsed: 1.4635405540466309
# Propagating to layer 4
# 532x554 clusters, computed at scale = 6.358
# Successive scales :  138.739, 138.739, 110.991, 88.793, 71.034, 56.827, 45.462, 36.370, 29.096, 23.277, 18.621, 14.897, 11.918, 9.534, 7.627, 6.102, 4.881, 3.905, 3.124, 2.499, 1.999, 1.600, 1.280, 1.024, 0.819, 0.655, 0.524, 0.419, 0.335, 0.268, 0.215, 0.172, 0.137, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.627) and 15 (σ=6.102).
# Keep 94357/294728 = 32.0% of the coarse cost matrix.
# Keep 89992/283024 = 31.8% of the coarse cost matrix.
# Keep 98856/306916 = 32.2% of the coarse cost matrix.
# OMT matching distance: 0.5235404372215271, time elapsed: 1.4459831714630127
# Propagating to layer 3
# 538x543 clusters, computed at scale = 6.342
# Successive scales :  138.388, 138.388, 110.711, 88.569, 70.855, 56.684, 45.347, 36.278, 29.022, 23.218, 18.574, 14.859, 11.887, 9.510, 7.608, 6.086, 4.869, 3.895, 3.116, 2.493, 1.994, 1.596, 1.276, 1.021, 0.817, 0.654, 0.523, 0.418, 0.335, 0.268, 0.214, 0.171, 0.137, 0.110, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.608) and 15 (σ=6.086).
# Keep 94557/292134 = 32.4% of the coarse cost matrix.
# Keep 93822/289444 = 32.4% of the coarse cost matrix.
# Keep 95391/294849 = 32.4% of the coarse cost matrix.
# OMT matching distance: 0.5405844449996948, time elapsed: 1.4338877201080322
# Propagating to layer 2
# 517x529 clusters, computed at scale = 6.328
# Successive scales :  138.085, 138.085, 110.468, 88.375, 70.700, 56.560, 45.248, 36.198, 28.959, 23.167, 18.534, 14.827, 11.861, 9.489, 7.591, 6.073, 4.858, 3.887, 3.109, 2.488, 1.990, 1.592, 1.274, 1.019, 0.815, 0.652, 0.522, 0.417, 0.334, 0.267, 0.214, 0.171, 0.137, 0.109, 0.088, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.591) and 15 (σ=6.073).
# Keep 89093/273493 = 32.6% of the coarse cost matrix.
# Keep 87009/267289 = 32.6% of the coarse cost matrix.
# Keep 91229/279841 = 32.6% of the coarse cost matrix.
# OMT matching distance: 0.5827406048774719, time elapsed: 1.403130054473877
# Propagating to layer 1
# 500x508 clusters, computed at scale = 6.315
# Successive scales :  137.818, 137.818, 110.254, 88.203, 70.563, 56.450, 45.160, 36.128, 28.902, 23.122, 18.498, 14.798, 11.838, 9.471, 7.577, 6.061, 4.849, 3.879, 3.103, 2.483, 1.986, 1.589, 1.271, 1.017, 0.814, 0.651, 0.521, 0.417, 0.333, 0.267, 0.213, 0.171, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.577) and 15 (σ=6.061).
# Keep 83583/254000 = 32.9% of the coarse cost matrix.
# Keep 82404/250000 = 33.0% of the coarse cost matrix.
# Keep 84844/258064 = 32.9% of the coarse cost matrix.
# OMT matching distance: 0.6608209013938904, time elapsed: 3.1114859580993652
# Propagating to layer 0
# 481x497 clusters, computed at scale = 6.314
# Successive scales :  137.792, 137.792, 110.234, 88.187, 70.549, 56.440, 45.152, 36.121, 28.897, 23.118, 18.494, 14.795, 11.836, 9.469, 7.575, 6.060, 4.848, 3.878, 3.103, 2.482, 1.986, 1.589, 1.271, 1.017, 0.813, 0.651, 0.521, 0.416, 0.333, 0.267, 0.213, 0.171, 0.136, 0.109, 0.087, 0.070, 0.056, 0.050
# Jump from coarse to fine between indices 14 (σ=7.575) and 15 (σ=6.060).
# Keep 79911/239057 = 33.4% of the coarse cost matrix.
# Keep 77425/231361 = 33.5% of the coarse cost matrix.
# Keep 82405/247009 = 33.4% of the coarse cost matrix.
# OMT matching distance: 0.7221152782440186, time elapsed: 4.691882610321045
# Propagating to layer 6
# 533x586 clusters, computed at scale = 6.412
# Successive scales :  139.935, 139.935, 111.948, 89.558, 71.646, 57.317, 45.854, 36.683, 29.346, 23.477, 18.782, 15.025, 12.020, 9.616, 7.693, 6.154, 4.924, 3.939, 3.151, 2.521, 2.017, 1.613, 1.291, 1.033, 0.826, 0.661, 0.529, 0.423, 0.338, 0.271, 0.217, 0.173, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.693) and 15 (σ=6.154).
# Keep 98207/312338 = 31.4% of the coarse cost matrix.
# Keep 91355/284089 = 32.2% of the coarse cost matrix.
# Keep 105742/343396 = 30.8% of the coarse cost matrix.
# OMT matching distance: 1.1085354089736938, time elapsed: 1.4633395671844482
# Propagating to layer 7
# 527x590 clusters, computed at scale = 6.481
# Successive scales :  141.437, 141.437, 113.149, 90.519, 72.416, 57.932, 46.346, 37.077, 29.661, 23.729, 18.983, 15.187, 12.149, 9.719, 7.776, 6.220, 4.976, 3.981, 3.185, 2.548, 2.038, 1.631, 1.305, 1.044, 0.835, 0.668, 0.534, 0.427, 0.342, 0.274, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=7.776) and 15 (σ=6.220).
# Keep 96054/310930 = 30.9% of the coarse cost matrix.
# Keep 88099/277729 = 31.7% of the coarse cost matrix.
# Keep 104804/348100 = 30.1% of the coarse cost matrix.
# OMT matching distance: 1.438071608543396, time elapsed: 1.4856724739074707
# Propagating to layer 8
# 544x607 clusters, computed at scale = 6.560
# Successive scales :  143.150, 143.150, 114.520, 91.616, 73.293, 58.634, 46.907, 37.526, 30.021, 24.017, 19.213, 15.371, 12.296, 9.837, 7.870, 6.296, 5.037, 4.029, 3.223, 2.579, 2.063, 1.650, 1.320, 1.056, 0.845, 0.676, 0.541, 0.433, 0.346, 0.277, 0.222, 0.177, 0.142, 0.113, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=7.870) and 15 (σ=6.296).
# Keep 101304/330208 = 30.7% of the coarse cost matrix.
# Keep 93502/295936 = 31.6% of the coarse cost matrix.
# Keep 109745/368449 = 29.8% of the coarse cost matrix.
# OMT matching distance: 2.0317282676696777, time elapsed: 1.528001308441162
# Propagating to layer 9
# 538x617 clusters, computed at scale = 6.695
# Successive scales :  146.112, 146.112, 116.890, 93.512, 74.809, 59.848, 47.878, 38.302, 30.642, 24.514, 19.611, 15.689, 12.551, 10.041, 8.033, 6.426, 5.141, 4.113, 3.290, 2.632, 2.106, 1.685, 1.348, 1.078, 0.862, 0.690, 0.552, 0.442, 0.353, 0.283, 0.226, 0.181, 0.145, 0.116, 0.093, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=8.033) and 15 (σ=6.426).
# Keep 100613/331946 = 30.3% of the coarse cost matrix.
# Keep 90110/289444 = 31.1% of the coarse cost matrix.
# Keep 111567/380689 = 29.3% of the coarse cost matrix.
# OMT matching distance: 3.271061897277832, time elapsed: 1.543168306350708
# Propagating to layer 10
# 562x655 clusters, computed at scale = 6.866
# Successive scales :  149.840, 149.840, 119.872, 95.898, 76.718, 61.375, 49.100, 39.280, 31.424, 25.139, 20.111, 16.089, 12.871, 10.297, 8.238, 6.590, 5.272, 4.218, 3.374, 2.699, 2.159, 1.728, 1.382, 1.106, 0.885, 0.708, 0.566, 0.453, 0.362, 0.290, 0.232, 0.185, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.238) and 15 (σ=6.590).
# Keep 110088/368110 = 29.9% of the coarse cost matrix.
# Keep 97442/315844 = 30.9% of the coarse cost matrix.
# Keep 123659/429025 = 28.8% of the coarse cost matrix.
# OMT matching distance: 4.342101097106934, time elapsed: 1.656184196472168
# 534x558 clusters, computed at scale = 8.122
# Successive scales :  177.252, 177.252, 141.801, 113.441, 90.753, 72.602, 58.082, 46.465, 37.172, 29.738, 23.790, 19.032, 15.226, 12.181, 9.745, 7.796, 6.236, 4.989, 3.991, 3.193, 2.554, 2.044, 1.635, 1.308, 1.046, 0.837, 0.670, 0.536, 0.429, 0.343, 0.274, 0.219, 0.176, 0.140, 0.112, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.745) and 15 (σ=7.796).
# Keep 89418/297972 = 30.0% of the coarse cost matrix.
# Keep 86570/285156 = 30.4% of the coarse cost matrix.
# Keep 92362/311364 = 29.7% of the coarse cost matrix.
# OMT matching distance: 1.5234899520874023, time elapsed: 1.5026469230651855
# Propagating to layer 4
# 530x536 clusters, computed at scale = 8.101
# Successive scales :  176.774, 176.774, 141.419, 113.135, 90.508, 72.407, 57.925, 46.340, 37.072, 29.658, 23.726, 18.981, 15.185, 12.148, 9.718, 7.775, 6.220, 4.976, 3.981, 3.184, 2.548, 2.038, 1.630, 1.304, 1.043, 0.835, 0.668, 0.534, 0.427, 0.342, 0.274, 0.219, 0.175, 0.140, 0.112, 0.090, 0.072, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.718) and 15 (σ=7.775).
# Keep 85621/284080 = 30.1% of the coarse cost matrix.
# Keep 85162/280900 = 30.3% of the coarse cost matrix.
# Keep 86028/287296 = 29.9% of the coarse cost matrix.
# OMT matching distance: 0.837914228439331, time elapsed: 1.473384141921997
# Propagating to layer 3
# 509x515 clusters, computed at scale = 8.075
# Successive scales :  176.220, 176.220, 140.976, 112.781, 90.225, 72.180, 57.744, 46.195, 36.956, 29.565, 23.652, 18.921, 15.137, 12.110, 9.688, 7.750, 6.200, 4.960, 3.968, 3.174, 2.540, 2.032, 1.625, 1.300, 1.040, 0.832, 0.666, 0.533, 0.426, 0.341, 0.273, 0.218, 0.175, 0.140, 0.112, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.688) and 15 (σ=7.750).
# Keep 79222/262135 = 30.2% of the coarse cost matrix.
# Keep 78593/259081 = 30.3% of the coarse cost matrix.
# Keep 79871/265225 = 30.1% of the coarse cost matrix.
# OMT matching distance: 0.8331830501556396, time elapsed: 1.4335832595825195
# Propagating to layer 2
# 490x502 clusters, computed at scale = 8.064
# Successive scales :  175.984, 175.984, 140.787, 112.630, 90.104, 72.083, 57.666, 46.133, 36.907, 29.525, 23.620, 18.896, 15.117, 12.094, 9.675, 7.740, 6.192, 4.954, 3.963, 3.170, 2.536, 2.029, 1.623, 1.299, 1.039, 0.831, 0.665, 0.532, 0.426, 0.340, 0.272, 0.218, 0.174, 0.139, 0.112, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.675) and 15 (σ=7.740).
# Keep 74534/245980 = 30.3% of the coarse cost matrix.
# Keep 73058/240100 = 30.4% of the coarse cost matrix.
# Keep 76160/252004 = 30.2% of the coarse cost matrix.
# OMT matching distance: 0.8441966772079468, time elapsed: 3.1796138286590576
# Propagating to layer 1
# 481x483 clusters, computed at scale = 8.055
# Successive scales :  175.789, 175.789, 140.631, 112.505, 90.004, 72.003, 57.602, 46.082, 36.866, 29.492, 23.594, 18.875, 15.100, 12.080, 9.664, 7.731, 6.185, 4.948, 3.958, 3.167, 2.533, 2.027, 1.621, 1.297, 1.038, 0.830, 0.664, 0.531, 0.425, 0.340, 0.272, 0.218, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.664) and 15 (σ=7.731).
# Keep 70521/232323 = 30.4% of the coarse cost matrix.
# Keep 70537/231361 = 30.5% of the coarse cost matrix.
# Keep 70421/233289 = 30.2% of the coarse cost matrix.
# OMT matching distance: 0.8902073502540588, time elapsed: 4.804453372955322
# Propagating to layer 0
# 466x468 clusters, computed at scale = 8.053
# Successive scales :  175.741, 175.741, 140.592, 112.474, 89.979, 71.983, 57.587, 46.069, 36.855, 29.484, 23.588, 18.870, 15.096, 12.077, 9.661, 7.729, 6.183, 4.947, 3.957, 3.166, 2.533, 2.026, 1.621, 1.297, 1.037, 0.830, 0.664, 0.531, 0.425, 0.340, 0.272, 0.218, 0.174, 0.139, 0.111, 0.089, 0.071, 0.057, 0.050
# Jump from coarse to fine between indices 14 (σ=9.661) and 15 (σ=7.729).
# Keep 66291/218088 = 30.4% of the coarse cost matrix.
# Keep 66396/217156 = 30.6% of the coarse cost matrix.
# Keep 66190/219024 = 30.2% of the coarse cost matrix.
# OMT matching distance: 0.9837580323219299, time elapsed: 4.673513174057007
# Propagating to layer 6
# 527x575 clusters, computed at scale = 8.148
# Successive scales :  177.808, 177.808, 142.247, 113.797, 91.038, 72.830, 58.264, 46.611, 37.289, 29.831, 23.865, 19.092, 15.274, 12.219, 9.775, 7.820, 6.256, 5.005, 4.004, 3.203, 2.562, 2.050, 1.640, 1.312, 1.050, 0.840, 0.672, 0.537, 0.430, 0.344, 0.275, 0.220, 0.176, 0.141, 0.113, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.775) and 15 (σ=7.820).
# Keep 91119/303025 = 30.1% of the coarse cost matrix.
# Keep 84981/277729 = 30.6% of the coarse cost matrix.
# Keep 97679/330625 = 29.5% of the coarse cost matrix.
# OMT matching distance: 2.0147440433502197, time elapsed: 1.506711721420288
# Propagating to layer 7
# 547x589 clusters, computed at scale = 8.177
# Successive scales :  178.447, 178.447, 142.758, 114.206, 91.365, 73.092, 58.473, 46.779, 37.423, 29.938, 23.951, 19.161, 15.328, 12.263, 9.810, 7.848, 6.279, 5.023, 4.018, 3.215, 2.572, 2.057, 1.646, 1.317, 1.053, 0.843, 0.674, 0.539, 0.431, 0.345, 0.276, 0.221, 0.177, 0.141, 0.113, 0.090, 0.072, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.810) and 15 (σ=7.848).
# Keep 95876/322183 = 29.8% of the coarse cost matrix.
# Keep 90779/299209 = 30.3% of the coarse cost matrix.
# Keep 101159/346921 = 29.2% of the coarse cost matrix.
# OMT matching distance: 2.79225492477417, time elapsed: 1.5671894550323486
# Propagating to layer 8
# 549x606 clusters, computed at scale = 8.210
# Successive scales :  179.170, 179.170, 143.336, 114.669, 91.735, 73.388, 58.710, 46.968, 37.575, 30.060, 24.048, 19.238, 15.391, 12.312, 9.850, 7.880, 6.304, 5.043, 4.035, 3.228, 2.582, 2.066, 1.653, 1.322, 1.058, 0.846, 0.677, 0.542, 0.433, 0.347, 0.277, 0.222, 0.177, 0.142, 0.114, 0.091, 0.073, 0.058, 0.050
# Jump from coarse to fine between indices 14 (σ=9.850) and 15 (σ=7.880).
# Keep 97381/332694 = 29.3% of the coarse cost matrix.
# Keep 89859/301401 = 29.8% of the coarse cost matrix.
# Keep 105064/367236 = 28.6% of the coarse cost matrix.
# OMT matching distance: 4.574985504150391, time elapsed: 1.5952668190002441
# Propagating to layer 9
# 561x637 clusters, computed at scale = 8.293
# Successive scales :  180.984, 180.984, 144.787, 115.830, 92.664, 74.131, 59.305, 47.444, 37.955, 30.364, 24.291, 19.433, 15.546, 12.437, 9.950, 7.960, 6.368, 5.094, 4.075, 3.260, 2.608, 2.087, 1.669, 1.335, 1.068, 0.855, 0.684, 0.547, 0.438, 0.350, 0.280, 0.224, 0.179, 0.143, 0.115, 0.092, 0.073, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=9.950) and 15 (σ=7.960).
# Keep 103354/357357 = 28.9% of the coarse cost matrix.
# Keep 92977/314721 = 29.5% of the coarse cost matrix.
# Keep 114165/405769 = 28.1% of the coarse cost matrix.
# OMT matching distance: 5.896459579467773, time elapsed: 1.6542880535125732
# Propagating to layer 10
# 568x672 clusters, computed at scale = 8.389
# Successive scales :  183.062, 183.062, 146.449, 117.160, 93.728, 74.982, 59.986, 47.989, 38.391, 30.713, 24.570, 19.656, 15.725, 12.580, 10.064, 8.051, 6.441, 5.153, 4.122, 3.298, 2.638, 2.111, 1.688, 1.351, 1.081, 0.864, 0.692, 0.553, 0.443, 0.354, 0.283, 0.227, 0.181, 0.145, 0.116, 0.093, 0.074, 0.059, 0.050
# Jump from coarse to fine between indices 14 (σ=10.064) and 15 (σ=8.051).
# Keep 109333/381696 = 28.6% of the coarse cost matrix.
# Keep 94544/322624 = 29.3% of the coarse cost matrix.
# Keep 125266/451584 = 27.7% of the coarse cost matrix.
# OMT matching distance: 8.034188270568848, time elapsed: 1.7560341358184814
# 537x569 clusters, computed at scale = 7.674
# Successive scales :  167.470, 167.470, 133.976, 107.181, 85.745, 68.596, 54.877, 43.901, 35.121, 28.097, 22.477, 17.982, 14.386, 11.508, 9.207, 7.365, 5.892, 4.714, 3.771, 3.017, 2.414, 1.931, 1.545, 1.236, 0.989, 0.791, 0.633, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.207) and 15 (σ=7.365).
# Keep 94942/305553 = 31.1% of the coarse cost matrix.
# Keep 90501/288369 = 31.4% of the coarse cost matrix.
# Keep 99529/323761 = 30.7% of the coarse cost matrix.
# OMT matching distance: 0.567281186580658, time elapsed: 1.5349416732788086
# Propagating to layer 4
# 530x557 clusters, computed at scale = 7.672
# Successive scales :  167.421, 167.421, 133.937, 107.150, 85.720, 68.576, 54.861, 43.888, 35.111, 28.089, 22.471, 17.977, 14.381, 11.505, 9.204, 7.363, 5.891, 4.712, 3.770, 3.016, 2.413, 1.930, 1.544, 1.235, 0.988, 0.791, 0.632, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.204) and 15 (σ=7.363).
# Keep 92612/295210 = 31.4% of the coarse cost matrix.
# Keep 89062/280900 = 31.7% of the coarse cost matrix.
# Keep 96279/310249 = 31.0% of the coarse cost matrix.
# OMT matching distance: 0.9479020833969116, time elapsed: 1.5144381523132324
# Propagating to layer 3
# 524x546 clusters, computed at scale = 7.669
# Successive scales :  167.367, 167.367, 133.894, 107.115, 85.692, 68.554, 54.843, 43.874, 35.099, 28.080, 22.464, 17.971, 14.377, 11.501, 9.201, 7.361, 5.889, 4.711, 3.769, 3.015, 2.412, 1.930, 1.544, 1.235, 0.988, 0.790, 0.632, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.201) and 15 (σ=7.361).
# Keep 90016/286104 = 31.5% of the coarse cost matrix.
# Keep 87468/274576 = 31.9% of the coarse cost matrix.
# Keep 92712/298116 = 31.1% of the coarse cost matrix.
# OMT matching distance: 0.9659210443496704, time elapsed: 1.4954555034637451
# Propagating to layer 2
# 507x525 clusters, computed at scale = 7.668
# Successive scales :  167.338, 167.338, 133.871, 107.096, 85.677, 68.542, 54.833, 43.867, 35.093, 28.075, 22.460, 17.968, 14.374, 11.499, 9.200, 7.360, 5.888, 4.710, 3.768, 3.014, 2.412, 1.929, 1.543, 1.235, 0.988, 0.790, 0.632, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.200) and 15 (σ=7.360).
# Keep 84278/266175 = 31.7% of the coarse cost matrix.
# Keep 82369/257049 = 32.0% of the coarse cost matrix.
# Keep 86155/275625 = 31.3% of the coarse cost matrix.
# OMT matching distance: 0.9815085530281067, time elapsed: 1.4621539115905762
# Propagating to layer 1
# 490x518 clusters, computed at scale = 7.667
# Successive scales :  167.309, 167.309, 133.848, 107.078, 85.662, 68.530, 54.824, 43.859, 35.087, 28.070, 22.456, 17.965, 14.372, 11.497, 9.198, 7.358, 5.887, 4.709, 3.767, 3.014, 2.411, 1.929, 1.543, 1.235, 0.988, 0.790, 0.632, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.198) and 15 (σ=7.358).
# Keep 80643/253820 = 31.8% of the coarse cost matrix.
# Keep 77252/240100 = 32.2% of the coarse cost matrix.
# Keep 84052/268324 = 31.3% of the coarse cost matrix.
# OMT matching distance: 1.021287441253662, time elapsed: 3.226799249649048
# Propagating to layer 0
# 483x503 clusters, computed at scale = 7.668
# Successive scales :  167.325, 167.325, 133.860, 107.088, 85.670, 68.536, 54.829, 43.863, 35.091, 28.072, 22.458, 17.966, 14.373, 11.498, 9.199, 7.359, 5.887, 4.710, 3.768, 3.014, 2.411, 1.929, 1.543, 1.235, 0.988, 0.790, 0.632, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.199) and 15 (σ=7.359).
# Keep 76640/242949 = 31.5% of the coarse cost matrix.
# Keep 74865/233289 = 32.1% of the coarse cost matrix.
# Keep 78381/253009 = 31.0% of the coarse cost matrix.
# OMT matching distance: 1.211982011795044, time elapsed: 3.1752636432647705
# Propagating to layer 6
# 531x573 clusters, computed at scale = 7.678
# Successive scales :  167.546, 167.546, 134.036, 107.229, 85.783, 68.627, 54.901, 43.921, 35.137, 28.109, 22.488, 17.990, 14.392, 11.514, 9.211, 7.369, 5.895, 4.716, 3.773, 3.018, 2.415, 1.932, 1.545, 1.236, 0.989, 0.791, 0.633, 0.506, 0.405, 0.324, 0.259, 0.207, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.211) and 15 (σ=7.369).
# Keep 94762/304263 = 31.1% of the coarse cost matrix.
# Keep 89261/281961 = 31.7% of the coarse cost matrix.
# Keep 100347/328329 = 30.6% of the coarse cost matrix.
# OMT matching distance: 1.1991275548934937, time elapsed: 1.526362419128418
# Propagating to layer 7
# 538x598 clusters, computed at scale = 7.682
# Successive scales :  167.650, 167.650, 134.120, 107.296, 85.837, 68.669, 54.936, 43.948, 35.159, 28.127, 22.502, 18.001, 14.401, 11.521, 9.217, 7.373, 5.899, 4.719, 3.775, 3.020, 2.416, 1.933, 1.546, 1.237, 0.990, 0.792, 0.633, 0.507, 0.405, 0.324, 0.259, 0.208, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.217) and 15 (σ=7.373).
# Keep 98910/321724 = 30.7% of the coarse cost matrix.
# Keep 90218/289444 = 31.2% of the coarse cost matrix.
# Keep 107916/357604 = 30.2% of the coarse cost matrix.
# OMT matching distance: 1.541891098022461, time elapsed: 1.5889182090759277
# Propagating to layer 8
# 543x609 clusters, computed at scale = 7.686
# Successive scales :  167.733, 167.733, 134.186, 107.349, 85.879, 68.703, 54.963, 43.970, 35.176, 28.141, 22.513, 18.010, 14.408, 11.527, 9.221, 7.377, 5.902, 4.721, 3.777, 3.022, 2.417, 1.934, 1.547, 1.238, 0.990, 0.792, 0.634, 0.507, 0.406, 0.324, 0.260, 0.208, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.221) and 15 (σ=7.377).
# Keep 99141/330687 = 30.0% of the coarse cost matrix.
# Keep 89765/294849 = 30.4% of the coarse cost matrix.
# Keep 109307/370881 = 29.5% of the coarse cost matrix.
# OMT matching distance: 1.7927122116088867, time elapsed: 1.6069715023040771
# Propagating to layer 9
# 559x623 clusters, computed at scale = 7.691
# Successive scales :  167.838, 167.838, 134.270, 107.416, 85.933, 68.746, 54.997, 43.998, 35.198, 28.159, 22.527, 18.021, 14.417, 11.534, 9.227, 7.382, 5.905, 4.724, 3.779, 3.024, 2.419, 1.935, 1.548, 1.238, 0.991, 0.793, 0.634, 0.507, 0.406, 0.325, 0.260, 0.208, 0.166, 0.133, 0.106, 0.085, 0.068, 0.054, 0.050
# Jump from coarse to fine between indices 14 (σ=9.227) and 15 (σ=7.382).
# Keep 102120/348257 = 29.3% of the coarse cost matrix.
# Keep 92395/312481 = 29.6% of the coarse cost matrix.
# Keep 112491/388129 = 29.0% of the coarse cost matrix.
# OMT matching distance: 2.4517812728881836, time elapsed: 1.658883810043335
# Propagating to layer 10
# 580x656 clusters, computed at scale = 7.699
# Successive scales :  168.002, 168.002, 134.402, 107.522, 86.017, 68.814, 55.051, 44.041, 35.233, 28.186, 22.549, 18.039, 14.431, 11.545, 9.236, 7.389, 5.911, 4.729, 3.783, 3.026, 2.421, 1.937, 1.550, 1.240, 0.992, 0.793, 0.635, 0.508, 0.406, 0.325, 0.260, 0.208, 0.166, 0.133, 0.106, 0.085, 0.068, 0.055, 0.050
# Jump from coarse to fine between indices 14 (σ=9.236) and 15 (σ=7.389).
# Keep 109439/380480 = 28.8% of the coarse cost matrix.
# Keep 98148/336400 = 29.2% of the coarse cost matrix.
# Keep 121330/430336 = 28.2% of the coarse cost matrix.
# OMT matching distance: 4.342530250549316, time elapsed: 1.7793521881103516

# %% [markdown]
# # Older propagation code based on Nighres

# %%
# (re)load template
temp_save_folder = 'tmp/crashs_template'
md_temp = MeshData(load_vtk(f'{temp_save_folder}/template_shoot_left.vtk'), device)

# %%
def loop_subdivide(v, f, iterations=1):
    ms = pymeshlab.MeshSet()
    ms.add_mesh(pymeshlab.Mesh(vertex_matrix=v, face_matrix=f))
    ms.meshing_surface_subdivision_loop(iterations=iterations, threshold=pymeshlab.Percentage(0.0))
    return ms.mesh(0).vertex_matrix(), ms.mesh(0).face_matrix()

# %%
# Subdivide the template by splitting triangles
subdivide_level = 1
v_temp_sub, f_temp_sub = loop_subdivide(md_temp.v, md_temp.f, iterations=subdivide_level)
print(md_temp.v.shape, md_temp.f.shape, v_temp_sub.shape, f_temp_sub.shape)
# Out:
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)

# %%
# Load the CSV with the label descriptions
import pandas as pd
df_uclm = pd.read_csv('/data/pauly2/ashs_xv/manifest/label_grouping_ashs.csv',
                      names=('uclm','group','uclm_desc','group_desc'))

# These are the gray matter labels
uclm_group_labels_gm = (1,3,4,5,7,8,9)

# Label to group map
uclm_label_grouping = { q['uclm']: q['group'] for _, q in df_uclm.iterrows() if q['group'] in uclm_group_labels_gm }

# %%
import SimpleITK as sitk
import nighres

# Define the list of labels that we care about
uclm_labels = uclm_label_grouping.keys()

# Create a label map tensor. For each template vertex, we store for the five Nighres layers
# the probability of each label, plus the background probability
uclm_label_map = np.zeros((v_temp_sub.shape[0], 5, len(md_aff), len(uclm_labels) + 1))

# Load each segmentation in turn
for i, (id, md_i) in enumerate(md_aff.items()):

    # Read the global segmentation
    fn_global_seg = f'/data/pauly2/ashs_xv/input/{id}/{id}_label_global.nii.gz'
    img = sitk.ReadImage(fn_global_seg, outputPixelType=sitk.sitkFloat32)

    # Read the cortex image - because it has the dimensions that match the mesh
    img_ref = sitk.ReadImage(data[id]['workspace'].cruise_gm_prob)

    # Split the segmentation into binary images
    x_img = sitk.GetArrayFromImage(img)
    p_lab = np.stack([ x_img == l for l in uclm_labels])
    p_lab = np.append(p_lab, [1 - p_lab.sum(0)], axis=0)

    # Put it back into a vector ITK image (not very efficient)
    img_p = sitk.GetImageFromArray(p_lab.transpose(1,2,3,0), isVector=True)
    img_p.CopyInformation(img)

    # Smooth the image a bit
    img_p = sitk.SmoothingRecursiveGaussian(img_p, [0.4, 0.4, 0.4])

    # Load the fitted mesh and its interpolation arrays
    pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the midsurface mesh from cruise and map the template to this space
    pd_hw_nighres = load_vtk(data[id]['workspace'].fn_cruise('mtl_mesh-p2.vtk'))
    v_temp_to_hw_nighres = np.einsum('vij,vi->vj', vtk_get_points(pd_hw_nighres)[v_int,:], w_int)

    # Load the template that is OMT matched to the target inflated mesh, and subdivide it
    v_omt_sub, f_omt_sub = loop_subdivide(v_temp_to_hw_nighres, vtk_get_triangles(pd_i_fit), iterations=subdivide_level)
    print(v_temp_to_hw_nighres.shape, vtk_get_triangles(pd_i_fit).shape, v_omt_sub.shape, f_omt_sub.shape)

    # Perform profile meshing using the subdivided mesh
    profile_meshing = nighres.laminar.profile_meshing(
                          profile_surface_image=data[id]['workspace'].fn_cruise(f'mtl_layering-boundaries.nii.gz'),
                          starting_surface_mesh={'points': v_omt_sub, 'faces': f_omt_sub},
                          save_data=True,
                          overwrite=True,
                          file_name=f'template_subdiv_{id}.vtk',
                          output_dir='tmp/')
    
    # Repeat for each mesh layer
    print(f'Sampling {id}')
    for layer in range(5):

        # Load the mesh for that layer
        # pd_layer = load_vtk(data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))
        pd_layer = load_vtk(f'tmp/template_subdiv_{id}_mesh-p{layer}.vtk')
        v_layer = vtk_get_points(pd_layer)

        # Sample the label map at this layer, keeping in mind that the layer is going to
        # be in image coordinate space, not physical space
        n_hit, n_miss = 0, 0
        for j in range(v_layer.shape[0]):
            # Transform to physical point via reference image
            p_j = img_ref.TransformContinuousIndexToPhysicalPoint(v_layer[j, :].tolist())
            try:
                l = img_p.EvaluateAtPhysicalPoint(p_j, sitk.sitkLinear)
                n_hit = n_hit + 1
            except:
                n_miss = n_miss + 1
                l = 0
            uclm_label_map[j, layer, i, :] = l
# Out:
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_104937L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 104937L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_106049L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 106049L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_106312R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 106312R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_113909R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 113909R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_116748R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 116748R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_117243R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 117243R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_117667R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 117667R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_118374L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 118374L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_118430R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 118430R
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120126L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 120126L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120267L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 120267L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120937L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 120937L
# (6460, 3) (12916, 3) (25834, 3) (51664, 3)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_121250L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# Sampling 121250L

# %%
""" Old code - no upsample

# --- backup of cell 
import SimpleITK as sitk

# Define the list of labels that we care about
uclm_labels = uclm_label_grouping.keys()

# Create a label map tensor. For each template vertex, we store for the five Nighres layers
# the probability of each label, plus the background probability
uclm_label_map = np.zeros((md_temp.v.shape[0], 5, len(md_aff), len(uclm_labels) + 1))

# Load each segmentation in turn
for i, (id, md_i) in enumerate(md_aff.items()):

    # Read the global segmentation
    fn_global_seg = f'/data/pauly2/ashs_xv/input/{id}/{id}_label_global.nii.gz'
    img = sitk.ReadImage(fn_global_seg, outputPixelType=sitk.sitkFloat32)

    # Read the cortex image - because it has the dimensions that match the mesh
    img_ref = sitk.ReadImage(data[id]['workspace'].cruise_gm_prob)

    # Split the segmentation into binary images
    x_img = sitk.GetArrayFromImage(img)
    p_lab = np.stack([ x_img == l for l in uclm_labels])
    p_lab = np.append(p_lab, [1 - p_lab.sum(0)], axis=0)

    # Put it back into a vector ITK image (not very efficient)
    img_p = sitk.GetImageFromArray(p_lab.transpose(1,2,3,0), isVector=True)
    img_p.CopyInformation(img)

    # Smooth the image a bit
    img_p = sitk.SmoothingRecursiveGaussian(img_p, [0.4, 0.4, 0.4])

    # Load the fitted template with its interpolation arrays
    pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Repeat for each mesh layer
    print(f'Sampling {id}')
    for layer in range(5):

        # Load the mesh for that layer
        pd_layer = load_vtk(data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))

        # Map template vertices to that layer
        v_temp_to_layer = np.einsum('vij,vi->vj', vtk_get_points(pd_layer)[v_int,:], w_int)

        # Sample the label map at this layer, keeping in mind that the layer is going to
        # be in image coordinate space, not physical space
        n_hit, n_miss = 0, 0
        for j in range(v_temp_to_layer.shape[0]):
            # Transform to physical point via reference image
            p_j = img_ref.TransformContinuousIndexToPhysicalPoint(v_temp_to_layer[j, :].tolist())
            try:
                l = img_p.EvaluateAtPhysicalPoint(p_j, sitk.sitkLinear)
                n_hit = n_hit + 1
            except:
                n_miss = n_miss + 1
                l = 0
            uclm_label_map[j, layer, i, :] = l
"""
# Out:
# " Old code - no upsample\n\n# --- backup of cell \nimport SimpleITK as sitk\n\n# Define the list of labels that we care about\nuclm_labels = uclm_label_grouping.keys()\n\n# Create a label map tensor. For each template vertex, we store for the five Nighres layers\n# the probability of each label, plus the background probability\nuclm_label_map = np.zeros((md_temp.v.shape[0], 5, len(md_aff), len(uclm_labels) + 1))\n\n# Load each segmentation in turn\nfor i, (id, md_i) in enumerate(md_aff.items()):\n\n    # Read the global segmentation\n    fn_global_seg = f'/data/pauly2/ashs_xv/input/{id}/{id}_label_global.nii.gz'\n    img = sitk.ReadImage(fn_global_seg, outputPixelType=sitk.sitkFloat32)\n\n    # Read the cortex image - because it has the dimensions that match the mesh\n    img_ref = sitk.ReadImage(data[id]['workspace'].cruise_gm_prob)\n\n    # Split the segmentation into binary images\n    x_img = sitk.GetArrayFromImage(img)\n    p_lab = np.stack([ x_img == l for l in uclm_labels])\n    p_lab = np.append(p_lab, [1 - p_lab.sum(0)], axis=0)\n\n    # Put it back into a vector ITK image (not very efficient)\n    img_p = sitk.GetImageFromArray(p_lab.transpose(1,2,3,0), isVector=True)\n    img_p.CopyInformation(img)\n\n    # Smooth the image a bit\n    img_p = sitk.SmoothingRecursiveGaussian(img_p, [0.4, 0.4, 0.4])\n\n    # Load the fitted template with its interpolation arrays\n    pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')\n    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)\n    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')\n\n    # Repeat for each mesh layer\n    print(f'Sampling {id}')\n    for layer in range(5):\n\n        # Load the mesh for that layer\n        pd_layer = load_vtk(data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))\n\n        # Map template vertices to that layer\n        v_temp_to_layer = np.einsum('vij,vi->vj', vtk_get_points(pd_layer)[v_int,:], w_int)\n\n        # Sample the label map at this layer, keeping in mind that the layer is going to\n        # be in image coordinate space, not physical space\n        n_hit, n_miss = 0, 0\n        for j in range(v_temp_to_layer.shape[0]):\n            # Transform to physical point via reference image\n            p_j = img_ref.TransformContinuousIndexToPhysicalPoint(v_temp_to_layer[j, :].tolist())\n            try:\n                l = img_p.EvaluateAtPhysicalPoint(p_j, sitk.sitkLinear)\n                n_hit = n_hit + 1\n            except:\n                n_miss = n_miss + 1\n                l = 0\n            uclm_label_map[j, layer, i, :] = l\n"

# %%
# Average the map between subjects
uclm_label_consensus = np.mean(uclm_label_map, 2)

# Consensus labeling
pd_consensus = vtk_make_pd(v_temp_sub, f_temp_sub)
for layer in range(5):
    layer_prob = uclm_label_consensus[:,layer,:].astype(np.float32)
    vtk_set_point_array(pd_consensus, f'layer_{layer}_prob_uclm', layer_prob)
    vtk_set_point_array(pd_consensus, f'layer_{layer}_label_uclm', np.argmax(layer_prob, 1))

save_vtk(pd_consensus, 'tmp/template_ec_test.vtk', binary=True)

# %% [markdown]
# Now the real magic, map the consensus distribution into subject space. Here we can try to use RBF interpolation.

# %%
from pykeops.torch import LazyTensor
def laplacian_kernel(x, y, sigma=0.1):
    x_i = LazyTensor(x[:, None, :])  # (M, 1, 1)
    y_j = LazyTensor(y[None, :, :])  # (1, N, 1)
    D_ij = ((x_i - y_j) ** 2).sum(-1)  # (M, N) symbolic matrix of squared distances
    return (-D_ij.sqrt() / sigma).exp()

for i, (id, md_i) in enumerate(md_aff.items()):

    # Read the segmentation that we want to apply this labeling to
    fn_target = f'/data/pauly2/ashs_xv/work/fold_0/work/{id}/{id}_ivseg_ashs_upsample.nii.gz'
    img = sitk.ReadImage(fn_target, outputPixelType=sitk.sitkFloat32)

    # Extract pixels of interest
    x_img = sitk.GetArrayViewFromImage(img)
    x_img = np.sum(np.stack([x_img == l for l in uclm_group_labels_gm]), axis=0)

    # Get the pixel coordinates - these are flipped so they correspond to ITK
    nz = np.flip(np.transpose(np.stack(np.nonzero(x_img)).astype(np.float32)), 1)

    # Map each of these coordinates into the Nighres mesh coordinates
    img_ref = sitk.ReadImage(data[id]['workspace'].cruise_gm_prob)
    y = np.array([img_ref.TransformPhysicalPointToContinuousIndex(
        img.TransformContinuousIndexToPhysicalPoint(nz[j,:].tolist())) for j in range(nz.shape[0]) ])
    
    # Load the fitted mesh and its interpolation arrays
    pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the midsurface mesh from cruise and map the template to this space
    pd_hw_nighres = load_vtk(data[id]['workspace'].fn_cruise('mtl_mesh-p2.vtk'))
    v_temp_to_hw_nighres = np.einsum('vij,vi->vj', vtk_get_points(pd_hw_nighres)[v_int,:], w_int)

    # Load the template that is OMT matched to the target inflated mesh, and subdivide it
    v_omt_sub, f_omt_sub = loop_subdivide(v_temp_to_hw_nighres, vtk_get_triangles(pd_i_fit), iterations=subdivide_level)

    # Perform profile meshing using the subdivided mesh
    profile_meshing = nighres.laminar.profile_meshing(
                          profile_surface_image=data[id]['workspace'].fn_cruise(f'mtl_layering-boundaries.nii.gz'),
                          starting_surface_mesh={'points': v_omt_sub, 'faces': f_omt_sub},
                          save_data=True,
                          overwrite=True,
                          file_name=f'template_subdiv_{id}.vtk',
                          output_dir='tmp/')
    
    # Load the fitted template with its interpolation arrays
    #pd_i_fit = load_vtk(f'tmp/template_fit_to_{id}.vtk')
    #v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    #w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the Nighres meshes - these are the coordinates from which we wish to interpolate
    mesh_coord, mesh_label = [], []
    for layer in range(5):

        # Load the mesh for that layer
        # pd_layer = load_vtk(data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))
        pd_layer = load_vtk(f'tmp/template_subdiv_{id}_mesh-p{layer}.vtk')
        v_layer = vtk_get_points(pd_layer)

        # Map template vertices to that layer and append to list of all interpolated coords
        # mesh_coord.append(np.einsum('vij,vi->vj', vtk_get_points(pd_layer)[v_int,:], w_int))
        mesh_coord.append(v_layer)
        mesh_label.append(uclm_label_consensus[:,layer,:])

    # Put the coordinates together - these are the points we want to interpolate from
    x = np.concatenate(mesh_coord)

    # Put the label probabilities together - these are the values we want to propagate
    b = np.concatenate(mesh_label)

    # Perform RBF interpolation, so easy!
    K_yx = laplacian_kernel(
        torch.tensor(y, dtype=torch.float32, device=device), 
        torch.tensor(x, dtype=torch.float32, device=device), 
        sigma=1.0)
    b_y = (K_yx @ torch.tensor(b, dtype=torch.float32, device=device)).detach().cpu().numpy()

    # Assign the values to the vertices
    l_best = np.argmax(b_y[:,:-1], 1)
    l_best_remap = np.zeros_like(l_best)
    for k, label in enumerate(uclm_label_grouping.keys()):
        l_best_remap[l_best == k] = label
    x_img[x_img != 0] = l_best_remap

    img_result = sitk.GetImageFromArray(x_img)
    img_result.CopyInformation(img)

    # Save the image
    sitk.WriteImage(img_result, f'tmp/crashs_fill_labels_{id}.nii.gz')
# Out:
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_104937L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_104937L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
# [KeOps] Generating code for formula Sum_Reduction(Exp(-Sqrt(Sum((Var(0,3,0)-Var(1,3,1))**2)))*Var(2,33,1),0) ... OK
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_106049L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_106049L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_106312R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_106312R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_113909R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_113909R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_116748R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_116748R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_117243R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_117243R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_117667R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_117667R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_118374L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_118374L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_118430R_mesh-p0.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p1.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p2.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p3.vtk
#
# Saving tmp/template_subdiv_118430R_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120126L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120126L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120267L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120267L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_120937L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_120937L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)
#
# Profile meshing
#
# Outputs will be saved to tmp/
#
# Saving tmp/template_subdiv_121250L_mesh-p0.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p1.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p2.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p3.vtk
#
# Saving tmp/template_subdiv_121250L_mesh-p4.vtk
# lines: (2584, 1)
# indices: (2584, 5)
# lines: (2584, 6)

# %% [markdown]
# ### Now do the same for the nnU-Net segmentations

# %%
import glob
test_ids = [ os.path.basename(x) for x in glob.glob('/data/pauly2/ashs_xv/work/fold_0/nnunet/*') ]

# %%
# Keep track of ASHS importers and workspaces created
test_data = {}

# Run basic Nighres for each subject
for id in test_ids:
    # Get the side
    side = 'left' if id.endswith('L') else 'right'

    # Create the output dir
    crashs_dir = os.path.join('/data/pauly2/ashs_xv/work/fold_0/crashs_apply_nnunet', id)
    workspace = Workspace(crashs_dir, id)

    # Store the data
    test_data[id] = { 'side': side, 'workspace': workspace }

# %%
for i, id in enumerate(test_ids):

    # Read the segmentation that we want to apply this labeling to
    fn_target = f'/data/pauly2/ashs_xv/work/fold_0/nnunet/{id}/{id}_ivseg_ashs_upsample.nii.gz'
    img = sitk.ReadImage(fn_target, outputPixelType=sitk.sitkFloat32)

    # Extract pixels of interest
    x_img = sitk.GetArrayViewFromImage(img)
    x_img = np.sum(np.stack([x_img == l for l in uclm_group_labels_gm]), axis=0)

    # Get the pixel coordinates - these are flipped so they correspond to ITK
    nz = np.flip(np.transpose(np.stack(np.nonzero(x_img)).astype(np.float32)), 1)

    # Map each of these coordinates into the Nighres mesh coordinates
    img_ref = sitk.ReadImage(test_data[id]['workspace'].cruise_gm_prob)
    y = np.array([img_ref.TransformPhysicalPointToContinuousIndex(
        img.TransformContinuousIndexToPhysicalPoint(nz[j,:].tolist())) for j in range(nz.shape[0]) ])
    
    # Load the fitted template with its interpolation arrays
    pd_i_fit = load_vtk(test_data[id]['workspace'].fit_omt_match)
    v_int = vtk_get_point_array(pd_i_fit, 'omt_v_int').astype(np.int32)
    w_int = vtk_get_point_array(pd_i_fit, 'omt_w_int')

    # Load the Nighres meshes - these are the coordinates from which we wish to interpolate
    mesh_coord, mesh_label = [], []
    for layer in range(5):

        # Load the mesh for that layer
        pd_layer = load_vtk(test_data[id]['workspace'].fn_cruise(f'mtl_mesh-p{layer}.vtk'))

        # Map template vertices to that layer and append to list of all interpolated coords
        mesh_coord.append(np.einsum('vij,vi->vj', vtk_get_points(pd_layer)[v_int,:], w_int))
        mesh_label.append(uclm_label_consensus[:,layer,:])

    # Put the coordinates together - these are the points we want to interpolate from
    x = np.concatenate(mesh_coord)

    # Put the label probabilities together - these are the values we want to propagate
    b = np.concatenate(mesh_label)

    # Perform RBF interpolation, so easy!
    K_yx = laplacian_kernel(torch.tensor(y, dtype=torch.float32, device=device), 
                        torch.tensor(x, dtype=torch.float32, device=device))
    b_y = (K_yx @ torch.tensor(b, dtype=torch.float32, device=device)).detach().cpu().numpy()

    # Assign the values to the vertices
    l_best = np.argmax(b_y[:,:-1], 1)
    l_best_remap = np.zeros_like(l_best)
    for k, label in enumerate(uclm_label_grouping.keys()):
        l_best_remap[l_best == k] = label
    x_img[x_img != 0] = l_best_remap

    img_result = sitk.GetImageFromArray(x_img)
    img_result.CopyInformation(img)

    # Save the image
    sitk.WriteImage(img_result, f'tmp/crashs_nnunet_fill_labels_{id}.nii.gz')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2276749/4080615753.py in <module>
#      23
#      24     # Load the midsurface mesh from cruise and map the template to this space
# ---> 25     pd_hw_nighres = load_vtk(data[id]['workspace'].fn_cruise('mtl_avg_l2m-mesh.vtk'))
#      26     v_temp_to_hw_nighres = np.einsum('vij,vi->vj', vtk_get_points(pd_hw_nighres)[v_int,:], w_int)
#      27     pd_temp_to_hw_nighres = vtk_make_pd(v_temp_to_hw_nighres, vtk_get_triangles(pd_i_fit))
#
# KeyError: '100551R'

# %% [markdown]
# # Debug extreme stretching in template to subject fitting

# %%
# Which id to test on?
test_id = '106049L'
md_temp = MeshData(load_vtk(f'tmp/template_final_with_momenta.vtk'), device=device)
md_subj = MeshData(load_vtk(f'tmp/test_register_{test_id}.vtk'), device=device)

# %%
def lddmm_fit_subject(md_temp, md_subj, n_iter=50, sigma_lddmm=5, sigma_varifold=10, gamma_lddmm=0.1):

    # LDDMM kernels
    device = md_temp.vt.device
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))
    K_vari = GaussLinKernelWithLabels(torch.tensor(sigma_varifold, dtype=torch.float32, device=device), md_temp.lp.shape[1])

    # Create losses for each of the target meshes
    d_loss = lossVarifoldSurfWithLabels(md_temp.ft, md_subj.vt, md_subj.ft, md_temp.lpt, md_subj.lpt, K_vari) 
            
    # Create the root->template points/momentum, as well as the template->subject momenta
    q_temp = torch.tensor(md_temp.vt, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_temp = torch.zeros(md_temp.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()

    # Create the optimizer
    start = time.time()
    optimizer = torch.optim.LBFGS([p_temp], max_eval=16, max_iter=16, line_search_fn='strong_wolfe')

    def closure(detail = False):
        optimizer.zero_grad()
        _, q_i = Shooting(p_temp, q_temp, K_temp)[-1]
        l_ham = gamma_lddmm * Hamiltonian(K_temp)(p_temp, q_temp)
        l_data = d_loss(q_i)
        L = l_ham + l_data
        L.backward()
        if detail:
            return l_ham, l_data, L
        else:
            return L

    # Perform optimization
    for i in range(n_iter):
        l_ham, l_data, L = closure(True)
        print(f'Iteration {i:03d}  Losses: H={l_ham:8.6f}  D={l_data:8.6f}  Total={L:8.6f}')
        optimizer.step(closure)

    print(f'Optimization (L-BFGS) time: {round(time.time() - start, 2)} seconds')

    # Return the root model and the momenta
    return p_temp


def lddmm_fit_subject_jac_penalty(md_temp, md_subj, n_iter=50, sigma_lddmm=5, sigma_varifold=10, 
                                  gamma_lddmm=0.1, w_jac_penalty=1.0):

    # LDDMM kernels
    device = md_temp.vt.device
    K_temp = GaussKernel(sigma=torch.tensor(sigma_lddmm, dtype=torch.float32, device=device))
    K_vari = GaussLinKernelWithLabels(torch.tensor(sigma_varifold, dtype=torch.float32, device=device), md_temp.lp.shape[1])

    # Create losses for each of the target meshes
    d_loss = lossVarifoldSurfWithLabels(md_temp.ft, md_subj.vt, md_subj.ft, md_temp.lpt, md_subj.lpt, K_vari) 
            
    # Create the root->template points/momentum, as well as the template->subject momenta
    q_temp = torch.tensor(md_temp.vt, dtype=torch.float32, device=device, requires_grad=True).contiguous()
    p_temp = torch.zeros(md_temp.vt.shape, dtype=torch.float32, device=device, requires_grad=True).contiguous()

    # Create the optimizer
    start = time.time()
    optimizer = torch.optim.LBFGS([p_temp], max_eval=16, max_iter=16, line_search_fn='strong_wolfe')

    z0 = md_temp.vt[md_temp.ft]
    area_0 = torch.norm(torch.cross(z0[:,1,:] - z0[:,0,:], z0[:,2,:] - z0[:,0,:]),dim=1) 

    def closure(detail = False):
        optimizer.zero_grad()
        _, q_i = Shooting(p_temp, q_temp, K_temp)[-1]
        z = q_i[md_temp.ft]
        area = torch.norm(torch.cross(z[:,1,:] - z[:,0,:], z[:,2,:] - z[:,0,:]),dim=1)
        log_jac = torch.log10(area / area_0)

        l_ham = gamma_lddmm * Hamiltonian(K_temp)(p_temp, q_temp)
        l_data = d_loss(q_i)
        l_jac = torch.sum(log_jac ** 2) * w_jac_penalty
        L = l_ham + l_data + l_jac
        L.backward()
        if detail:
            return l_ham, l_data, l_jac, L
        else:
            return L

    # Perform optimization
    for i in range(n_iter):
        l_ham, l_data, l_jac, L = closure(True)
        print(f'Iteration {i:03d}  Losses: H={l_ham:8.6f}  D={l_data:8.6f}  J={l_jac:8.6f}  Total={L:8.6f}')
        optimizer.step(closure)

    print(f'Optimization (L-BFGS) time: {round(time.time() - start, 2)} seconds')

    # Return the root model and the momenta
    return p_temp

# %%
# Examine pairwise registration
p = lddmm_fit_subject_jac_penalty(md_temp, md_subj, n_iter=50,
                      sigma_lddmm = template['left'].get_lddmm_sigma(), 
                      sigma_varifold = 5,
                      gamma_lddmm=0.05, w_jac_penalty=10.)
# Out:
# /tmp/ipykernel_476292/2632595993.py:55: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Iteration 000  Losses: H=0.000000  D=69699.453125  J=0.000000  Total=69699.453125
# Iteration 001  Losses: H=18.435059  D=5901.156250  J=3948.298096  Total=9867.889648
# Iteration 002  Losses: H=27.894758  D=2977.500000  J=3456.654785  Total=6462.049805
# Iteration 003  Losses: H=35.484474  D=2132.656250  J=3025.152832  Total=5193.293457
# Iteration 004  Losses: H=40.652882  D=1759.687500  J=2814.804688  Total=4615.145020
# Iteration 005  Losses: H=43.886608  D=1567.750000  J=2646.022461  Total=4257.659180
# Iteration 006  Losses: H=46.895168  D=1437.000000  J=2548.185791  Total=4032.081055
# Iteration 007  Losses: H=50.572807  D=1359.375000  J=2472.786377  Total=3882.734131
# Iteration 008  Losses: H=52.279385  D=1293.437500  J=2437.608398  Total=3783.325195
# Iteration 009  Losses: H=53.251942  D=1234.125000  J=2431.110840  Total=3718.487793
# Iteration 010  Losses: H=54.692726  D=1203.250000  J=2404.950195  Total=3662.893066
# Iteration 011  Losses: H=55.352955  D=1167.250000  J=2388.989014  Total=3611.591797
# Iteration 012  Losses: H=56.166187  D=1136.875000  J=2375.934814  Total=3568.976074
# Iteration 013  Losses: H=57.088909  D=1104.125000  J=2366.518066  Total=3527.731934
# Iteration 014  Losses: H=58.489651  D=1076.093750  J=2360.494141  Total=3495.077637
# Iteration 015  Losses: H=59.127697  D=1059.437500  J=2350.204834  Total=3468.770020
# Iteration 016  Losses: H=59.827358  D=1045.500000  J=2343.595703  Total=3448.923096
# Iteration 017  Losses: H=60.479389  D=1034.593750  J=2335.564941  Total=3430.638184
# Iteration 018  Losses: H=61.060341  D=1017.593750  J=2335.547119  Total=3414.201172
# Iteration 019  Losses: H=62.145668  D=1004.187500  J=2331.055176  Total=3397.388184
# Iteration 020  Losses: H=62.518688  D=996.375000  J=2325.727783  Total=3384.621582
# Iteration 021  Losses: H=62.874634  D=991.843750  J=2318.866211  Total=3373.584473
# Iteration 022  Losses: H=63.432434  D=982.375000  J=2315.381104  Total=3361.188477
# Iteration 023  Losses: H=64.232018  D=977.156250  J=2310.762207  Total=3352.150391
# Iteration 024  Losses: H=64.261086  D=972.406250  J=2305.596680  Total=3342.264160
# Iteration 025  Losses: H=64.345337  D=969.406250  J=2299.671875  Total=3333.423340
# Iteration 026  Losses: H=64.543854  D=965.062500  J=2294.464355  Total=3324.070801
# Iteration 027  Losses: H=65.058563  D=962.437500  J=2288.073486  Total=3315.569580
# Iteration 028  Losses: H=65.154778  D=961.125000  J=2282.536621  Total=3308.816406
# Iteration 029  Losses: H=65.797920  D=955.656250  J=2279.781738  Total=3301.235840
# Iteration 030  Losses: H=66.449364  D=952.343750  J=2276.457031  Total=3295.250000
# Iteration 031  Losses: H=66.674103  D=949.906250  J=2273.150391  Total=3289.730713
# Iteration 032  Losses: H=66.705238  D=949.500000  J=2269.073242  Total=3285.278564
# Iteration 033  Losses: H=66.825760  D=950.281250  J=2263.696289  Total=3280.803223
# Iteration 034  Losses: H=67.105103  D=947.281250  J=2261.845947  Total=3276.232422
# Iteration 035  Losses: H=67.268211  D=946.812500  J=2258.291016  Total=3272.371582
# Iteration 036  Losses: H=67.743828  D=939.875000  J=2260.342285  Total=3267.961182
# Iteration 037  Losses: H=67.896965  D=937.125000  J=2258.703125  Total=3263.725098
# Iteration 038  Losses: H=67.854225  D=936.625000  J=2254.868164  Total=3259.347412
# Iteration 039  Losses: H=67.998894  D=935.593750  J=2251.731201  Total=3255.323730
# Iteration 040  Losses: H=68.204315  D=933.593750  J=2250.087402  Total=3251.885498
# Iteration 041  Losses: H=68.517555  D=929.593750  J=2249.844971  Total=3247.956299
# Iteration 042  Losses: H=69.080650  D=927.312500  J=2247.779785  Total=3244.172852
# Iteration 043  Losses: H=69.350014  D=926.750000  J=2244.533936  Total=3240.634033
# Iteration 044  Losses: H=69.625282  D=924.312500  J=2243.502930  Total=3237.440674
# Iteration 045  Losses: H=69.882912  D=923.218750  J=2241.768066  Total=3234.869629
# Iteration 046  Losses: H=70.066765  D=920.812500  J=2241.153320  Total=3232.032715
# Iteration 047  Losses: H=70.183212  D=921.062500  J=2238.262695  Total=3229.508301
# Iteration 048  Losses: H=70.183083  D=920.375000  J=2236.786621  Total=3227.344727
# Iteration 049  Losses: H=70.155212  D=921.375000  J=2233.497314  Total=3225.027588
# Optimization (L-BFGS) time: 202.57 seconds

# %%
md_fit = shoot_template_to_subject(md_temp, p, template['left'].get_lddmm_sigma())
jac = torch.norm(torch.cross(z[:,1,:] - z[:,0,:], z[:,2,:] - z[:,0,:]),dim=1) / torch.norm(torch.cross(z0[:,1,:] - z0[:,0,:], z0[:,2,:] - z0[:,0,:]),dim=1)

vtk_set_cell_array(md_fit.pd, 'jacobian', jac.detach().cpu().numpy())
save_vtk(md_fit.pd, f'tmp/test_bad_fit_{test_id}.vtk')

# %%
z = md_fit.vt[md_fit.ft]
z0 = md_temp.vt[md_temp.ft]

# %%
jac = torch.norm(torch.cross(z[:,1,:] - z[:,0,:], z[:,2,:] - z[:,0,:]),dim=1) / torch.norm(torch.cross(z0[:,1,:] - z0[:,0,:], z0[:,2,:] - z0[:,0,:]),dim=1)

# %% [markdown]
# save_vtk(pd_temp_save, 'tmp/template_final_with_momenta.vtk')
# md_aff[id] = MeshData(load_vtk(f'tmp/test_register_{id}.vtk'), device)

# %%
np.max(np.log(jac.detach().cpu().numpy()))
# Out:
# 3.3452086

# %% [markdown]
# # Debug CRUISE mesh propagation
# Layer mesh propagation does not match the average surface all the way down to the GM/CSF surface, some profiles never reach the outer boundary due to low gradient (I think). Try using CRUISE to compute a correspondence between concentric layers

# %%
# Define the subject to experiment with
id_test = '118374L'
ws_test = data[id_test]['workspace']

# Load the subject's layer levelset image
img_ls = sitk.ReadImage(ws_test.fn_cruise('mtl_layering-boundaries.nii.gz'))

# %%
layer = img_ls[:,:,:,5]

def layer_to_mesh(layer, edge_len_pct=0.75, to_ras=True):
    pix_raw = sitk.GetArrayFromImage(layer)
    img = vtk.vtkImageData()
    img.GetPointData().SetScalars(numpy_to_vtk(pix_raw.flatten(), array_type=vtk.VTK_FLOAT))
    img.SetDimensions(layer.GetSize()[0], layer.GetSize()[1], layer.GetSize()[2]) 
    # img.SetOrigin(layer.GetOrigin()[0],layer.GetOrigin()[1],layer.GetOrigin()[2])
    # img.SetSpacing(layer.GetSpacing()[0],layer.GetSpacing()[1],layer.GetSpacing()[2])
    # img.SetDirectionMatrix(*layer.GetDirection())

    cube = vtk.vtkMarchingCubes()
    cube.SetInputData(img)
    cube.SetNumberOfContours(1)
    cube.SetValue(0, 0.0)

    tri1 = vtk.vtkTriangleFilter()
    tri1.SetInputConnection(cube.GetOutputPort())
    tri1.PassLinesOff()
    tri1.PassVertsOff()

    clean = vtk.vtkCleanPolyData()
    clean.SetInputConnection(tri1.GetOutputPort())
    clean.PointMergingOn()
    clean.SetTolerance(0.0)

    tri2 = vtk.vtkTriangleFilter()
    tri2.SetInputConnection(clean.GetOutputPort())
    tri2.PassLinesOff()
    tri2.PassVertsOff()

    tri2.Update()
    pd_cubes = tri2.GetOutput()

    # Apply remeshing to the template
    ms = pymeshlab.MeshSet()
    ms.add_mesh(pymeshlab.Mesh(vertex_matrix=vtk_get_points(pd_cubes), face_matrix=vtk_get_triangles(pd_cubes)))
    ms.meshing_isotropic_explicit_remeshing(targetlen = pymeshlab.Percentage(edge_len_pct))
    v_remesh, f_remesh = ms.mesh(0).vertex_matrix(), ms.mesh(0).face_matrix()
    return vtk_make_pd(v_remesh, f_remesh)

# %%
layer_5 = layer_to_mesh(img_ls[:,:,:,5])
layer_6 = layer_to_mesh(img_ls[:,:,:,6])

_, w_omt = match_omt(
    torch.tensor(vtk_get_points(layer_5), dtype=torch.float32, device=device),
    torch.tensor(vtk_get_triangles(layer_5), dtype=torch.int32, device=device),
    torch.tensor(vtk_get_points(layer_6), dtype=torch.float32, device=device),
    torch.tensor(vtk_get_triangles(layer_6), dtype=torch.int32, device=device))

v_omt, _, _ = omt_match_to_vertex_weights(layer_5, layer_6, w_omt.detach().cpu().numpy())
layer5_omt_to_6 = vtk_make_pd(v_omt, vtk_get_triangles(layer_5))
# Out:
# 553x580 clusters, computed at scale = 6.971
# Successive scales :  152.127, 152.127, 121.702, 97.361, 77.889, 62.311, 49.849, 39.879, 31.903, 25.523, 20.418, 16.335, 13.068, 10.454, 8.363, 6.691, 5.352, 4.282, 3.426, 2.740, 2.192, 1.754, 1.403, 1.122, 0.898, 0.718, 0.575, 0.460, 0.368, 0.294, 0.235, 0.188, 0.151, 0.121, 0.096, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.363) and 15 (σ=6.691).
# Keep 102453/320740 = 31.9% of the coarse cost matrix.
# Keep 97693/305809 = 31.9% of the coarse cost matrix.
# Keep 107462/336400 = 31.9% of the coarse cost matrix.
# OMT matching distance: 0.5250161290168762, time elapsed: 1.624000072479248

# %%
# Propagate a mesh through the levelset shells using OMT, starting with the 
# specified level. If no level specified, middle level will be used
def profile_meshing_omt(img_ls, source_mesh=None, init_layer=None):

    # The OMT algorithm that is called repeatedly
    def do_omt(l_src, l_trg):
        _, w_omt = match_omt(
            torch.tensor(vtk_get_points(l_src), dtype=torch.float32, device=device),
            torch.tensor(vtk_get_triangles(l_src), dtype=torch.int32, device=device),
            torch.tensor(vtk_get_points(l_trg), dtype=torch.float32, device=device),
            torch.tensor(vtk_get_triangles(l_trg), dtype=torch.int32, device=device))
        v_omt, _, _ = omt_match_to_vertex_weights(l_src, l_trg, w_omt.detach().cpu().numpy())
        return vtk_make_pd(v_omt, vtk_get_triangles(l_src))
    
    # Extract all the isolayers from the image 
    layers = [ layer_to_mesh(img_ls[:,:,:,k]) for k in range(img_ls.GetSize()[3]) ]
    matched = [ None for k in layers ]

    # Determine init layer
    if init_layer is None:
        init_layer = img_ls.GetSize()[3] // 2

    # Propagate from the mesh to the initial layer (unless we want to use a layer as source)
    matched[init_layer] = do_omt(source_mesh, layers[init_layer]) if source_mesh else layers[init_layer]

    # Propagate in both directions
    seq1 = reversed(range(0, init_layer))
    seq2 = reversed(range(img_ls.GetSize()[3]-1, init_layer, -1))
    for seq in seq1, seq2:
        prop_source = matched[init_layer]
        for k in seq:
            print(f'Propagating to layer {k}')
            matched[k] = do_omt(prop_source, layers[k])
            prop_source = matched[k]

    # Return the propagated meshes
    return matched, init_layer

# %%
prof_meshes, mid_layer = profile_meshing_omt(img_ls)
# Out:
# Propagating to layer 4
# 564x551 clusters, computed at scale = 6.935
# Successive scales :  151.332, 151.332, 121.066, 96.853, 77.482, 61.986, 49.589, 39.671, 31.737, 25.389, 20.311, 16.249, 12.999, 10.399, 8.320, 6.656, 5.325, 4.260, 3.408, 2.726, 2.181, 1.745, 1.396, 1.117, 0.893, 0.715, 0.572, 0.457, 0.366, 0.293, 0.234, 0.187, 0.150, 0.120, 0.096, 0.077, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.320) and 15 (σ=6.656).
# Keep 97692/310764 = 31.4% of the coarse cost matrix.
# Keep 100152/318096 = 31.5% of the coarse cost matrix.
# Keep 95287/303601 = 31.4% of the coarse cost matrix.
# OMT matching distance: 0.4317602515220642, time elapsed: 1.5990068912506104
# Propagating to layer 3
# 561x543 clusters, computed at scale = 6.904
# Successive scales :  150.673, 150.673, 120.538, 96.431, 77.144, 61.716, 49.372, 39.498, 31.598, 25.279, 20.223, 16.178, 12.943, 10.354, 8.283, 6.627, 5.301, 4.241, 3.393, 2.714, 2.171, 1.737, 1.390, 1.112, 0.889, 0.712, 0.569, 0.455, 0.364, 0.291, 0.233, 0.187, 0.149, 0.119, 0.096, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.283) and 15 (σ=6.627).
# Keep 95982/304623 = 31.5% of the coarse cost matrix.
# Keep 98949/314721 = 31.4% of the coarse cost matrix.
# Keep 93059/294849 = 31.6% of the coarse cost matrix.
# OMT matching distance: 0.3628784120082855, time elapsed: 1.6024844646453857
# Propagating to layer 2
# 544x529 clusters, computed at scale = 6.882
# Successive scales :  150.189, 150.189, 120.151, 96.121, 76.897, 61.518, 49.214, 39.371, 31.497, 25.198, 20.158, 16.126, 12.901, 10.321, 8.257, 6.605, 5.284, 4.227, 3.382, 2.706, 2.164, 1.732, 1.385, 1.108, 0.887, 0.709, 0.567, 0.454, 0.363, 0.291, 0.232, 0.186, 0.149, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.257) and 15 (σ=6.605).
# Keep 91479/287776 = 31.8% of the coarse cost matrix.
# Keep 93332/295936 = 31.5% of the coarse cost matrix.
# Keep 89595/279841 = 32.0% of the coarse cost matrix.
# OMT matching distance: 0.3501805067062378, time elapsed: 1.5636954307556152
# Propagating to layer 1
# 528x506 clusters, computed at scale = 6.865
# Successive scales :  149.810, 149.810, 119.848, 95.878, 76.702, 61.362, 49.090, 39.272, 31.417, 25.134, 20.107, 16.086, 12.869, 10.295, 8.236, 6.589, 5.271, 4.217, 3.373, 2.699, 2.159, 1.727, 1.382, 1.105, 0.884, 0.707, 0.566, 0.453, 0.362, 0.290, 0.232, 0.185, 0.148, 0.119, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.236) and 15 (σ=6.589).
# Keep 85101/267168 = 31.9% of the coarse cost matrix.
# Keep 89104/278784 = 32.0% of the coarse cost matrix.
# Keep 81260/256036 = 31.7% of the coarse cost matrix.
# OMT matching distance: 0.349528968334198, time elapsed: 1.5286667346954346
# Propagating to layer 0
# 506x492 clusters, computed at scale = 6.853
# Successive scales :  149.543, 149.543, 119.634, 95.707, 76.566, 61.253, 49.002, 39.202, 31.361, 25.089, 20.071, 16.057, 12.846, 10.277, 8.221, 6.577, 5.262, 4.209, 3.367, 2.694, 2.155, 1.724, 1.379, 1.103, 0.883, 0.706, 0.565, 0.452, 0.362, 0.289, 0.231, 0.185, 0.148, 0.118, 0.095, 0.076, 0.061, 0.050
# Jump from coarse to fine between indices 14 (σ=8.221) and 15 (σ=6.577).
# Keep 78668/248952 = 31.6% of the coarse cost matrix.
# Keep 81354/256036 = 31.8% of the coarse cost matrix.
# Keep 76044/242064 = 31.4% of the coarse cost matrix.
# OMT matching distance: 0.39282694458961487, time elapsed: 3.191640615463257
# Propagating to layer 6
# 553x580 clusters, computed at scale = 6.971
# Successive scales :  152.127, 152.127, 121.702, 97.361, 77.889, 62.311, 49.849, 39.879, 31.903, 25.523, 20.418, 16.335, 13.068, 10.454, 8.363, 6.691, 5.352, 4.282, 3.426, 2.740, 2.192, 1.754, 1.403, 1.122, 0.898, 0.718, 0.575, 0.460, 0.368, 0.294, 0.235, 0.188, 0.151, 0.121, 0.096, 0.077, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.363) and 15 (σ=6.691).
# Keep 102453/320740 = 31.9% of the coarse cost matrix.
# Keep 97693/305809 = 31.9% of the coarse cost matrix.
# Keep 107462/336400 = 31.9% of the coarse cost matrix.
# OMT matching distance: 0.5250161290168762, time elapsed: 1.6224756240844727
# Propagating to layer 7
# 564x575 clusters, computed at scale = 7.019
# Successive scales :  153.176, 153.176, 122.541, 98.033, 78.426, 62.741, 50.193, 40.154, 32.123, 25.699, 20.559, 16.447, 13.158, 10.526, 8.421, 6.737, 5.389, 4.312, 3.449, 2.759, 2.208, 1.766, 1.413, 1.130, 0.904, 0.723, 0.579, 0.463, 0.370, 0.296, 0.237, 0.190, 0.152, 0.121, 0.097, 0.078, 0.062, 0.050
# Jump from coarse to fine between indices 14 (σ=8.421) and 15 (σ=6.737).
# Keep 103808/324300 = 32.0% of the coarse cost matrix.
# Keep 102614/318096 = 32.3% of the coarse cost matrix.
# Keep 104963/330625 = 31.7% of the coarse cost matrix.
# OMT matching distance: 0.6806175112724304, time elapsed: 1.6414308547973633
# Propagating to layer 8
# 539x588 clusters, computed at scale = 7.115
# Successive scales :  155.257, 155.257, 124.205, 99.364, 79.491, 63.593, 50.874, 40.700, 32.560, 26.048, 20.838, 16.671, 13.336, 10.669, 8.535, 6.828, 5.463, 4.370, 3.496, 2.797, 2.237, 1.790, 1.432, 1.146, 0.916, 0.733, 0.587, 0.469, 0.375, 0.300, 0.240, 0.192, 0.154, 0.123, 0.098, 0.079, 0.063, 0.050, 0.050
# Jump from coarse to fine between indices 14 (σ=8.535) and 15 (σ=6.828).
# Keep 101307/316932 = 32.0% of the coarse cost matrix.
# Keep 93725/290521 = 32.3% of the coarse cost matrix.
# Keep 108970/345744 = 31.5% of the coarse cost matrix.
# OMT matching distance: 0.9673792123794556, time elapsed: 1.7029132843017578
# Propagating to layer 9
# 558x614 clusters, computed at scale = 7.221
# Successive scales :  157.579, 157.579, 126.063, 100.850, 80.680, 64.544, 51.635, 41.308, 33.047, 26.437, 21.150, 16.920, 13.536, 10.829, 8.663, 6.930, 5.544, 4.435, 3.548, 2.839, 2.271, 1.817, 1.453, 1.163, 0.930, 0.744, 0.595, 0.476, 0.381, 0.305, 0.244, 0.195, 0.156, 0.125, 0.100, 0.080, 0.064, 0.051, 0.050
# Jump from coarse to fine between indices 14 (σ=8.663) and 15 (σ=6.930).
# Keep 106656/342612 = 31.1% of the coarse cost matrix.
# Keep 99072/311364 = 31.8% of the coarse cost matrix.
# Keep 114350/376996 = 30.3% of the coarse cost matrix.
# OMT matching distance: 2.3183438777923584, time elapsed: 1.7906508445739746
# Propagating to layer 10
# 586x631 clusters, computed at scale = 7.309
# Successive scales :  159.495, 159.495, 127.596, 102.077, 81.661, 65.329, 52.263, 41.811, 33.448, 26.759, 21.407, 17.126, 13.701, 10.960, 8.768, 7.015, 5.612, 4.489, 3.592, 2.873, 2.299, 1.839, 1.471, 1.177, 0.941, 0.753, 0.603, 0.482, 0.386, 0.309, 0.247, 0.197, 0.158, 0.126, 0.101, 0.081, 0.065, 0.052, 0.050
# Jump from coarse to fine between indices 14 (σ=8.768) and 15 (σ=7.015).
# Keep 112727/369766 = 30.5% of the coarse cost matrix.
# Keep 106916/343396 = 31.1% of the coarse cost matrix.
# Keep 118163/398161 = 29.7% of the coarse cost matrix.
# OMT matching distance: 5.032562255859375, time elapsed: 1.9046688079833984

# %%
for i, prop_layer in enumerate(prof_meshes):
    save_vtk(prop_layer, f'tmp/test_mesh_profiles_dist_{i:02d}.vtk')

# %%
save_vtk(layer_5, 'tmp/test_levelset_5.vtk')
save_vtk(layer_6, 'tmp/test_levelset_6.vtk')
save_vtk(layer5_omt_to_6, 'tmp/test_levelset_5_to_6.vtk')

# %%
img.SetDirectionMatrix(*layer.GetDirection())

# %%
img_ls.GetSize()
# Out:
# (118, 112, 120, 11)
